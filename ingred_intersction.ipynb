# %%
from __future__ import division
import numpy as np
import pandas as pd
import scipy.stats as st
import itertools
import math
from collections import Counter, defaultdict
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pylab as plt
import matplotlib as mpl
plt.rcParams['figure.figsize'] = (12.0, 6.0)
#%matplotlib notebook
# %matplotlib inline
# %load_ext base16_mplrc
# %base16_mplrc light default
# Out:
# The base16_mplrc extension is already loaded. To reload it, use:
#   %reload_ext base16_mplrc
# Setting plotting theme to default-light. Palette available in b16_colors
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
import cPickle as pickle
from fuzzywuzzy import fuzz, process
from fenaroli_parser.recipe_weights import compute_all_weights, match_ingredients, compute_single_avg_weight

# %% [markdown]
# ## ingredient words

# %%
with open('./data/recipes.pkl', 'r') as f:
    recipe_raw = pickle.load(f)

# %%
recipe_comb = {}
for f in recipe_raw:
    recipe_comb.update(f)

# %%
with open('./comb_recipes.pkl', 'w') as f:
    pickle.dump(recipe_comb, f)

# %%
cocktail_ing_lists = recipe_comb.values()
cocktail_ing_bow = [ing[0].lower() for ing in cocktail_ing_lists]
len(set(cocktail_ing_bow))
# Out:
# 303

# %%
with open('./data/second_ing_flav_dict.pkl', 'r') as f:
    comp_ing_dict = pickle.load(f)

# %%
recipe_comb
# Out:
# {u'Smokin\u2019 Mary': [u'brown simple syrup',
#   u'chipotle hot sauce',
#   u'lapsang souchong tea',
#   u'lime',
#   u'Scotch',
#   u'smoked black pepper',
#   u'smoked paprika',
#   u'vegetable juice',
#   u'vodka',
#   u'Liqueurs'],
#  u'Grapefruit Negroni': [u'Campari',
#   u'grapefruit peel',
#   u'ruby red grapefruit',
#   u'ruby red grapefruit juice',
#   u'sweet vermouth',
#   u'Gin,'],
#  u'The Joy Division': [u'absinthe', u'cointreau', u'dry vermouth', u'Gin'],
#  u'John the Baptist Recipe': [u'absinthe',
#   u'Blume Marillen Apricot Eau de Vie',
#   u'Coco Lopez',
#   u'Green Spot Irish Whiskey',
#   u'Marie Brizard Apry',
#   u'Marie Brizard Creme de Cacao Blanc',
#   u'Matcha green tea powder',
#   u'Pistachio syrup*',
#   u''],
#  u'Harvest Highball': [u'ginger beer',
#   u'lime juice',
#   u'simple syrup',
#   u'Vodka'],
#  u'Perfect Ten Martini': [u'grapefruit twist', u'Gin'],
#  u'Sunset Gold': [u'club soda',
#   u'lemon juice',
#   u'mint',
#   u'simple syrup',
#   u'Vodka'],
#  u'Corpse Reviver No. 1': [u'apple brandy',
#   u'calvados',
#   u'sweet vermouth',
#   u'Brandy'],
#  u'The Translucent Cocktail': [u'cherry',
#   u'cr\xe8me de cacao',
#   u'kirschwasser',
#   u'Gin'],
#  u'Samba Breeze': [u'cranberry juice',
#   u'orange',
#   u'orange juice',
#   u'Cacha\xe7a'],
#  u'Dark and Stormy ': [u'ginger beer', u'lime', u'Rum'],
#  u'Pumpkin &amp; Spice': [u'allspice liqueur',
#   u'bitters',
#   u'black walnut bitters',
#   u'ginger beer',
#   u'molasses',
#   u'pumpkin',
#   u'raw oats',
#   u'sherry',
#   u'Vodka'],
#  u'Bushmills Black Bush The Black Nail': [u'Irish whiskey liqueur',
#   u'orange peel',
#   u'Irish'],
#  u'Piha Spritz Recipe': [u'Fresh lime juice',
#   u'Fresh pineapple juice',
#   u'herbal tea bag',
#   u'palm sugar',
#   u'sage flower',
#   u'white sugar',
#   u'Gin,'],
#  u'Point Reyes Punch Recipe': [u'fresh lemon juice',
#   u'pineapple juice',
#   u'Rum,'],
#  u'Conquistador': [u'Ancho Reyes ancho chile liqueur',
#   u'cr\xe8me de cacao',
#   u'orange',
#   u'orange bitters',
#   u'sherry',
#   u'Liqueurs,'],
#  u'The 56 Julep': [u'brown sugar', u'mint', u'Bourbon'],
#  u'Mount Gay Hot Buttered Rum': [u'allspice',
#   u'brown sugar',
#   u'butter',
#   u'cinnamon',
#   u'cinnamon stick',
#   u'nutmeg',
#   u'vanilla extract',
#   u'Rum'],
#  u'Wild Turkey Sparkling Tea': [u'cherry',
#   u'club soda',
#   u'herbal tea bag',
#   u'honey liqueur',
#   u'lemon',
#   u'Liqueurs'],
#  u'Frenchie': [u'elderflower liqueur',
#   u'grapefruit',
#   u'grapefruit juice',
#   u'Gin'],
#  u'Spiced Pumpkin Flip': [u'agave nectar',
#   u'amaretto',
#   u'pumpkin ale',
#   u'pumpkin butter',
#   u'whole egg',
#   u'Bourbon'],
#  u'Smash and Grab': [u'lemon',
#   u'mint',
#   u'orange',
#   u'simple syrup',
#   u'Bourbon'],
#  u'Orange Poppy': [u'Lemon-lime soda',
#   u'mint',
#   u'orange',
#   u'orange liqueur',
#   u'Absinthe'],
#  u'Preakness': [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'lemon twist',
#   u'sweet vermouth',
#   u'Bourbon'],
#  u'Bloody Sherry Cocktail': [u'Blood orange oleo saccharum',
#   u'lemon juice',
#   u'oloroso sherry',
#   u'Gin'],
#  u'Tender Nob': [u'amaro',
#   u'lemon twist',
#   u'Liquore Strega',
#   u'orange twist',
#   u'walnut orgeat',
#   u'Brandy'],
#  u'Cinnamon Sparkle': [u'cinnamon',
#   u'lemon juice',
#   u'peach liqueur',
#   u'sugar',
#   u'wine',
#   u'Brandy'],
#  u'Magic Hour ': [u'grapefruit juice',
#   u'simple syrup',
#   u'sparkling wine',
#   u'Yellow Chartreuse',
#   u'Vermouth'],
#  u'Cinquecento': [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'Campari',
#   u'grapefruit juice',
#   u'grapefruit twist',
#   u'Vodka'],
#  u'Yamazaki Autumn Delight': [u'apple',
#   u'apple cider',
#   u'cinnamon',
#   u'Japanese'],
#  u'Chopin Holiday Punch': [u'Angostura Bitters',
#   u'apple',
#   u'club soda',
#   u'cranberry juice',
#   u'cucumber',
#   u'lime juice',
#   u'mint',
#   u'orange liqueur',
#   u'pear',
#   u'Vodka'],
#  u'Colony Records': [u'Angostura Bitters',
#   u'cranberry syrup',
#   u'grapefruit juice',
#   u'Rum'],
#  u'Necromancer': [u'elderflower liqueur',
#   u'gin',
#   u'lemon juice',
#   u'Lillet Blanc',
#   u'Absinthe'],
#  u'Tea &amp; C Time ': [u'club soda',
#   u'cream',
#   u'earl grey tea syrup',
#   u'egg white',
#   u'lime juice',
#   u'Cacha\xe7a'],
#  u'Basil Hayden\u2019s Apple Bubbly': [u'apple',
#   u'sparkling apple juice',
#   u'Bourbon'],
#  u'NZ Sauvignon Blanc Punch': [u'aperol',
#   u'club soda',
#   u'grapefruit juice',
#   u'lemon juice',
#   u'simple syrup',
#   u'wine',
#   u'Liqueurs'],
#  u'Rooster-Tail': [u'lemon juice',
#   u'madeira',
#   u'mint',
#   u"Peychaud's Bitters",
#   u'raspberries',
#   u'raspberry syrup',
#   u'Brandy'],
#  u'Italian Love Affair': [u'Champagne', u'pink grapefruit', u'Vodka'],
#  u'Fresh Watermelon Margarita': [u'agave syrup',
#   u'lime juice',
#   u'watermelon',
#   u'Tequila'],
#  u'Euro': [u'dry vermouth', u'orange liqueur', u'sherry', u'Irish'],
#  u'The Modern': [u'agave nectar',
#   u'apple juice',
#   u'lime juice',
#   u'raspberry',
#   u'rose syrup',
#   u'Rum'],
#  u'Black Hawk': [u'cherry',
#   u'lemon juice',
#   u'orange',
#   u'sloe gin',
#   u'Canadian'],
#  u'The Symphony': [u'', u'Brandy'],
#  u'81 Old Fashioned': [u'Angostura Bitters',
#   u'Demerara sugar',
#   u'lemon twist',
#   u'orange bitters',
#   u'orange twist',
#   u'Bourbon'],
#  u'1793': [u'bitters',
#   u'dried lavender blossoms',
#   u'grapefruit juice',
#   u'grapefruit peel',
#   u'lavender',
#   u'lemon peel',
#   u'Lillet Rose',
#   u'pastis',
#   u'sugar',
#   u'Gin'],
#  u'Rub &amp; Rye': [u'barbecue bitters',
#   u'dry rub spice mixture',
#   u'egg white',
#   u'lemon juice',
#   u'maple syrup',
#   u'mesquite salt',
#   u'Scaldis P\xc3\xaache Mel beer',
#   u'Beer,'],
#  u'White Dragon': [u'egg white',
#   u'lemon juice',
#   u'orange liqueur',
#   u'orange twist',
#   u'Tequila'],
#  u'Coral Reef': [u'aperol',
#   u'club soda',
#   u'elderflower liqueur',
#   u'lemon twist',
#   u'Gin'],
#  u'Spiced Cocoa Recipe': [u'cayenne pepper',
#   u'chili pepper',
#   u'cocoa powder',
#   u'salt',
#   u'sugar',
#   u'Bourbon'],
#  u'Basil Hayden\u2019s Last Stand': [u'absinthe',
#   u'bitters',
#   u'club soda',
#   u'lemon',
#   u'Absinthe,'],
#  u'Absolut 100 Pumpkin Martini': [u'cinnamon stick',
#   u'pumpkin spice liqueur',
#   u'simple syrup',
#   u'Vodka'],
#  u'Tequila Sunrise': [u'cherry',
#   u'grenadine',
#   u'orange',
#   u'orange juice',
#   u'Tequila'],
#  u'Stoli Razpiroska': [u'club soda', u'raspberry', u'simple syrup', u'Vodka'],
#  u'Golden Cup': [u'apple',
#   u'club soda',
#   u'cucumber',
#   u'mint',
#   u'orange Cura\xe7ao',
#   u'sherry',
#   u'Gin'],
#  u'Cardamom and Pop Punch': [u'club soda',
#   u'grapefruit juice',
#   u'green cardamom',
#   u'lime',
#   u'lime juice',
#   u'orange bitters',
#   u'sugar',
#   u'Rum'],
#  u'Beefeater French 75': [u'Champagne',
#   u'lemon juice',
#   u'maraschino cherry',
#   u'simple syrup',
#   u'Gin'],
#  u'Witch\u2019s Brew': [u'Champagne', u'cr\xe8me de cassis', u'Vodka'],
#  u'La Poire Peartini': [u'Disaronno',
#   u'lemon juice',
#   u'pear',
#   u'pear vodka',
#   u'simple syrup',
#   u'Vodka'],
#  u'Clover Club': [u'egg white', u'lemon juice', u'raspberry syrup', u'Gin'],
#  u'Leche Mexicana (Mexican Milk)': [u'cr\xe8me de cacao',
#   u'half and half',
#   u'Liqueurs,'],
#  u'Spanish Raindrop': [u'agave nectar',
#   u'lime juice',
#   u'orange zest',
#   u'sherry',
#   u'simple syrup',
#   u'turbinado sugar',
#   u'Tequila'],
#  u'The Brotherhood': [u'B\xe9n\xe9dictine',
#   u'lemon juice',
#   u'lemon peel',
#   u'orange liqueur',
#   u'Irish'],
#  u'Hudson Rob Roy': [u'Angostura Bitters',
#   u'cherry',
#   u'lemon twist',
#   u'sweet vermouth',
#   u'Bourbon'],
#  u'Sage Passage': [u'cucumber',
#   u'lemon juice',
#   u'pomegranate juice',
#   u'sage',
#   u'simple syrup',
#   u'Vodka'],
#  u'Fashionista': [u'agave nectar',
#   u'lime',
#   u'lime juice',
#   u'pomegranate juice',
#   u'wine',
#   u''],
#  u'Grey Goose Classic Martini': [u'dry vermouth',
#   u'lemon twist',
#   u'olive',
#   u'orange bitters',
#   u'Vodka'],
#  u'Lime Bumboo': [u'brown sugar',
#   u'lime',
#   u'lime juice',
#   u'nutmeg',
#   u'orange liqueur',
#   u'Rum'],
#  u'Basil Watermelon Cooler': [u'basil',
#   u'ginger',
#   u'ginger ale',
#   u'lime juice',
#   u'simple syrup',
#   u'watermelon',
#   u'Vodka'],
#  u'Cape Codder': [u'cranberry juice', u'lime', u'Vodka'],
#  u'Kyoto Sour': [u'agave nectar',
#   u'grapefruit',
#   u'lemon juice',
#   u'mint',
#   u'sake',
#   u'Tabasco Sauce',
#   u''],
#  u'French Connection': [u'amaretto', u'Brandy'],
#  u'Dutch Negroni': [u'Campari',
#   u'orange',
#   u'orange zest',
#   u'sweet vermouth',
#   u'Gin,'],
#  u'Black Pepper Gibson': [u'black pepper',
#   u'cocktail onion',
#   u'dry vermouth',
#   u'Vodka'],
#  u'Breakfast Martini': [u'Combier',
#   u'lemon',
#   u'lemon juice',
#   u'rhubarb marmalade',
#   u'Gin'],
#  u'The Rose': [u'brandied cherry',
#   u'cherry brandy',
#   u'dry vermouth',
#   u'raspberry syrup',
#   u'Brandy'],
#  u'Timmy\u2019s Brandy Milk Punch': [u'milk',
#   u'nutmeg',
#   u'powdered sugar',
#   u'vanilla extract',
#   u'Brandy'],
#  u'Dukes Gin Classic Martini': [u'dry vermouth', u'lemon twist', u'Gin'],
#  u'Beefeater Tom Collins': [u'club soda',
#   u'lemon',
#   u'lemon juice',
#   u'simple syrup',
#   u'Gin'],
#  u'The Hornitos Hot Shotty': [u'chili powder',
#   u'hot chocolate',
#   u'whipped cream',
#   u'Tequila'],
#  u'Sazerac': [u'absinthe',
#   u'Angostura Bitters',
#   u'lemon peel',
#   u"Peychaud's Bitters",
#   u'sugar',
#   u'Absinthe,'],
#  u'Green Derby': [u'ginger syrup',
#   u'Grade A maple syrup',
#   u'grapefruit juice',
#   u'The Dead Rabbit Orinoco Bitters',
#   u'Bourbon'],
#  u'The Sherry-Netherland': [u'orange bitters',
#   u'orange liqueur',
#   u'raisin',
#   u'sherry',
#   u'Gin'],
#  u'Sunset on the Pacific': [u'kaffir lime leaf', u'tangerine', u'Tequila'],
#  u'The Pale Rider': [u'absinthe',
#   u'Angostura Bitters',
#   u'dry vermouth',
#   u'lemon peel',
#   u'orange bitters',
#   u'sherry',
#   u'thyme liqueur',
#   u'Gin'],
#  u'Mink Coat and No Manners': [u'cayenne pepper',
#   u'Green Chartreuse',
#   u'Liqueurs,'],
#  u'VeeV Holiday Highball': [u'apple chip',
#   u'Green Chartreuse',
#   u'mint',
#   u'simple syrup',
#   u'sparkling apple cider',
#   u'sparkling pear cider',
#   u'Liqueurs'],
#  u'My Spicy Valentine': [u'chocolate bitters',
#   u'cr\xe8me de cacao',
#   u'milk',
#   u'orange liqueur',
#   u'red Fresno chile pepper',
#   u'Vodka'],
#  u'Kyuuri Hana': [u'cucumber vodka',
#   u'mint',
#   u'simple syrup',
#   u'sour mix',
#   u'Gin'],
#  u'One-Two Punch': [u'grapefruit',
#   u'grapefruit juice',
#   u'lemon',
#   u'lemon juice',
#   u'pilsner',
#   u'sugar',
#   u'Beer,'],
#  u'Raspberry White Chocolate Truffle': [u'cr\xe8me de cacao',
#   u'raspberry',
#   u'raspberry liqueur',
#   u'white chocolate liqueur',
#   u'Liqueurs,'],
#  u'Pi\xf1a Perfection': [u'lime juice',
#   u'pineapple juice',
#   u'rosemary',
#   u'simple syrup',
#   u'Tequila'],
#  u'The Billionaire Cocktail': [u'absinthe',
#   u'Angostura Bitters',
#   u'Green Chartreuse',
#   u'grenadine',
#   u'lemon juice',
#   u'mint bitters',
#   u"Peychaud's Bitters",
#   u'simple syrup',
#   u'Bourbon'],
#  u'Hot Toddy': [u'brown sugar',
#   u'clove',
#   u'Demerara sugar',
#   u'lemon juice',
#   u'lemon twist',
#   u'Bourbon'],
#  u'Bushmills Irish Buck': [u'ginger ale',
#   u'lime juice',
#   u'lime wheel',
#   u'Irish'],
#  u'Shamrock Sour': [u'agave nectar',
#   u'egg white',
#   u'grapefruit juice',
#   u'Green Chartreuse',
#   u'lemon',
#   u'lemon juice',
#   u'mint',
#   u'Bourbon'],
#  u'Mangape\xf1o': [u'aperol',
#   u'jalape\xf1o',
#   u'lemon juice',
#   u'mango syrup',
#   u'Vodka'],
#  u'Ten French 75': [u'Champagne',
#   u'lemon juice',
#   u'lemon twist',
#   u'simple syrup',
#   u'Gin'],
#  u'Winter Sour': [u'Campari',
#   u'egg white',
#   u'honey',
#   u'Meyer lemon juice',
#   u'rosemary',
#   u'Liqueurs'],
#  u'Baileys Mocha Monkey': [u'Baileys with a Hint of Coffee',
#   u'banana',
#   u'chocolate syrup',
#   u'coffee bean',
#   u'vanilla ice cream',
#   u'Liqueurs'],
#  u'Falling Leaves': [u'Dry Riesling',
#   u'honey syrup',
#   u'orange Cura\xe7ao',
#   u"Peychaud's Bitters",
#   u'Vermouth'],
#  u'Moscow Mule': [u'ginger beer', u'lime', u'Vodka'],
#  u'White Sangria': [u'grape',
#   u'lime',
#   u'orange',
#   u'orange liqueur',
#   u'peach',
#   u'wine',
#   u'Liqueurs'],
#  u'Woodford Reserve Rocks': [u'', u'Bourbon'],
#  u'Fish House Punch': [u'Demerara sugar',
#   u'lemon',
#   u'lemon juice',
#   u'nutmeg',
#   u'peach brand',
#   u'Brandy'],
#  u'The Gold Rush': [u'cherry', u'ginger liqueur', u'lemon juice', u'Bourbon'],
#  u'La Valencia': [u'Angostura Bitters',
#   u'chamomile tea',
#   u'lemon juice',
#   u'sherry',
#   u'simple syrup',
#   u'Yellow Chartreuse',
#   u'Rye'],
#  u'Chocomole': [u'agave nectar',
#   u'black peppercorn',
#   u'chile powder',
#   u'cinnamon',
#   u'corn chip',
#   u'cumin',
#   u'evaporated milk',
#   u'guajillo chile',
#   u'Mexican hot chocolate mix',
#   u'oregano',
#   u'peanut butter',
#   u'Tequila'],
#  u'USS Richmond Punch': [u'Champagne',
#   u'club soda',
#   u'lemon',
#   u'nutmeg',
#   u'orange liqueur',
#   u'port',
#   u'sugar',
#   u'tea',
#   u'Brandy'],
#  u'Tippy Cow\xe2\u201e\xa2 Halloween Layered Shooters: Toot Toot Tootsie': [u'',
#   u'Liqueurs'],
#  u"Rudolph's Nose Recipe": [u'Chateau Montifaud Pineau de Charentes Rosso',
#   u'Gran Classico Bitter',
#   u'luxardo cherry',
#   u'Luxardo Maraschino Liqueur',
#   u'Other'],
#  u'Hornitos Watermelon Paloma Recipe': [u'', u'Tequila'],
#  u'Mojito Italiano': [u'Campari',
#   u'lemon juice',
#   u'mint',
#   u'prosecco',
#   u'simple syrup',
#   u'Rum'],
#  u'Apple Dandy': [u'chamomile tea',
#   u'evaporated cane juice',
#   u'lemon',
#   u'pommeau de Normandie',
#   u'Tequila'],
#  u'Dizzy Blonde Negroni': [u'aperol',
#   u'cointreau',
#   u'dry vermouth',
#   u'water',
#   u'Gin'],
#  u'Brian Boru': [u'absinthe',
#   u'chamomile flowers',
#   u'Cherry Heering',
#   u'Everclear',
#   u'green tea bags',
#   u'honey liqueur',
#   u'lemon juice',
#   u'lemon sherbet',
#   u'nutmeg',
#   u'Vodka'],
#  u'Moroccopolitan': [u'honey',
#   u'lemon juice',
#   u'Moroccan bitters',
#   u'pomegranate',
#   u'Vodka'],
#  u'Cunningham': [u'B\xe9n\xe9dictine',
#   u'blood orange juice',
#   u'blood orange twist',
#   u'brandied cherries',
#   u'Cherry Heering',
#   u'lemon juice',
#   u'Scotch'],
#  u'Swedish Mule': [u'ginger beer', u'lime juice', u'simple syrup', u'Vodka'],
#  u'The Blackthorn': [u'absinthe',
#   u'Angostura Bitters',
#   u'lemon twist',
#   u'sweet vermouth',
#   u'Irish'],
#  u'Cannibal Corpse Reviver No. 2': [u'Fernet-Branca',
#   u'lemon',
#   u'lemon juice',
#   u'pear brandy',
#   u'prosecco',
#   u'simple syrup',
#   u'Gin'],
#  u'Apple Irish Coffee': [u'apple brandy',
#   u'coffee',
#   u'lemon twist',
#   u'Yellow Chartreuse',
#   u'Liqueurs'],
#  u'Forbidden Sour': [u'cherry',
#   u'lemon juice',
#   u'orange',
#   u'pomegranate liqueur',
#   u'simple syrup',
#   u'Bourbon'],
#  u'Hwayo Vieux Carr\xe9 Recipe': [u'Angostura Bitters',
#   u'lemon twist',
#   u"Peychaud's Bitters",
#   u''],
#  u'Summer\u2019s End': [u'applejack',
#   u'cherry',
#   u'cherry liqueur',
#   u'lemon twist',
#   u'Brandy'],
#  u'The Bottom Line': [u'amaro',
#   u'Angostura Bitters',
#   u'honey liqueur',
#   u'orange bitters',
#   u'sherry',
#   u'Scotch'],
#  u'The Sazerac Cocktail': [u'anise liqueur',
#   u'lemon peel',
#   u"Peychaud's Bitters",
#   u'sugar',
#   u'Rye'],
#  u'Twist My Arm(agnac) Recipe': [u'Demerara syrup',
#   u'fresh lemon juice',
#   u'Fresh pineapple juice',
#   u'pineapple core',
#   u'Brandy'],
#  u'Gibson': [u'cocktail onion', u'dry vermouth', u'Gin,'],
#  u'Horni Toddy': [u'cinnamon stick',
#   u'honey',
#   u'lemon',
#   u'lemon juice',
#   u'tea',
#   u'Tequila'],
#  u'Dubious Manhattan': [u'dried cherry',
#   u'Dubonnet Rouge',
#   u'peach bitters',
#   u'sugar',
#   u'sweet vermouth',
#   u'Bourbon'],
#  u'Ginger Rogers': [u'7UP',
#   u'Campari',
#   u'clementine',
#   u'edible pansy',
#   u'ground ginger',
#   u'orange juice',
#   u'strawberry',
#   u'Liqueurs'],
#  u'24 Sour': [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'cherry',
#   u'egg white',
#   u'lemon juice',
#   u'orange',
#   u'simple syrup',
#   u'Gin'],
#  u'Vieux Carr\xe9': [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u"Peychaud's Bitters",
#   u'sweet vermouth',
#   u'Brandy'],
#  u'Bourbon Rickey': [u'club soda', u'lime', u'Bourbon'],
#  u'Monsoon Sangria Recipe': [u'basil',
#   u'blue Cura\xe7ao',
#   u'blueberries',
#   u'club soda',
#   u'concord grapes',
#   u'lemon',
#   u'plum',
#   u'sugar',
#   u'tea',
#   u''],
#  u'Cherry Bomb': [u'cherry',
#   u'cherry liqueur',
#   u'club soda',
#   u'lime',
#   u'lime juice',
#   u'Cacha\xe7a'],
#  u'No. 3 French 75': [u'brandied cherry',
#   u'Champagne',
#   u'lemon juice',
#   u'simple syrup',
#   u'Gin'],
#  u'Tippy Cow\xe2\u201e\xa2 Halloween Layered Shooters: Candy Corn': [u'',
#   u'Liqueurs'],
#  u'Camus Fresh': [u'lemon juice', u'lemon peel', u'simple syrup', u'Brandy'],
#  u'Malena': [u'Campari',
#   u'cinnamon',
#   u'orange',
#   u'orange bitters',
#   u'orange blossom water',
#   u'port',
#   u'Liqueurs,'],
#  u'Moon Mountain Raspberry Sling': [u'ginger',
#   u'lime juice',
#   u'raspberry',
#   u'sugar',
#   u'tonic water',
#   u'Vodka'],
#  u'Tipperary Cocktail Recipe': [u'Angostura Bitters',
#   u'Green Chartreuse',
#   u'orange peel',
#   u'sweet vermouth',
#   u'Irish'],
#  u'Hanalei Sun': [u'pineapple', u'Rum,'],
#  u'Mata Hari': [u'black tea',
#   u'cardamom',
#   u'chai',
#   u'cinnamon stick',
#   u'clove',
#   u'dried rose buds',
#   u'ginger',
#   u'lemon juice',
#   u'pomegranate juice',
#   u'simple syrup',
#   u'sweet vermouth',
#   u'Brandy'],
#  u'Montford Spritz': [u'aperol',
#   u'Champagne',
#   u'Cynar',
#   u'grapefruit twist',
#   u'Lillet Blanc',
#   u"Peychaud's Bitters",
#   u'Gin,'],
#  u'Airmail Punch': [u'Champagne',
#   u'honey syrup',
#   u'lime juice',
#   u'nutmeg',
#   u'Rum'],
#  u'Very Sexy Martini': [u'Champagne',
#   u'lime juice',
#   u'mint',
#   u'raspberry',
#   u'simple syrup',
#   u'Vodka'],
#  u'Bayou Bloody Mary': [u'black pepper',
#   u'celery salt',
#   u'crawfish tail',
#   u'horseradish',
#   u'lemon juice',
#   u'olive',
#   u'pickled string bean',
#   u'Tabasco Sauce',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Vodka'],
#  u'A\xe7a\xed Cosmo': [u'cranberry juice',
#   u'Grand Marnier',
#   u'lemon twist',
#   u'lime juice',
#   u'orange liqueur',
#   u'strawberry',
#   u'VeeV A\xe7ai Spirit',
#   u'Liqueurs'],
#  u'Tough to Hear': [u'chile de arbol',
#   u'lime juice',
#   u'st. germain',
#   u'Absinthe,'],
#  u'Deshler': [u'Dubonnet Rouge',
#   u'orange liqueur',
#   u'orange twist',
#   u"Peychaud's Bitters",
#   u'Rye'],
#  u'La Cola Nostra': [u'amaro',
#   u'lime',
#   u'lime juice',
#   u'pimento dram',
#   u'prosecco',
#   u'simple syrup',
#   u'sparkling wine',
#   u'Rum'],
#  u'Ruby Mae\u2019s (Second) Surfing Bird': [u'Campari',
#   u'lime juice',
#   u'mezcal',
#   u'passion fruit syrup',
#   u'pineapple juice',
#   u'simple syrup',
#   u''],
#  u'Patr\xf3n Grapefruit ': [u'club soda',
#   u'grapefruit juice',
#   u'lemon',
#   u'lime',
#   u'orange liqueur',
#   u'Tequila'],
#  u'Bloody-tini': [u'a\xe7ai juice',
#   u'Champagne',
#   u'lime juice',
#   u'VeeV',
#   u'Liqueurs'],
#  u'Neighborhood Negroni': [u'Campari',
#   u'orange slice',
#   u'orange twist',
#   u'sweet vermouth',
#   u'Gin,'],
#  u'1792 Kentucky White Dog Julep': [u'mint',
#   u'moonshine',
#   u'sugar',
#   u'white dog',
#   u'Bourbon'],
#  u'Finlandia Vodka Cranberry French Martini': [u'lemon twist',
#   u'pineapple juice',
#   u'raspberry liqueur',
#   u'Vodka'],
#  u'A\xe7ai-Blueberry Mojito': [u'blueberry',
#   u'club soda',
#   u'lime juice',
#   u'mint',
#   u'simple syrup',
#   u'Vodka'],
#  u'Breakfast Margarita': [u'agave nectar',
#   u'lime juice',
#   u'orange',
#   u'orange liqueur',
#   u'orange marmalade',
#   u'Tequila'],
#  u'Brazilian': [u'lemon', u'lemonade', u'Vodka'],
#  u'Hellfire': [u'beer', u'ginger beer', u'lime', u'Tabasco Sauce', u'Beer,'],
#  u'Grand Sidecar': [u'lemon juice',
#   u'orange liqueur',
#   u'simple syrup',
#   u'sugar',
#   u'Liqueurs'],
#  u'The Last Word': [u'Green Chartreuse',
#   u'lime juice',
#   u'maraschino liqueur',
#   u'Gin,'],
#  u'Mexican Punch': [u'7UP',
#   u'bitters',
#   u'grenadine',
#   u'lemon',
#   u'lime',
#   u'lime juice',
#   u'orange',
#   u'simple syrup',
#   u'Tequila'],
#  u'5 Keys Recipe': [u'cherry',
#   u'Cynar',
#   u'maraschino liqueur',
#   u'sweet vermouth',
#   u'Bourbon'],
#  u'Sacred Grape Recipe': [u'concord grape',
#   u'concord grape puree',
#   u'sugar',
#   u'Thai basil',
#   u'Gin'],
#  u'Margaritas by the Pitcher': [u'agave nectar',
#   u'lime',
#   u'lime juice',
#   u'orange liqueur',
#   u'simple syrup',
#   u'Tequila'],
#  u'Rubia Bonita': [u'aperol',
#   u'cilantro',
#   u'lime juice',
#   u'orange bitters',
#   u'simple syrup',
#   u'strawberry',
#   u'Tequila'],
#  u'Ten Rickey': [u'club soda', u'lime', u'lime juice', u'sour mix', u'Gin'],
#  u'Yellow Bird': [u'Galliano', u'lime', u'lime juice', u'triple sec', u'Rum'],
#  u'Margarita Cocktail Recipe': [u'lime',
#   u'lime juice',
#   u'orange liqueur',
#   u'triple sec',
#   u'Tequila'],
#  u'Front Porch Swing': [u'berries',
#   u'grape',
#   u'mint',
#   u'orange',
#   u'st. germain',
#   u'tarragon',
#   u'white wine',
#   u'Vodka'],
#  u'Beggar\u2019s Banquet': [u'Angostura Bitters',
#   u'beer',
#   u'lemon juice',
#   u'maple syrup',
#   u'orange',
#   u'Beer,'],
#  u'Baileys Toasted Almond Brittle': [u'almond',
#   u'Baileys with a Hint of Caramel',
#   u'half and half',
#   u'hazelnut liqueur',
#   u'honey',
#   u'vanilla liqueur',
#   u'Liqueurs'],
#  u'Fall and Summer': [u'fig preserves',
#   u'ginger',
#   u'orange juice',
#   u'rosemary',
#   u'sugar',
#   u'Tequila'],
#  u'Holiday \u201cSauce\u201d': [u'cinnamon',
#   u'cranberry sauce',
#   u'Fee Brothers Cranberry Bitters',
#   u'lemon juice',
#   u'sugar',
#   u'Brandy'],
#  u'Not Manhattan': [u'Angostura Bitters',
#   u'apple juice',
#   u'cherry',
#   u"Peychaud's Bitters",
#   u'Rum'],
#  u'Train\u2019s A Comin\u2019 Recipe': [u'absinthe',
#   u'cinnamon sticks',
#   u'concord grapes',
#   u'lemon juice',
#   u'lemon twist',
#   u'star anise',
#   u'sugar',
#   u'Brandy'],
#  u'Strawberry Basil Lemonade': [u'basil',
#   u'club soda',
#   u'lemonade',
#   u'strawberry',
#   u'Gin'],
#  u'No. 3 Gin &amp; Tonic': [u'lime', u'tonic water', u'Gin'],
#  u'Dry Martini': [u'dry vermouth', u'lemon twist', u'orange bitters', u'Gin,'],
#  u'Stars and Stripes ': [u'absinthe',
#   u'blueberry',
#   u'ginger beer',
#   u'lemon juice',
#   u'raspberry brandy',
#   u'simple syrup',
#   u'sugar',
#   u'Absinthe,'],
#  u'Back to Capistrano Recipe': [u'Angostura Bitters',
#   u'cinnamon syrup',
#   u'concord grapes',
#   u'Demerara syrup',
#   u'lemon juice',
#   u'sorghum syrup',
#   u'Liqueurs'],
#  u'Vanilla-Orangecello': [u'', u'Liqueurs'],
#  u'Bellini': [u'peach', u'prosecco', u'white peach puree', u''],
#  u'Kumquat Syrup': [u'kumquats', u'vodka', u'water', u'white sugar', u''],
#  u'Eggnog': [u'', u'Bourbon'],
#  u'Ready Fire Aim': [u'hellfire bitters',
#   u'honey-pinapple syrup',
#   u'lime juice',
#   u'mezcal',
#   u'pineapple juice',
#   u'Mezcal'],
#  u'Mint Muse ': [u'7UP',
#   u'lime',
#   u'mint',
#   u'pineapple juice',
#   u'Sprite',
#   u'Absinthe'],
#  u'Heated Affair': [u'allspice',
#   u'apple juice',
#   u'cinnamon',
#   u'clove',
#   u'heavy cream',
#   u'nutmeg',
#   u'orange peel',
#   u'Tequila'],
#  u'Bloody Mason': [u'bacon',
#   u'beef straw',
#   u'bloody mary mix',
#   u'celery',
#   u'celery salt',
#   u'cocktail onion',
#   u'lemon',
#   u'lime',
#   u'pickled green bean',
#   u'pickled okra',
#   u'prepared horseradish',
#   u'sea salt',
#   u'Sriracha',
#   u'Tabasco Sauce',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Vodka'],
#  u'Crime and Punishment': [u'aperol',
#   u'orange bitters',
#   u'sweet vermouth',
#   u'Bourbon'],
#  u'The Ultimat Dill': [u'agave nectar',
#   u'cucumber slices',
#   u'dill',
#   u'lime juice',
#   u'Vodka'],
#  u'Pharaoh Cooler': [u'club soda',
#   u'grenadine',
#   u'lime juice',
#   u'orange flower water',
#   u'watermelon juice',
#   u'Tequila'],
#  u'The Good Cork': [u'B\xe9n\xe9dictine', u"Peychaud's Bitters", u'Irish'],
#  u'Barbacoa': [u'agave nectar',
#   u'beef jerky',
#   u'bell pepper',
#   u'chipotle pepper',
#   u'ginger syrup',
#   u'lemon',
#   u'lemon juice',
#   u'lime',
#   u'lime wedge',
#   u'Mezcal'],
#  u'Moon Mountain Greyhound': [u'elderflower liqueur',
#   u'grapefruit peel',
#   u'orgeat syrup',
#   u'rosemary',
#   u'ruby red grapefruit juice',
#   u'salt',
#   u'Vodka'],
#  u'Woodford Reserve Rye Manhattan Cocktail Recipe': [u'brandied cherries',
#   u'sweet vermouth',
#   u'Rye'],
#  u'Woodford Reserve Lions Tail': [u'Angostura Bitters',
#   u'lime juice',
#   u'orange peel',
#   u'simple syrup',
#   u'St. Elizabeth Allspice Dram',
#   u'Bourbon'],
#  u'Tripper Duval\u2019s Manhattan': [u'Angostura Bitters',
#   u'vermouth',
#   u'Bourbon'],
#  u'Hot Buttered Rum': [u'brown sugar',
#   u'butter',
#   u'cinnamon',
#   u'cloves',
#   u'ice cream',
#   u'nutmeg',
#   u'sugar',
#   u'Rum'],
#  u'Lychee Recipe': [u'Absolut Smoked Tea',
#   u'Coconut-lychee milk*',
#   u'Fresh lime juice',
#   u'Salted pistachio syrup*',
#   u'Vodka'],
#  u'Green Acres Punch': [u'Demerara sugar', u'green tea', u'Rum'],
#  u'McGlashan': [u'bitters',
#   u'ginger',
#   u'lemon juice',
#   u'oloroso sherry',
#   u'orange-ginger marmalade',
#   u'sugar',
#   u'Irish'],
#  u'Couture-tini': [u'agave nectar',
#   u'sparkling wine',
#   u'strawberry',
#   u'wine',
#   u''],
#  u'Americano': [u'Campari',
#   u'club soda',
#   u'orange twist',
#   u'sweet vermouth',
#   u'Liqueurs,'],
#  u'The Holland House': [u'dry vermouth',
#   u'lemon juice',
#   u'lemon twist',
#   u'maraschino liqueur',
#   u'Gin,'],
#  u'Copper &amp; Kings Brandy Old Fashioned': [u'amarena cherry',
#   u'Angostura Bitters',
#   u'orange',
#   u'sugar cube',
#   u'Brandy'],
#  u'Dubonnet Cosmopolitan': [u'', u'Vermouth'],
#  u'Stag\u2019s Leap Recipe': [u'seltzer', u'Liqueurs,'],
#  u'Remnants of Summer': [u'cucumber',
#   u'Fernet-Branca',
#   u'lime juice',
#   u'maraschino liqueur',
#   u'sparkling wine',
#   u'Tequila'],
#  u'The Copper': [u'apple juice',
#   u'black tea',
#   u'cinnamon',
#   u'lemon',
#   u'lemon juice',
#   u'nutmeg',
#   u'star anise',
#   u'Irish'],
#  u'Brandy Crusta': [u'Angostura Bitters',
#   u'lemon juice',
#   u'maraschino liqueur',
#   u'simple syrup',
#   u'triple sec',
#   u'Brandy'],
#  u'The Ascot': [u'dry vermouth', u'sweet vermouth', u'Brandy'],
#  u'Wild Turkey Mint Tea': [u'black tea',
#   u'lemon juice',
#   u'lime juice',
#   u'mint',
#   u'sugar',
#   u'Bourbon'],
#  u'Cousin Eddie': [u'black pepper',
#   u'cinnamon',
#   u'egg',
#   u'heavy cream',
#   u'nutmeg',
#   u'sugar',
#   u'Brandy'],
#  u'Jewel Mine': [u'The Dead Rabbit Orinoco Bitters',
#   u'tonic water',
#   u'Bourbon'],
#  u'Caf\xe9 Correcci\xf3n Ponche': [u'cinnamon',
#   u'coffee',
#   u'Demerara sugar',
#   u'orange juice',
#   u'orange peel',
#   u'simple syrup',
#   u'sweet vermouth',
#   u'Rum,'],
#  u'Space Gin Smash': [u'apple',
#   u'grape',
#   u'lemon',
#   u'mint',
#   u'simple syrup',
#   u'Gin'],
#  u'Dutchman\u2019s Daiquiri': [u'chile pepper',
#   u'lime juice',
#   u'simple syrup',
#   u'Gin'],
#  u'Hurricane': [u'cherry',
#   u'grenadine',
#   u'lime juice',
#   u'orange',
#   u'orange juice',
#   u'passion fruit juice',
#   u'simple syrup',
#   u'Rum'],
#  u'Maison Premiere Sazerac': [u'bitters',
#   u'lemon twist',
#   u'simple syrup',
#   u'Absinthe,'],
#  u'Weekend Getaway': [u'basil leaves',
#   u'club soda',
#   u'lemon juice',
#   u'pineapple syrup',
#   u'Vodka'],
#  u'Nomayo': [u'aperol',
#   u'Champagne',
#   u'elderflower liqueur',
#   u'lemon juice',
#   u'lime twist',
#   u'Gin,'],
#  u'Peppermint Tea Syrup': [u'Peppermint tea', u'sugar', u'water', u''],
#  u'Patrinos Recipe': [u'brewed coffee',
#   u'ground cinnamon',
#   u'milk',
#   u'Liqueurs'],
#  u'Kilbeggan Waterwheel': [u'apple juice',
#   u'blueberry',
#   u'cherry bitters',
#   u'pineapple juice',
#   u'sugar',
#   u'Irish'],
#  u'Hubble\u2019s Law': [u'Amaro Montenegro',
#   u'brown sugar syrup',
#   u'lime juice',
#   u'Vodka'],
#  u'Pomchi Smash': [u'Angostura Bitters',
#   u'cranberry juice',
#   u'ginger ale',
#   u'lemon juice',
#   u'mint',
#   u'raspberry',
#   u'simple syrup',
#   u'Rum'],
#  u'Spiced Apple Fizz': [u'apple cider',
#   u'honey syrup',
#   u'lemon juice',
#   u'pear brandy',
#   u'Vodka'],
#  u'Basil Simple Syrup': [u'basil', u'sugar', u'water', u'Non-alcoholic'],
#  u'St-Rita': [u'elderflower liqueur',
#   u'lime',
#   u'lime juice',
#   u'salt',
#   u'Liqueurs,'],
#  u'C &amp; B Old Fashioned ': [u'B\xe9n\xe9dictine',
#   u'Campari',
#   u'club soda',
#   u'Lillet Blanc',
#   u'orange liqueur',
#   u'orange twist',
#   u'Gin,'],
#  u'Autumn': [u'Amontillado sherry',
#   u'apple bitters',
#   u'Clear Creek Pear Brandy',
#   u'maple syrup',
#   u'Brandy'],
#  u'Woodford Reserve Manhattan': [u'cherry', u'sweet vermouth', u'Bourbon'],
#  u'Black Widow': [u'agave nectar',
#   u'basil',
#   u'blackberry',
#   u'lime juice',
#   u'Tequila'],
#  u'Holiday Gl\xf6gg': [u'blanched almonds',
#   u'mulling spices',
#   u'orange zest',
#   u'raisin',
#   u'sugar',
#   u'wine',
#   u'Vodka'],
#  u'El Bicentenario': [u'agave nectar',
#   u'habanero pepper',
#   u'lime juice',
#   u'tangerine',
#   u'Tequila'],
#  u'Pyrat Passion': [u'grenadine', u'peach', u'peach puree', u'Rum'],
#  u'Guava Rose': [u'guava puree',
#   u'lime juice',
#   u'rose petal',
#   u'rose syrup',
#   u'Cacha\xe7a'],
#  u'B-52': [u'Baileys', u'coffee liqueur', u'orange liqueur', u'Liqueurs'],
#  u'Don Julio Hot Nantucket Night': [u'agave nectar',
#   u'cranberry',
#   u'jalape\xf1o',
#   u'lime juice',
#   u'Tequila'],
#  u'Raspberry Bellini': [u'raspberry',
#   u'sparkling wine',
#   u'white peach',
#   u'Vodka'],
#  u'The Casa Noble Old Fashioned': [u'agave nectar',
#   u'Angostura Bitters',
#   u'orange',
#   u'Tequila'],
#  u'Bourbon Manhattan': [u'Angostura Bitters', u'sweet vermouth', u'Bourbon'],
#  u'Blood Sage': [u'blood orange',
#   u'egg white',
#   u'lime juice',
#   u'sage',
#   u'simple syrup',
#   u'Gin'],
#  u'Red Red \u201cVine\u201d': [u'club soda',
#   u'ginger',
#   u'grape',
#   u'lemon',
#   u'mint',
#   u'raw sugar',
#   u'Gin'],
#  u'Monte Cassino': [u'B\xe9n\xe9dictine',
#   u'lemon juice',
#   u'lemon twist',
#   u'Yellow Chartreuse',
#   u'Liqueurs,'],
#  u'Flying Dutchman': [u'B\xe9n\xe9dictine',
#   u'lemon juice',
#   u'Yellow Chartreuse',
#   u'Gin'],
#  u'Golden Gate Spritz Recipe': [u'fresh grapefruit juice',
#   u'grapefruit peel',
#   u'sparkling wine',
#   u'Vermouth'],
#  u'Boilermaker': [u'beer', u'Beer,'],
#  u'Hydrate': [u'cucumber',
#   u'lime juice',
#   u'mint',
#   u'Truvia',
#   u'watermelon',
#   u'Vodka'],
#  u'Ponche Navide\xf1o': [u'apple',
#   u'brown sugar',
#   u'cinnamon',
#   u'clove',
#   u'guava',
#   u'hibiscus',
#   u'pear',
#   u'pink peppercorn',
#   u'star anise',
#   u'sugar cane',
#   u'tamarind',
#   u'tejocote',
#   u'walnut',
#   u'Brandy'],
#  u'Bloody Bulldog': [u'asparagus',
#   u'balsamic vinegar',
#   u'black pepper',
#   u'carrot',
#   u'celery',
#   u'celery salt',
#   u'dill pickle',
#   u'garlic',
#   u'horseradish',
#   u'lemon juice',
#   u'olive',
#   u'pickled okra',
#   u'Tabasco Sauce',
#   u'tomato',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Gin'],
#  u'Spiced Pear Bellini': [u'cinnamon',
#   u'nutmeg',
#   u'pear brandy',
#   u'Pear puree or nectar',
#   u'sparkling wine',
#   u''],
#  u'Mudslide': [u'chocolate syrup', u'cream', u'ice', u'milk', u'Liqueurs,'],
#  u'1942 Martini Cocktail Recipe': [u'dry vermouth',
#   u'orange bitters',
#   u'orange peel',
#   u'Tequila,'],
#  u'Grand Coffee': [u'brown sugar',
#   u'coffee',
#   u'orange liqueur',
#   u'whipped cream',
#   u'Liqueurs'],
#  u'Tarragon Simple Syrup': [u'sugar', u'tarragon', u'water', u'Non-alcoholic'],
#  u'Fat Like Buddha Cocktail': [u'B\xe9n\xe9dictine',
#   u'Dubonnet Rouge',
#   u'orange liqueur',
#   u'orange twist',
#   u'Rum'],
#  u'Rosie Lee': [u'Angostura Bitters',
#   u'lemon',
#   u'lemon juice',
#   u'lychee juice',
#   u'orange',
#   u'rose petal',
#   u'simple syrup',
#   u'Gin'],
#  u'Two-Hit Fig Punch': [u'fig',
#   u'lemon juice',
#   u'lime',
#   u'nutmeg',
#   u'orange juice',
#   u'simple syrup',
#   u'Bourbon'],
#  u'Bitter Lemon Cooler': [u'bitter lemon soda',
#   u'dry vermouth',
#   u'grenadine',
#   u'lemon',
#   u'lemon juice',
#   u'Gin,'],
#  u'Negroni Sbagliato': [u'cinnamon', u'fruit', u'prosecco', u'Liqueurs,'],
#  u'Campari Sparkling Passion': [u'Campari',
#   u'grapefruit juice',
#   u'mint',
#   u'orange',
#   u'passion fruit puree',
#   u'prosecco',
#   u'raspberry',
#   u'Liqueurs'],
#  u'Jack &amp; Canton': [u'ginger liqueur',
#   u'lime',
#   u'sweetened lime juice',
#   u'tonic water',
#   u'Bourbon'],
#  u'Hard Water Presbyterian': [u'candied ginger',
#   u'club soda',
#   u'ginger syrup',
#   u'lemon juice',
#   u'Bourbon'],
#  u'Stoli Gala Applik Sangria': [u'apple',
#   u'lemon',
#   u'lime',
#   u'orange',
#   u'strawberry',
#   u'white cranberry juice',
#   u'wine',
#   u'Vodka'],
#  u'Scramble': [u'agave nectar',
#   u'blackberry',
#   u'blackberry liqueur',
#   u'lemon juice',
#   u'lemon twist',
#   u'lime juice',
#   u'Tequila'],
#  u'Tequila Daisy': [u'club soda',
#   u'Grand Marnier',
#   u'lemon juice',
#   u'sugar',
#   u'Tequila'],
#  u'Singapore Raffles Sling': [u'B\xe9n\xe9dictine',
#   u'cherry',
#   u'cherry brandy',
#   u'club soda',
#   u'lime',
#   u'Gin'],
#  u'Pimm\u2019s Cup': [u'7UP',
#   u'cucumber',
#   u'lemon',
#   u'mint',
#   u'orange',
#   u"Pimm's No. 1",
#   u'Sprite',
#   u'strawberry',
#   u'Liqueurs'],
#  u'Girls Next Door': [u'Bittermens Burlesque Bitters',
#   u'egg white',
#   u'hibiscus-rosehip tea',
#   u'lemon juice',
#   u'pear liqueur',
#   u'strawberry',
#   u'sugar',
#   u'vodka',
#   u'Vodka'],
#  u'Maple Leaf Recipe': [u'bitters',
#   u'lemon juice',
#   u'Organic maple syrup',
#   u'Purely Syrup Vanilla Bean',
#   u'vanilla bean',
#   u'Bourbon'],
#  u'Beachbum\u2019s Own': [u'lemon juice',
#   u'Licor 43',
#   u'orange juice',
#   u'passion fruit puree',
#   u'pineapple juice',
#   u'Rum'],
#  u'The Rose Garden': [u'egg white',
#   u'fresh lemon juice',
#   u'pineapple juice',
#   u'rose petals',
#   u'rose syrup',
#   u'strawberry',
#   u'Gin'],
#  u'Prospector Cocktail Recipe': [u'amaro',
#   u'Angostura Bitters',
#   u'lemon twist',
#   u'sherry',
#   u'Bourbon'],
#  u'El Tequiletto': [u'amaretto',
#   u'lime',
#   u'mint',
#   u'orange juice',
#   u'Tequila'],
#  u'Holiday Sparkler Wine': [u'cranberry juice',
#   u'elderflower liqueur',
#   u'orange bitters',
#   u'sparkling wine',
#   u'sugar',
#   u'Liqueurs'],
#  u'Grapefruit Hemingway': [u'fresh grapefruit wheel',
#   u'lemon juice',
#   u'lemon simple syrup',
#   u'maraschino liqueur',
#   u'Gin'],
#  u'Woodford Reserve Old Fashioned': [u'Angostura Bitters',
#   u'Demarara Syrup',
#   u"regan's orange bitters no. 6",
#   u'Bourbon'],
#  u'Dieci E Lode': [u'Campari', u'grapefruit juice', u'lime', u'Gin'],
#  u'Hera\u2019s Crown': [u'club soda',
#   u'grenadine',
#   u'lemon juice',
#   u'orange juice',
#   u'orange peel',
#   u'Non-alcoholic'],
#  u'Horse\u2019s Neck': [u'ginger ale', u'lemon peel', u'Bourbon'],
#  u'Ruby Partida': [u'cassis',
#   u'lemon juice',
#   u'orange liqueur',
#   u'ruby red grapefruit juice',
#   u'Tequila'],
#  u'Tom Collins': [u'cherry',
#   u'club soda',
#   u'lemon',
#   u'lemon juice',
#   u'simple syrup',
#   u'Gin'],
#  u'Pom Blanco': [u'lime',
#   u'lime juice',
#   u'pomegranate juice',
#   u'simple syrup',
#   u'Tequila'],
#  u'VeeV Holiday Cider': [u'apple cider',
#   u'cinnamon stick',
#   u'orange',
#   u'VeeV',
#   u'Liqueurs'],
#  u'Pumpkin Toddy': [u'Angostura Bitters',
#   u'boiling water',
#   u'lemon juice',
#   u'maple syrup',
#   u'pumpkin puree',
#   u'Bourbon'],
#  u'Cream of the Crop Recipe': [u'Coconut-pistachio puree*',
#   u'Del Maguey Vida Mezcal',
#   u'fresh lemon juice',
#   u'King\u2019s Ginger',
#   u'Mezcal'],
#  u'French 75': [u'Champagne',
#   u'lemon juice',
#   u'lemon peel',
#   u'simple syrup',
#   u'Brandy'],
#  u'Washington Apple Recipe': [u'apple slice', u'cranberry juice', u'Canadian'],
#  u'Champagne Cocktail': [u'Angostura Bitters',
#   u'Champagne',
#   u'lemon twist',
#   u'sugar cube',
#   u''],
#  u'Campari Margarita': [u'Campari',
#   u'lime juice',
#   u'orange liqueur',
#   u'Liqueurs,'],
#  u'Pisco Punch': [u'cherry',
#   u'lime juice',
#   u'pineapple',
#   u'pineapple juice',
#   u'pisco',
#   u'simple syrup',
#   u'Pisco'],
#  u'Rose-Colored Glass': [u'Angostura Bitters',
#   u'lemon juice',
#   u'lemon twist',
#   u'rose petal',
#   u'simple syrup',
#   u'sparkling wine',
#   u''],
#  u'Ten Aviation': [u'cr\xe8me de violette',
#   u'lemon juice',
#   u'lemon twist',
#   u'maraschino cherry',
#   u'maraschino liqueur',
#   u'Gin'],
#  u'Chocolate Cheer': [u'agave nectar',
#   u'chocolate milk',
#   u'cognac',
#   u'nutmeg',
#   u'Tequila'],
#  u'West Side': [u'club soda',
#   u'lemon juice',
#   u'Meyer lemon vodka',
#   u'mint',
#   u'simple syrup',
#   u'Vodka'],
#  u'Duke\u2019s Martini': [u'dry vermouth', u'Gin'],
#  u'Kiwi Kwencher': [u'club soda',
#   u'elderflower liqueur',
#   u'kiwi',
#   u'simple syrup',
#   u'sparkling wine',
#   u'Liqueurs'],
#  u'Warming Zen': [u'cinnamon stick',
#   u'cocoa powder',
#   u'green tea liqueur',
#   u'matcha powder',
#   u'simple syrup',
#   u'steamed milk',
#   u'Irish'],
#  u'Chilcano': [u'Angostura Bitters',
#   u'ginger ale',
#   u'lime',
#   u'lime juice',
#   u'Pisco'],
#  u'Tennessee Two Step': [u'Angostura Bitters',
#   u'Gran Gala',
#   u'lemon juice',
#   u'nutmeg',
#   u'orange peel',
#   u'Punt e Mes',
#   u'seltzer',
#   u'sugar',
#   u'Bourbon'],
#  u'Kentucky Flyer': [u'brandied cherry',
#   u'lemon juice',
#   u'maraschino liqueur',
#   u'mint',
#   u'Bourbon'],
#  u'Hornitos Tequila Toddy': [u'agave syrup',
#   u'cinnamon',
#   u'cloves',
#   u'honey',
#   u'lemon',
#   u'Tequila'],
#  u'The Basil Fizz': [u'Champagne', u'Bourbon'],
#  u'Dubonnet Cocktail': [u'Angostura Bitters', u'Dubonnet Rouge', u'Gin,'],
#  u'Oceanus Cocktail': [u'celery bitters',
#   u'lemon twist',
#   u'olive',
#   u'sherry',
#   u'Gin'],
#  u'Baileys Peppermint Cream': [u'Baileys with a Hint of Mint Chocolate',
#   u'candy cane',
#   u'hot chocolate',
#   u'mint',
#   u'whipped cream',
#   u'Liqueurs'],
#  u'E-Sencha-L': [u'sencha tea', u'Gin'],
#  u'The Mount Gay Black Barrel Manhattan': [u'bitters',
#   u'dry vermouth',
#   u'sweet vermouth',
#   u'Rum'],
#  u'Kahlua Espresso Martini': [u'espresso', u'Kahlua', u'Liqueurs,'],
#  u'Stoli O Main Squeeze': [u'club soda',
#   u'orange',
#   u'orange juice',
#   u'orange liqueur',
#   u'triple sec',
#   u'Vodka'],
#  u'Snake Bit Sprout Recipe': [u'apple cider',
#   u'chamomile buds',
#   u'Fresh lime juice',
#   u'pineapple juice',
#   u'simple syrup',
#   u'Gin'],
#  u'Sparkler': [u'Champagne', u'simple syrup', u'strawberry', u'Tequila'],
#  u'Elyx Pineapple Recipe': [u'Bittermens Tiki Bitters',
#   u'dried pineapple',
#   u'fresh lemon juice',
#   u'granulated sugar',
#   u'milk',
#   u'oloroso sherry',
#   u'pineapple puree',
#   u'rosemary',
#   u'rosemary syrup',
#   u'salt',
#   u'salted caramel syrup',
#   u'vanilla extract',
#   u'Vodka'],
#  u'Las Fresas': [u'lime juice', u'simple syrup', u'strawberry', u'Rum'],
#  u'Forbidden Apple': [u'Angostura Bitters',
#   u'calvados',
#   u'Grand Marnier',
#   u'orange twist',
#   u'Brandy'],
#  u'Louisville Jockey Club Julep': [u'banana',
#   u'cinnamon',
#   u'lemon bitters',
#   u'lemon juice',
#   u'mint',
#   u'nutmeg',
#   u'sugar',
#   u'Bourbon'],
#  u'Start Me Up!': [u'apple cider',
#   u'cranberry juice',
#   u'ginger ale',
#   u'ginger liqueur',
#   u'lemon',
#   u'pomegranate juice',
#   u'Gin'],
#  u'Raspberry-White Peach Puree': [u'', u''],
#  u'Seven and Seven': [u'7UP', u'Bourbon'],
#  u'Bourbon, Vanilla, and Chocolate Milk Shakes': [u'simple chocolate syrup',
#   u'vanilla ice cream',
#   u'whole milk',
#   u'Bourbon'],
#  u'Almond Orgeat': [u'blanched almonds',
#   u'brandy',
#   u'orange flower water',
#   u'sugar',
#   u'water',
#   u'Brandy'],
#  u'Skinny Superfruit Sangria': [u'cranberry juice',
#   u'red wine',
#   u'strawberry',
#   u'VeeV A\xe7ai Spirit',
#   u'Liqueurs'],
#  u'Jalisco Express': [u'agave nectar',
#   u'coffee bean',
#   u'coffee liqueur',
#   u'Tequila'],
#  u'Don Sherry Recipe': [u'orange twist', u'Canadian'],
#  u'Grey Goose Mediterranean Mary': [u'black pepper',
#   u'celery salt',
#   u'cucumber',
#   u'dried basil',
#   u'dried oregano',
#   u'hot sauce',
#   u'lemon',
#   u'lemon juice',
#   u'lime juice',
#   u'olive',
#   u'olive oil',
#   u'olive tapenade',
#   u'salt',
#   u'sherry',
#   u'tomato juice',
#   u'Vodka'],
#  u'Final Judgment': [u'absinthe',
#   u'lime juice',
#   u'Pear puree',
#   u'simple syrup',
#   u'Gin'],
#  u'Passion Potion': [u'basil',
#   u'lime juice',
#   u'passion fruit puree',
#   u'simple syrup',
#   u'Rum'],
#  u'Sin Cyn': [u'Cynar', u'orange twist', u'sweet vermouth', u'Liqueurs,'],
#  u'Yum Kaax Cocktail Recipe': [u'', u'Mezcal'],
#  u'Stone Cold Larceny': [u'apple juice',
#   u'ginger ale',
#   u'ginger beer',
#   u'lemon',
#   u'Bourbon'],
#  u'Enc(rust)ed Nail': [u'Drambuie',
#   u'lemon juice',
#   u'maraschino liqueur',
#   u"Peychaud's Bitters",
#   u'Liqueurs,'],
#  u'Stinger': [u'cr\xe8me de menthe', u'Brandy'],
#  u'Plymouth Duff': [u'Angostura Bitters',
#   u'beer',
#   u'cinnamon',
#   u'lemon juice',
#   u'lemon peel',
#   u'pale ale',
#   u'Sauternes',
#   u'wine',
#   u'Gin'],
#  u'Queen Rose': [u'aperol',
#   u'club soda',
#   u'grapefruit juice',
#   u'honey',
#   u'lemon juice',
#   u'Vodka'],
#  u'The Beatnik': [u'amaro', u'port', u'Bourbon'],
#  u'Peppermelon': [u'black pepper',
#   u'honey',
#   u'lemon juice',
#   u'watermelon',
#   u'watermelon juice',
#   u'Gin'],
#  u"Dewar's Smash": [u'lemon',
#   u'mint leaves',
#   u'seltzer water',
#   u'simple syrup',
#   u'Scotch'],
#  u'D\xe2\u20ac\u2122USS\xc3\u2030 Motown ': [u'lemon juice',
#   u'luxardo amaretto',
#   u'Rothman &amp; Winter Orchard Apricot',
#   u'Brandy'],
#  u'Tippy Cow\xe2\u201e\xa2 Halloween Layered Shooters: Mint Chocolate Moo': [u'',
#   u'Liqueurs'],
#  u'The Paper Plane': [u'Amaro Nonino', u'aperol', u'lemon juice', u'Bourbon'],
#  u'Rocky Manhattan': [u'The Dead Rabbit Orinoco Bitters', u'Bourbon'],
#  u'Louisville Cocktail': [u'Lillet Blanc', u'Lillet Rouge', u'Bourbon'],
#  u'Betsy Ross': [u'Angostura Bitters',
#   u'orange Cura\xe7ao',
#   u'port',
#   u'Brandy'],
#  u'The Mary Mac': [u'cider',
#   u'lemon juice',
#   u"Pimm's No. 1",
#   u'simple syrup',
#   u'vermouth',
#   u'Vodka'],
#  u'\u201cNick &amp; Nora\u201d Dry Martini': [u'dry vermouth',
#   u'olive',
#   u'Gin,'],
#  u'Spicy Negroni': [u'Ancho Chile Liqueur',
#   u'Bittermen\u2019s Mol\xe9 Bitters',
#   u'Campari',
#   u'Pierde Almas +9 Mezcal-Gin',
#   u'sweet vermouth',
#   u'Gin,'],
#  u'Tequila Furnace': [u'lime', u'salt', u'Tabasco Sauce', u'Tequila'],
#  u'Falken\u2019s Maze': [u'Creme Yvette',
#   u'lime juice',
#   u'orange bitters',
#   u'vanilla syrup',
#   u'Vodka'],
#  u'Set the New Year on Fire ': [u'Campari',
#   u'lime juice',
#   u'mint',
#   u'rum',
#   u'simple syrup',
#   u'sugar cane syrup',
#   u'sugar cube',
#   u'Scotch'],
#  u'The Zapatero': [u'Angostura Bitters',
#   u'chocolate bitters',
#   u'cinnamon',
#   u'cocktail cranberry',
#   u'orange twist',
#   u'orgeat',
#   u'Bourbon'],
#  u'The Grey Goose Martini': [u'dry vermouth', u'orange bitters', u'Vodka'],
#  u'Alma Blanca Cocktail Recipe': [u'', u'Tequila'],
#  u'VeeV Marguerite': [u'grenadine',
#   u'lemon',
#   u'lemon juice',
#   u'maraschino liqueur',
#   u'orange juice',
#   u'raspberry syrup',
#   u'Liqueurs'],
#  u'The Ultimat Blueberry Freeze': [u'blueberry juice',
#   u'orange juice',
#   u'orange liqueur',
#   u'watermelon',
#   u'Vodka'],
#  u'Desert Pear Mojito': [u'Lemon-lime soda',
#   u'lime',
#   u'mint',
#   u'pear syrup',
#   u'Rum'],
#  u'Plymouth Harvest Margherita': [u'balsamic vinegar',
#   u'basil',
#   u'black peppercorn',
#   u'club soda',
#   u'lemon juice',
#   u'sugar',
#   u'tomato',
#   u'Gin'],
#  u'Jorge Vargas Baquedano\u2019s Manhattan': [u'Angostura Bitters',
#   u"regan's orange bitters no. 6",
#   u'vermouth',
#   u'Bourbon'],
#  u'The Jalisco Jasmine': [u'bitter aperitif',
#   u'lemon juice',
#   u'lemon twist',
#   u'orange liqueur',
#   u'Tequila'],
#  u'Black Russian': [u'Kahlua', u'Vodka'],
#  u'Taylored Black Russian - Cocktail Recipe': [u'Hershey\u2019s chocolate syrup',
#   u'Kahlua',
#   u'Vodka'],
#  u'Last-Minute Mulled Wine': [u'cinnamon stick',
#   u'lemon peel',
#   u'orange peel',
#   u'star anise',
#   u'sugar',
#   u'wine',
#   u'Bourbon'],
#  u'Summerlin': [u'black pepper',
#   u'lemon juice',
#   u'orchid',
#   u'simple syrup',
#   u'watermelon',
#   u'Rum'],
#  u'Sin Nombre Recipe': [u'aloe vera juice',
#   u'fresh lemon juice',
#   u'lemon twist',
#   u'maraschino liqueur',
#   u'orange bitters',
#   u'orange twist',
#   u"Peychaud's Bitters",
#   u'pomegranate juice',
#   u'Tequila'],
#  u'Pi\xf1ata': [u'pineapple', u'pineapple juice', u'Tequila'],
#  u'Paloma Jimador': [u'grapefruit soda', u'lime juice', u'salt', u'Tequila'],
#  u'Pear Tree Martini': [u'Angostura Bitters',
#   u'elderflower liqueur',
#   u'lime juice',
#   u'pear',
#   u'Vodka'],
#  u'Coffee Cocktail': [u'egg', u'nutmeg', u'port', u'simple syrup', u'Brandy'],
#  u'Hobnail Recipe': [u'bitters',
#   u'ginger syrup',
#   u'lemon juice',
#   u'orange peel',
#   u'Scotch'],
#  u'Lincoln Club Cooler ': [u'ginger ale', u'Rum'],
#  u'The Count of \u017bubr\xf3wka': [u'Amaro Montenegro',
#   u'apple cider',
#   u'lemon juice',
#   u'Vodka'],
#  u'Corpse Reviver No. 2': [u'absinthe',
#   u'lemon juice',
#   u'Lillet Blanc',
#   u'orange liqueur',
#   u'Absinthe,'],
#  u'The Bowery': [u'Angostura Bitters',
#   u'ginger liqueur',
#   u'lemon juice',
#   u'lemon twist',
#   u'Liqueurs'],
#  u'Gentleman\u2019s Press': [u'ginger beer', u'lime', u'Bourbon'],
#  u'Hanky Panky': [u'Fernet-Branca',
#   u'orange twist',
#   u'sweet vermouth',
#   u'Gin'],
#  u'The Complete Irish Meal': [u'cherry liqueur',
#   u'egg',
#   u'orange juice',
#   u'Irish'],
#  u'East Indian Negroni': [u'', u'Rum'],
#  u'Rusty Apple Toddy': [u'apple juice',
#   u'cinnamon stick',
#   u'lemon',
#   u'Liqueurs'],
#  u'Presbyterian': [u'club soda', u'ginger ale', u'Bourbon'],
#  u'New Orleans: #RAD': [u'absinthe',
#   u'lemon juice',
#   u'sparkling ros\xe9 wine',
#   u'strawberry puree',
#   u'Brandy'],
#  u'Strawberry Pisco Sour': [u'egg white',
#   u'lime juice',
#   u'strawberry-rose syrup',
#   u'Pisco'],
#  u'Savory Eyeballs': [u'cocktail onions', u'olive', u'red food dye', u''],
#  u'Call it a Night': [u'absinthe',
#   u'averna',
#   u'oloroso sherry',
#   u'vermouth',
#   u'Bourbon'],
#  u'Daniel Shoemaker\u2019s Brandied Cherries': [u'allspice berries',
#   u'cherries',
#   u'cinnamon sticks',
#   u'juniper berries',
#   u'lemon juice',
#   u'star anise',
#   u'sugar',
#   u'water',
#   u'Brandy'],
#  u'The Green Beast': [u'cucumber',
#   u'lime juice',
#   u'simple syrup',
#   u'Absinthe'],
#  u'Persephone\u2019s Elixir': [u'ginger beer',
#   u'lemon juice',
#   u'pomegranate liqueur',
#   u'Liqueurs,'],
#  u'Spring\u2019s First Bloom': [u'egg white',
#   u'elderflower liqueur',
#   u'lavender bitters',
#   u'lemon juice',
#   u'lemongrass',
#   u'mint',
#   u'sugar',
#   u'Gin'],
#  u'An Bodhran (The Drum)': [u'egg',
#   u'maple sugar',
#   u'mint bitters',
#   u'port',
#   u'Irish'],
#  u'Smuggler\u2019s Cove Straits Sling': [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'cherry liqueur',
#   u'club soda',
#   u'Demerara sugar',
#   u'lemon',
#   u'lemon juice',
#   u'orange bitters',
#   u'Gin'],
#  u'Absolut Mango Spice': [u'agave nectar',
#   u'jalape\xf1o',
#   u'lime juice',
#   u'mango nectar',
#   u'orange bitters',
#   u'Vodka'],
#  u'Paloma Recipe': [u'grapefruit soda', u'lime juice', u'sale', u'Tequila'],
#  u'Precision Timepiece Recipe': [u"Dale DeGroff's Pimento Bitters",
#   u'orange peel',
#   u'Liqueurs'],
#  u'Corzo Tequila Snow White': [u'coffee liqueur',
#   u'heavy cream',
#   u'vanilla cognac',
#   u'Tequila'],
#  u'Grand Cosmo': [u'cranberry juice',
#   u'lime juice',
#   u'lime wheel',
#   u'orange liqueur',
#   u'Vodka'],
#  u'Tegroni': [u'Campari', u'grapefruit twist', u'sweet vermouth', u'Tequila'],
#  u'Ginger Smash': [u'apple cider',
#   u'cranberries',
#   u'gingerroot',
#   u'lemon juice',
#   u'Gin'],
#  u'More Cowbell Recipe': [u'aperol',
#   u'cardamaro amaro',
#   u'gum syrup',
#   u'lemon juice',
#   u'lemon peel',
#   u'Gin'],
#  u'Dirty Oaxacan Martini': [u'dry vermouth',
#   u'Kalamata olive',
#   u'olive juice',
#   u'Mezcal'],
#  u'Super Sunday Punch Bowl of Freedom': [u'allspice',
#   u'apple',
#   u'cinnamon',
#   u'cloves',
#   u'honey',
#   u'ruby red grapefruit juice',
#   u'sweet tea',
#   u'Bourbon'],
#  u'Sparkling A\xe7a\xed Sangria': [u'blueberry',
#   u'elderflower liqueur',
#   u'orange',
#   u'orange juice',
#   u'sparkling wine',
#   u'strawberry',
#   u'VeeV',
#   u'Liqueurs'],
#  u'Final Indulgence': [u'cr\xe8me de cacao',
#   u'fig syrup',
#   u'port',
#   u'vanilla bitters',
#   u'Bourbon'],
#  u'The Bow Tie': [u'dry vermouth',
#   u'pineapple juice',
#   u'pineapple leaf',
#   u'Brandy'],
#  u'The Original Sazerac': [u'absinthe',
#   u'lemon twist',
#   u"Peychaud's Bitters",
#   u'simple syrup',
#   u'Absinthe,'],
#  u'Spring 2014': [u'absinthe',
#   u'aquavit',
#   u'lemon-thyme syrup',
#   u'lime juice',
#   u'maldon salt',
#   u'manzanilla sherry',
#   u'sea salt',
#   u'sugar snap peas',
#   u'verjus',
#   u'Liqueurs,'],
#  u'The Lanesborough': [u'Champagne',
#   u'cranberry juice',
#   u'orange liqueur',
#   u'orange twist',
#   u'passion fruit juice',
#   u'passion fruit puree',
#   u'Liqueurs'],
#  u'Royal Balmoral Punch': [u'apple juice',
#   u'Champagne',
#   u'lemon',
#   u'lemonade',
#   u'sugar',
#   u'tea',
#   u'thistle',
#   u'Scotch'],
#  u'Montgomerie Smoked Cider Recipe': [u'apple cider',
#   u'fresh lemon juice',
#   u'lemon wedge',
#   u'Scotch'],
#  u'Banana Nut Bay': [u'cream of coconut',
#   u'cr\xe8me de banane',
#   u'peanut rum cr\xe8me liqueur',
#   u'pineapple',
#   u'pineapple juice',
#   u'Rum'],
#  u'Golden Dream': [u'cream',
#   u'Galliano',
#   u'orange juice',
#   u'orange liqueur',
#   u'Liqueurs'],
#  u'Elderflower Fizz': [u'agave nectar',
#   u'elderflower liqueur',
#   u'lime juice',
#   u'sparkling wine',
#   u'thyme',
#   u'Vodka'],
#  u'Naughty or Nice': [u'blood orange',
#   u'ginger ale',
#   u'maraschino liqueur',
#   u'wine',
#   u'Brandy'],
#  u'The Royal Crest': [u'club soda',
#   u'grape',
#   u'simple syrup',
#   u'wine',
#   u'Brandy'],
#  u'Vanilla Bourbon': [u'brandied cherry',
#   u'club soda',
#   u'tamarind syrup',
#   u'vanilla liqueur',
#   u'Bourbon'],
#  u'Black &amp; Ginger': [u'Angostura Bitters', u'ginger ale', u'Rum'],
#  u'Revive Lemonade ': [u'agave nectar',
#   u'coconut water',
#   u'ginger',
#   u'lemon juice',
#   u''],
#  u'Hot Caramel Buttered Rum': [u'brown sugar',
#   u'butter',
#   u'caramel vodka',
# ...
#   u'Canadian whisky',
#   u'dry vermouth',
#   u'orange',
#   u'orange bitters',
#   u'simple syrup',
#   u'sweet vermouth',
#   u'Absinthe,'],
#  u'Coal Miner\u2019s Daughter': [u'ginger liqueur',
#   u'honey',
#   u'lavender',
#   u'lemon juice',
#   u'Bourbon'],
#  u'Hopped-Up Bloody Mary': [u"Demitri's Bloody Mary Seasoning",
#   u'fennel',
#   u'lemon',
#   u'lemon juice',
#   u'pink peppercorn',
#   u'sea salt',
#   u'shrimp',
#   u'tomato juice',
#   u'Vodka'],
#  u'Wilson\u2019s Smash': [u'absinthe',
#   u'Angostura Bitters',
#   u'butter',
#   u'club',
#   u'lemon',
#   u'lime juice',
#   u'mint',
#   u'pineapple',
#   u'pineapple juice',
#   u'soda',
#   u'sugar',
#   u'Rum'],
#  u'Alabama Slammer': [u'amaretto',
#   u'cherry',
#   u'orange',
#   u'orange juice',
#   u'sloe gin',
#   u'Southern Comfort',
#   u'Liqueurs'],
#  u'Sea Breeze': [u'cranberry juice', u'grapefruit juice', u'lime', u'Vodka'],
#  u'Classic Rum-Brandy Punch': [u'armagnac',
#   u'lemon',
#   u'lemon juice',
#   u'nutmeg',
#   u'Brandy'],
#  u'NOLET\u2019S Mango Crush': [u'fee brothers rhubarb bitters',
#   u'fresh lemon juice',
#   u'fresh mango puree',
#   u'simple syrup',
#   u'Gin'],
#  u'NOLET\u2019S Silver Dutch Mule': [u'ginger beer',
#   u'grapefruit',
#   u'mint',
#   u'Gin'],
#  u'Stoli Bloody Mary': [u'celery',
#   u'horseradish',
#   u'hot sauce',
#   u'lemon juice',
#   u'olive',
#   u'pepper',
#   u'salt',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Vodka'],
#  u'Spiced Chocolate': [u'chocolate liqueur',
#   u'coffee liqueur',
#   u'crushed red pepper',
#   u'whipped cream',
#   u'Liqueurs,'],
#  u'Organic Moscow Mule': [u'ginger beer', u'lime', u'lime juice', u'Vodka'],
#  u'Polar Bear': [u'cr\xe8me de menthe',
#   u'dried angelica root',
#   u'dry vermouth',
#   u'Everclear',
#   u'Mezcal'],
#  u'Cherry Collins': [u'cherry vodka',
#   u'club soda',
#   u'lemon juice',
#   u'simple syrup',
#   u'Vodka'],
#  u'Negroni': [u'Campari', u'orange', u'sweet vermouth', u'Gin,'],
#  u'Harvey Wallbanger': [u'Galliano', u'orange', u'orange juice', u'Vodka'],
#  u'Princess Mary\u2019s Pride': [u'apple brandy',
#   u'calvados',
#   u'dry vermouth',
#   u'Dubonnet Rouge',
#   u'orange peel',
#   u'Brandy'],
#  u'The Swindle': [u'Angostura Bitters',
#   u'lemon juice',
#   u"Peychaud's Bitters",
#   u'simple syrup',
#   u'Bourbon'],
#  u'Albari\xf1o Mint Julep': [u'mint', u'peach liqueur', u'wine', u'Liqueurs'],
#  u'Caipirinha': [u'lime', u'sugar', u'Cacha\xe7a'],
#  u'Side by Sidecar': [u'lemon juice',
#   u'orange liqueur',
#   u'pomegranate liqueur',
#   u'sugar',
#   u'triple sec',
#   u'Brandy'],
#  u'The Van Leer Rose': [u'fresh lemon juice',
#   u'grenadine',
#   u'lemon juice',
#   u'Bourbon'],
#  u'Sparkling Holiday Punch': [u'fig',
#   u'lemon',
#   u'lemon juice',
#   u'orange peel',
#   u'sparkling wine',
#   u'sugar',
#   u'tea',
#   u'Vodka'],
#  u'Minted Man': [u'cucumber',
#   u'lime juice',
#   u'mint',
#   u'simple syrup',
#   u'Vodka'],
#  u'Jack-o-Lantern Punch': [u'apple',
#   u'apple juice',
#   u'cinnamon sticks',
#   u'cloves',
#   u'club soda',
#   u'lemon juice',
#   u'nutmeg',
#   u'pumpkin seeds',
#   u'sugar',
#   u'Rum'],
#  u'Vesper': [u'lemon peel', u'Lillet Blanc', u'Gin,'],
#  u'Grand Mimosa': [u'Champagne',
#   u'orange juice',
#   u'orange liqueur',
#   u'strawberry',
#   u'Liqueurs'],
#  u'RumChata Martini': [u'vanilla vodka', u'Liqueurs,'],
#  u'Isaiah Rynders Cocktail Recipe': [u'cardamaro',
#   u'Fresh lime juice',
#   u'ginger syrup',
#   u'nutmeg',
#   u'orinoco bitters',
#   u'tamarind chutney',
#   u'vanilla soda',
#   u'Irish'],
#  u'Absolut Boston Home Run': [u'ginger ale', u'white grape juice', u'Vodka'],
#  u'Medicinal Courage': [u'Amaro Nonino',
#   u'Angostura Bitters',
#   u'bitters',
#   u'honey',
#   u'lemon juice',
#   u'rosemary',
#   u'star anise',
#   u'Gin'],
#  u'Holiday at the Hive': [u'honey',
#   u'lemon juice',
#   u'orange juice',
#   u'star anise powder',
#   u'triple sec',
#   u'water',
#   u'Vodka'],
#  u'Back Yard Tea': [u'iced tea', u'lemon', u'lemonade', u'spiced rum', u'Rum'],
#  u'The Purple One Recipe': [u'fermented concord grape soda',
#   u'lime juice',
#   u'simple syrup',
#   u'vermouth',
#   u'Gin'],
#  u'The Coco Chanel Martini Recipe': [u'', u'Vodka'],
#  u'Apples &amp; Pears': [u'Angostura Bitters',
#   u'apple',
#   u'hard cider',
#   u'lime juice',
#   u'nutmeg',
#   u'pear juice',
#   u'sugar',
#   u'vanilla bean',
#   u'Vodka'],
#  u'Gin &amp; Juice': [u'grapefruit juice', u'orange juice', u'Gin'],
#  u'Finlandia Vodka Wild Berritini': [u'berries',
#   u'club soda',
#   u'raspberry liqueur',
#   u'Vodka'],
#  u'Old Oaxacan': [u'Angostura Bitters',
#   u'Champagne',
#   u'lime',
#   u'lime juice',
#   u'mint',
#   u'simple syrup',
#   u'Mezcal'],
#  u'The American Poet Cocktail Recipe': [u'absinthe',
#   u'lemon twist',
#   u'rhubarb amaro',
#   u'sweet vermouth',
#   u'Rye'],
#  u'Finlandia Vodka Midnight Sun Martini': [u'cherry',
#   u'cranberry juice',
#   u'orange liqueur',
#   u'triple sec',
#   u'Vodka'],
#  u'Between The Sheets': [u'lemon juice',
#   u'orange peel',
#   u'triple sec',
#   u'Brandy'],
#  u'Pegu Club': [u'Angostura Bitters',
#   u'lime juice',
#   u'orange bitters',
#   u'orange Cura\xe7ao',
#   u'Gin'],
#  u'Planet Hoth Toddy Recipe': [u'egg white',
#   u'lime juice',
#   u'maraschino liqueur',
#   u'nutmeg',
#   u'simple syrup',
#   u'Rum'],
#  u'Surf and Sand': [u'Angostura Bitters',
#   u'cherry bitters',
#   u'Cherry Heering',
#   u'orange juice',
#   u'sweet vermouth',
#   u'Brandy'],
#  u'Pils Al Pastor Recipe': [u'La Boite 37 Spice and Salt Blend',
#   u'lime juice',
#   u'Pok Pok Pineapple Drinking Vinegar',
#   u'Beer,'],
#  u'VEEV Basil Gimlet': [u'basil', u'lime juice', u'simple syrup', u'Liqueurs'],
#  u'Cucumber, Basil &amp; Lime Gimlet': [u'basil',
#   u'cucumber',
#   u'lemonade',
#   u'lime',
#   u'lime juice',
#   u'Vodka'],
#  u'Knob Creek Old Fashioned': [u'bitters',
#   u'lemon peel',
#   u'simple syrup',
#   u'Bourbon'],
#  u'English Rose': [u'bitters',
#   u'dry vermouth',
#   u'egg white',
#   u'lemon juice',
#   u'rhubarb',
#   u'sugar',
#   u'Gin'],
#  u'Jubilee Recipe': [u'lemon juice',
#   u'maple syrup',
#   u'nutmeg',
#   u'pear fan',
#   u'seltzer',
#   u'spiced pear liqueur',
#   u'Vodka'],
#  u'Greenhouse ': [u'dry vermouth',
#   u'Green Chartreuse',
#   u'lime juice',
#   u'mint leaves',
#   u'Pea Shrub',
#   u'Tequila'],
#  u'Strawberry &amp; Ginger Bellini': [u'ginger juice',
#   u'prosecco',
#   u'strawberry',
#   u''],
#  u'Gentleman Bowery': [u'lemon',
#   u'lemon juice',
#   u'orange juice',
#   u'pom wonderful',
#   u'pomegranate juice',
#   u'Bourbon'],
#  u'Garibaldi Cocktail': [u'amaro',
#   u'lime juice',
#   u'mineral water',
#   u'orange bitters',
#   u'orange peel',
#   u'velvet falernum',
#   u'Liqueurs,'],
#  u'Smoky Martini': [u'lemon twist', u'Gin,'],
#  u'Italian Grape Sour': [u'amaretto',
#   u'grape',
#   u'lemon',
#   u'lemon juice',
#   u'white grape juice',
#   u'Vodka'],
#  u'Frosty Mule': [u'club soda',
#   u'ginger simple syrup',
#   u'lemon juice',
#   u'Yellow Chartreuse',
#   u'Vodka'],
#  u'Treme': [u'Hibiscus iced tea', u'mint', u'passion fruit iced tea', u'Rum'],
#  u'Basil Hayden\u2019s Kentucky Buck': [u'cranberry juice',
#   u'lemon',
#   u'orange juice',
#   u'simple syrup',
#   u'triple sec',
#   u'Bourbon'],
#  u'Sidra House': [u'allspice liqueur',
#   u'apple',
#   u'apple cider',
#   u'pear brandy',
#   u'sherry',
#   u'Rum'],
#  u'The Lone Ranger': [u'lemon juice',
#   u'ros\xe9 sparkling wine',
#   u'simple syrup',
#   u'Tequila'],
#  u'The Improved Holland Gin Cock-Tail': [u'absinthe',
#   u'Angostura Bitters',
#   u'lemon peel',
#   u'orange liqueur',
#   u'simple syrup',
#   u'Gin'],
#  u'Schlitzie Recipe': [u'brandied cherries',
#   u'grenadine',
#   u'lemon juice',
#   u'sherry',
#   u'Tequila'],
#  u'Don Julio\u2019s Bloody Maria': [u'black pepper',
#   u'celery salt',
#   u'horseradish',
#   u'lemon',
#   u'lime juice',
#   u'Tabasco Sauce',
#   u'tomato',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Tequila'],
#  u'Midnight Smash': [u'amaro',
#   u'blackberry',
#   u'ginger beer',
#   u'Meyer lemon',
#   u'Liqueurs,'],
#  u'Paddington': [u'absinthe',
#   u'grapefruit juice',
#   u'grapefruit twise',
#   u'lemon juice',
#   u'Lillet Blanc',
#   u'orange marmalade',
#   u'Absinthe,'],
#  u'Absolut Boston Mojito': [u'club soda',
#   u'lime juice',
#   u'mint',
#   u'simple syrup',
#   u'Vodka'],
#  u'Sangrita': [u'black pepper',
#   u'grapefruit juice',
#   u'hot sauce',
#   u'jalape\xf1o',
#   u'lime juice',
#   u'orange juice',
#   u'salt',
#   u'Tabasco Sauce',
#   u'tomato juice',
#   u'Tequila'],
#  u'Iz Bananaz': [u'amaro',
#   u'Amaro Montenegro',
#   u'Giffard Banane du Br\xe9sil Liqueur',
#   u'Hella Bitter Aromatic bitters',
#   u'lemon juice',
#   u'orange twist',
#   u'Cacha\xe7a'],
#  u'Queen Elizabeth': [u'B\xe9n\xe9dictine',
#   u'dry vermouth',
#   u'lime juice',
#   u'Liqueurs,'],
#  u'Adult Marshmallows': [u'corn syrup',
#   u'cr\xe8me de violette',
#   u'gelatin',
#   u'ginger liqueur',
#   u'orange liqueur',
#   u'sugar',
#   u'Liqueurs'],
#  u'Woodford Reserve Neat': [u'', u'Bourbon'],
#  u'Montauk': [u'dry vermouth', u'sweet vermouth', u'Gin'],
#  u'The Watchman': [u'Angostura Bitters',
#   u'egg white',
#   u'lemon juice',
#   u'orange juice',
#   u'simple syrup',
#   u'Bourbon'],
#  u'Lavender Honey Cream': [u'egg white',
#   u'heavy cream',
#   u'honey',
#   u'lavender blossom',
#   u'Square One Botanical Spirit',
#   u'Vodka'],
#  u'Suey\u2019s Sangrita': [u'Cholula hot sauce',
#   u'grapefruit juice',
#   u'jalape\xf1o',
#   u'lime juice',
#   u'orange juice',
#   u'Pinch Smoked paprika',
#   u'Pinch White pepper',
#   u'salt',
#   u'Tabasco hot sauce',
#   u'tomato juice',
#   u'Non-alcoholic'],
#  u'Allison Widdecombe\u2019s Manhattan': [u'Angostura Bitters',
#   u'carpano vermouth',
#   u'dry vermouth',
#   u'Bourbon'],
#  u'Bowery Orchard': [u'apple',
#   u'apple juice',
#   u'bitters',
#   u'elderflower cordial',
#   u'lemon juice',
#   u'simple syrup',
#   u'Bourbon'],
#  u'Kiss': [u'apple',
#   u'Dubonnet Rouge',
#   u'maraschino liqueur',
#   u'sweet vermouth',
#   u'Gin,'],
#  u'The Bacchus Recipe': [u'blackberries',
#   u'concord grapes',
#   u'egg white',
#   u'lemon juice',
#   u'Liqueurs,'],
#  u'Celebrity Crush': [u'grapefruit juice',
#   u'lemon juice',
#   u'Pamplemousse Rose Liqueur',
#   u'Vodka'],
#  u'Safe Kicker': [u'apricot preserves',
#   u'bitters',
#   u'cara cara orange juice',
#   u'cara cara orange twist',
#   u'cherry',
#   u'egg white',
#   u'Fee Brothers Whiskey Barrel Aged Bitters',
#   u'lemon juice',
#   u'oloroso sherry',
#   u'orange juice',
#   u'orange twist',
#   u'Bourbon'],
#  u'New York Sour': [u'egg white',
#   u'lemon juice',
#   u'red wine',
#   u'simple syrup',
#   u'Rye'],
#  u'The Cappa': [u'lemon peel',
#   u'maraschino liqueur',
#   u'pineau des charentes',
#   u'Gin'],
#  u'Ryan Puckett\u2019s Manhattan': [u'Angostura Bitters',
#   u'Punt e Mes',
#   u'vermouth',
#   u'Bourbon'],
#  u'Peppermint Pattie': [u'chocolate liqueur',
#   u'cream',
#   u'cr\xe8me de menthe',
#   u'Peppermint Pattie',
#   u'Vodka'],
#  u'Oh Gosh': [u'lemon twist',
#   u'lime juice',
#   u'simple syrup',
#   u'triple sec',
#   u'Rum'],
#  u'Virgin Ad Lib': [u'cilantro',
#   u'lemon juice',
#   u'simple syrup',
#   u'Non-alcoholic'],
#  u'Honey Deuce': [u'Chambord',
#   u'honeydew',
#   u'lemonade',
#   u'raspberry liqueur',
#   u'Vodka'],
#  u'Hey Bulldog!': [u'7UP',
#   u'peppermint schnapps',
#   u'raspberry liqueur',
#   u'Gin'],
#  u'Patr\xf3n Pomegranate': [u'lime',
#   u'orange liqueur',
#   u'pomegranate juice',
#   u'Tequila'],
#  u'House of Payne': [u'Campari', u'raspberries', u'sloe gin', u'Gin'],
#  u'Trilby Recipe': [u'dry vermouth',
#   u'lemon twist',
#   u'orange bitters',
#   u'Gin'],
#  u'Nueva Playa del Sur': [u'agave nectar',
#   u'blood orange',
#   u'Champagne',
#   u'orange twist',
#   u'Rum'],
#  u'The Goldwyn Follies': [u'apple',
#   u'apple juice',
#   u'cinnamon',
#   u'cranberry juice',
#   u'sugar',
#   u'tea',
#   u'Gin'],
#  u'Royal Smash': [u'lemon', u'mint', u'orange liqueur', u'Liqueurs'],
#  u'Marguerite': [u'dry vermouth',
#   u'lemon peel',
#   u'olive',
#   u'orange bitters',
#   u'Gin,'],
#  u'First Frost Recipe': [u'blanc vermouth',
#   u'cardamom bitters',
#   u'concord grapes',
#   u'vermont maple syrup',
#   u'Brandy'],
#  u'Irish Old Fashioned Cocktail Recipe': [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'orange bitters',
#   u'orange slice',
#   u'Irish'],
#  u'Pear &amp; Elderflower Collins': [u'club soda',
#   u'honey syrup',
#   u'lemon juice',
#   u'pear liqueur',
#   u'Pear puree',
#   u'Gin,'],
#  u'The Kilbeggan Secret Sour': [u'club soda',
#   u'dry vermouth',
#   u'grapefruit juice',
#   u'lemon juice',
#   u'lemon twist',
#   u'orange bitters',
#   u'simple syrup',
#   u'Irish'],
#  u'Tropical Sunset': [u'grenadine',
#   u'pineapple',
#   u'pineapple juice',
#   u'Vodka'],
#  u'Antiguo Citrus Mint Squeeze': [u'agave nectar',
#   u'club soda',
#   u'grapefruit',
#   u'lime',
#   u'mint',
#   u'Tequila'],
#  u'La Estrella': [u'cayenne pepper',
#   u'club soda',
#   u'lime juice',
#   u'pineapple',
#   u'strawberry',
#   u'sugar',
#   u'watermelon',
#   u'Rum'],
#  u'Summer Martini': [u'blackberry', u'dry vermouth', u'raspberry', u'Gin'],
#  u'Agave Ginger-Rita': [u'egg white',
#   u'ginger',
#   u'lime juice',
#   u'orange liqueur',
#   u'salt',
#   u'sugar',
#   u'Tequila'],
#  u'Rock Your Face Off Hot Toddy': [u'Fee Brothers Whiskey Barrel Aged Bitters',
#   u'fresh lemon juice',
#   u'honey syrup',
#   u'lemon wheel',
#   u'Rye'],
#  u'Mint Simple Syrup': [u'mint', u'sugar', u'water', u'Non-alcoholic'],
#  u'The Modern Cocktail': [u'absinthe',
#   u'lemon juice',
#   u'maraschino cherry',
#   u'orange bitters',
#   u'sloe gin',
#   u'sugar',
#   u'Absinthe,'],
#  u'Psycho Killer Cocktail Recipe': [u'absinthe',
#   u'Campari',
#   u'cocoa nibs',
#   u'Giffard Banane du Br\xe9sil',
#   u'white cocoa marie brizard',
#   u'Irish'],
#  u'Herradura Tequila Luxe': [u'agave nectar', u'lemon', u'lime', u'Tequila'],
#  u'No. 3 Gimlet': [u'agave nectar', u'lime', u'lime juice', u'Gin'],
#  u'Little Engine': [u'apple butter',
#   u'lemon juice',
#   u'maple syrup',
#   u'port',
#   u'Scotch'],
#  u'Stranger in the Alps Recipe': [u'bitters',
#   u'Campari',
#   u'carpano antica',
#   u'lemon pigtail',
#   u'salt',
#   u'Gin'],
#  u'Autumn Rickey': [u'club soda',
#   u'lime',
#   u'lime juice',
#   u'maple syrup',
#   u'Bourbon'],
#  u'Sidecar': [u'lemon juice',
#   u'orange liqueur',
#   u'orange peel',
#   u'sugar',
#   u'Brandy'],
#  u'Thistle Recipe': [u'bitters',
#   u'calvados',
#   u'lemon juice',
#   u'rye whiskey',
#   u'sherry',
#   u'Liqueurs'],
#  u'Not So Innocent': [u'Angostura Bitters',
#   u'apple cider',
#   u'lemon juice',
#   u'maple syrup',
#   u'Rum'],
#  u'The Mount Gay Old Fashioned': [u'Angostura Bitters',
#   u'orange peel',
#   u'sugar',
#   u'Rum'],
#  u'French 75 Recipe': [u'Champagne',
#   u'fresh lemon juice',
#   u'simple syrup',
#   u'Gin'],
#  u'Mike Mills Manhattan': [u'coffee bitters',
#   u'dry curacao',
#   u'vermouth',
#   u'Bourbon'],
#  u'Caribe\xf1o': [u'coconut water',
#   u'lime',
#   u'lime juice',
#   u'simple syrup',
#   u'Rum'],
#  u'Pear &amp; Cranberry Fizz': [u'bitters',
#   u'cranberry',
#   u'cranberry bitters',
#   u'cranberry juice',
#   u'lemon juice',
#   u'pear',
#   u'pear liqueur',
#   u'Vodka'],
#  u'Emerald Isle of the Caribbean': [u'Angostura Bitters',
#   u"B.G Reynolds Don's Spices #2",
#   u'brewed coffee',
#   u'cinnamon',
#   u'Demerara sugar',
#   u'heavy cream',
#   u'St. Elizabeth Allspice Dram',
#   u'sugar',
#   u'velvet falernum',
#   u'Rum'],
#  u'The Dead Rabbit Irish Coffee': [u'coffee',
#   u'Demerara sugar',
#   u'heavy cream',
#   u'Irish'],
#  u'Greyhound': [u'aperol', u'bitters', u'grapefruit', u''],
#  u'Roasted Poblano-Infused Tequila': [u'', u''],
#  u'Forbidden Fruit': [u'Angostura Bitters',
#   u'apple brandy',
#   u'ginger beer',
#   u'lemon',
#   u'lemon juice',
#   u"Peychaud's Bitters",
#   u"Pimm's No. 1",
#   u'simple syrup',
#   u'Brandy'],
#  u'The Orkney Chapel': [u'dry vermouth',
#   u'orange liqueur',
#   u'orange peel',
#   u'sherry',
#   u'sugar cane syrup',
#   u'Scotch,'],
#  u'Boston Rum Punch': [u'Demerara sugar',
#   u'lemon juice',
#   u'lemon peel',
#   u'lemonade',
#   u'Rum'],
#  u'Eden\u2019s Apple': [u'apple',
#   u'apple cider',
#   u'baked apple bitters',
#   u'bitters',
#   u'cinnamon',
#   u'lemon juice',
#   u'velvet falernum',
#   u'Vodka'],
#  u'Scofflaw': [u'dry vermouth',
#   u'grenadine',
#   u'lemon juice',
#   u'orange bitters',
#   u'Bourbon'],
#  u'A\xe7a\xed Lemonade': [u'cranberry juice',
#   u'lemon',
#   u'lemonade',
#   u'VeeV A\xe7ai Spirit',
#   u'Liqueurs'],
#  u'Traditional Mai Tai': [u'almond orgeat',
#   u'lime',
#   u'lime juice',
#   u'mint',
#   u'orange liqueur',
#   u'simple syrup',
#   u'Rum'],
#  u'Hakushu Highball Cocktail Recipe': [u'', u'Japanese'],
#  u'NOLET\u2019S Silver Clover Club': [u'egg white',
#   u'lemon juice',
#   u'raspberry simple syrup',
#   u'Gin'],
#  ...}

# %%
print recipe_comb['Mata Hari']
# Out:
# [u'black tea', u'cardamom', u'chai', u'cinnamon stick', u'clove', u'dried rose buds', u'ginger', u'lemon juice', u'pomegranate juice', u'simple syrup', u'sweet vermouth', u'Brandy']

# %%
fen_set = set(comp_ing_dict.keys())
cocktail_set = set([i.strip().lower() for sublist in cocktail_ing_lists for i in sublist if i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a4ee8d13b551> in <module>()
# ----> 1 fen_set = set(comp_ing_dict.keys())
#       2 cocktail_set = set([i.strip().lower() for sublist in cocktail_ing_lists for i in sublist if i])
#
# NameError: name 'comp_ing_dict' is not defined

# %%
# %page cocktail_set

# %%
# %page fen_set

# %%
cocktail_ing_lists
# Out:
# [[u'brown simple syrup',
#   u'chipotle hot sauce',
#   u'lapsang souchong tea',
#   u'lime',
#   u'Scotch',
#   u'smoked black pepper',
#   u'smoked paprika',
#   u'vegetable juice',
#   u'vodka',
#   u'Liqueurs'],
#  [u'Campari',
#   u'grapefruit peel',
#   u'ruby red grapefruit',
#   u'ruby red grapefruit juice',
#   u'sweet vermouth',
#   u'Gin,'],
#  [u'absinthe', u'cointreau', u'dry vermouth', u'Gin'],
#  [u'absinthe',
#   u'Blume Marillen Apricot Eau de Vie',
#   u'Coco Lopez',
#   u'Green Spot Irish Whiskey',
#   u'Marie Brizard Apry',
#   u'Marie Brizard Creme de Cacao Blanc',
#   u'Matcha green tea powder',
#   u'Pistachio syrup*',
#   u''],
#  [u'ginger beer', u'lime juice', u'simple syrup', u'Vodka'],
#  [u'grapefruit twist', u'Gin'],
#  [u'club soda', u'lemon juice', u'mint', u'simple syrup', u'Vodka'],
#  [u'apple brandy', u'calvados', u'sweet vermouth', u'Brandy'],
#  [u'cherry', u'cr\xe8me de cacao', u'kirschwasser', u'Gin'],
#  [u'cranberry juice', u'orange', u'orange juice', u'Cacha\xe7a'],
#  [u'ginger beer', u'lime', u'Rum'],
#  [u'allspice liqueur',
#   u'bitters',
#   u'black walnut bitters',
#   u'ginger beer',
#   u'molasses',
#   u'pumpkin',
#   u'raw oats',
#   u'sherry',
#   u'Vodka'],
#  [u'Irish whiskey liqueur', u'orange peel', u'Irish'],
#  [u'Fresh lime juice',
#   u'Fresh pineapple juice',
#   u'herbal tea bag',
#   u'palm sugar',
#   u'sage flower',
#   u'white sugar',
#   u'Gin,'],
#  [u'fresh lemon juice', u'pineapple juice', u'Rum,'],
#  [u'Ancho Reyes ancho chile liqueur',
#   u'cr\xe8me de cacao',
#   u'orange',
#   u'orange bitters',
#   u'sherry',
#   u'Liqueurs,'],
#  [u'brown sugar', u'mint', u'Bourbon'],
#  [u'allspice',
#   u'brown sugar',
#   u'butter',
#   u'cinnamon',
#   u'cinnamon stick',
#   u'nutmeg',
#   u'vanilla extract',
#   u'Rum'],
#  [u'cherry',
#   u'club soda',
#   u'herbal tea bag',
#   u'honey liqueur',
#   u'lemon',
#   u'Liqueurs'],
#  [u'elderflower liqueur', u'grapefruit', u'grapefruit juice', u'Gin'],
#  [u'agave nectar',
#   u'amaretto',
#   u'pumpkin ale',
#   u'pumpkin butter',
#   u'whole egg',
#   u'Bourbon'],
#  [u'lemon', u'mint', u'orange', u'simple syrup', u'Bourbon'],
#  [u'Lemon-lime soda', u'mint', u'orange', u'orange liqueur', u'Absinthe'],
#  [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'lemon twist',
#   u'sweet vermouth',
#   u'Bourbon'],
#  [u'Blood orange oleo saccharum', u'lemon juice', u'oloroso sherry', u'Gin'],
#  [u'amaro',
#   u'lemon twist',
#   u'Liquore Strega',
#   u'orange twist',
#   u'walnut orgeat',
#   u'Brandy'],
#  [u'cinnamon', u'lemon juice', u'peach liqueur', u'sugar', u'wine', u'Brandy'],
#  [u'grapefruit juice',
#   u'simple syrup',
#   u'sparkling wine',
#   u'Yellow Chartreuse',
#   u'Vermouth'],
#  [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'Campari',
#   u'grapefruit juice',
#   u'grapefruit twist',
#   u'Vodka'],
#  [u'apple', u'apple cider', u'cinnamon', u'Japanese'],
#  [u'Angostura Bitters',
#   u'apple',
#   u'club soda',
#   u'cranberry juice',
#   u'cucumber',
#   u'lime juice',
#   u'mint',
#   u'orange liqueur',
#   u'pear',
#   u'Vodka'],
#  [u'Angostura Bitters', u'cranberry syrup', u'grapefruit juice', u'Rum'],
#  [u'elderflower liqueur',
#   u'gin',
#   u'lemon juice',
#   u'Lillet Blanc',
#   u'Absinthe'],
#  [u'club soda',
#   u'cream',
#   u'earl grey tea syrup',
#   u'egg white',
#   u'lime juice',
#   u'Cacha\xe7a'],
#  [u'apple', u'sparkling apple juice', u'Bourbon'],
#  [u'aperol',
#   u'club soda',
#   u'grapefruit juice',
#   u'lemon juice',
#   u'simple syrup',
#   u'wine',
#   u'Liqueurs'],
#  [u'lemon juice',
#   u'madeira',
#   u'mint',
#   u"Peychaud's Bitters",
#   u'raspberries',
#   u'raspberry syrup',
#   u'Brandy'],
#  [u'Champagne', u'pink grapefruit', u'Vodka'],
#  [u'agave syrup', u'lime juice', u'watermelon', u'Tequila'],
#  [u'dry vermouth', u'orange liqueur', u'sherry', u'Irish'],
#  [u'agave nectar',
#   u'apple juice',
#   u'lime juice',
#   u'raspberry',
#   u'rose syrup',
#   u'Rum'],
#  [u'cherry', u'lemon juice', u'orange', u'sloe gin', u'Canadian'],
#  [u'', u'Brandy'],
#  [u'Angostura Bitters',
#   u'Demerara sugar',
#   u'lemon twist',
#   u'orange bitters',
#   u'orange twist',
#   u'Bourbon'],
#  [u'bitters',
#   u'dried lavender blossoms',
#   u'grapefruit juice',
#   u'grapefruit peel',
#   u'lavender',
#   u'lemon peel',
#   u'Lillet Rose',
#   u'pastis',
#   u'sugar',
#   u'Gin'],
#  [u'barbecue bitters',
#   u'dry rub spice mixture',
#   u'egg white',
#   u'lemon juice',
#   u'maple syrup',
#   u'mesquite salt',
#   u'Scaldis P\xc3\xaache Mel beer',
#   u'Beer,'],
#  [u'egg white',
#   u'lemon juice',
#   u'orange liqueur',
#   u'orange twist',
#   u'Tequila'],
#  [u'aperol', u'club soda', u'elderflower liqueur', u'lemon twist', u'Gin'],
#  [u'cayenne pepper',
#   u'chili pepper',
#   u'cocoa powder',
#   u'salt',
#   u'sugar',
#   u'Bourbon'],
#  [u'absinthe', u'bitters', u'club soda', u'lemon', u'Absinthe,'],
#  [u'cinnamon stick', u'pumpkin spice liqueur', u'simple syrup', u'Vodka'],
#  [u'cherry', u'grenadine', u'orange', u'orange juice', u'Tequila'],
#  [u'club soda', u'raspberry', u'simple syrup', u'Vodka'],
#  [u'apple',
#   u'club soda',
#   u'cucumber',
#   u'mint',
#   u'orange Cura\xe7ao',
#   u'sherry',
#   u'Gin'],
#  [u'club soda',
#   u'grapefruit juice',
#   u'green cardamom',
#   u'lime',
#   u'lime juice',
#   u'orange bitters',
#   u'sugar',
#   u'Rum'],
#  [u'Champagne', u'lemon juice', u'maraschino cherry', u'simple syrup', u'Gin'],
#  [u'Champagne', u'cr\xe8me de cassis', u'Vodka'],
#  [u'Disaronno',
#   u'lemon juice',
#   u'pear',
#   u'pear vodka',
#   u'simple syrup',
#   u'Vodka'],
#  [u'egg white', u'lemon juice', u'raspberry syrup', u'Gin'],
#  [u'cr\xe8me de cacao', u'half and half', u'Liqueurs,'],
#  [u'agave nectar',
#   u'lime juice',
#   u'orange zest',
#   u'sherry',
#   u'simple syrup',
#   u'turbinado sugar',
#   u'Tequila'],
#  [u'B\xe9n\xe9dictine',
#   u'lemon juice',
#   u'lemon peel',
#   u'orange liqueur',
#   u'Irish'],
#  [u'Angostura Bitters',
#   u'cherry',
#   u'lemon twist',
#   u'sweet vermouth',
#   u'Bourbon'],
#  [u'cucumber',
#   u'lemon juice',
#   u'pomegranate juice',
#   u'sage',
#   u'simple syrup',
#   u'Vodka'],
#  [u'agave nectar', u'lime', u'lime juice', u'pomegranate juice', u'wine', u''],
#  [u'dry vermouth', u'lemon twist', u'olive', u'orange bitters', u'Vodka'],
#  [u'brown sugar',
#   u'lime',
#   u'lime juice',
#   u'nutmeg',
#   u'orange liqueur',
#   u'Rum'],
#  [u'basil',
#   u'ginger',
#   u'ginger ale',
#   u'lime juice',
#   u'simple syrup',
#   u'watermelon',
#   u'Vodka'],
#  [u'cranberry juice', u'lime', u'Vodka'],
#  [u'agave nectar',
#   u'grapefruit',
#   u'lemon juice',
#   u'mint',
#   u'sake',
#   u'Tabasco Sauce',
#   u''],
#  [u'amaretto', u'Brandy'],
#  [u'Campari', u'orange', u'orange zest', u'sweet vermouth', u'Gin,'],
#  [u'black pepper', u'cocktail onion', u'dry vermouth', u'Vodka'],
#  [u'Combier', u'lemon', u'lemon juice', u'rhubarb marmalade', u'Gin'],
#  [u'brandied cherry',
#   u'cherry brandy',
#   u'dry vermouth',
#   u'raspberry syrup',
#   u'Brandy'],
#  [u'milk', u'nutmeg', u'powdered sugar', u'vanilla extract', u'Brandy'],
#  [u'dry vermouth', u'lemon twist', u'Gin'],
#  [u'club soda', u'lemon', u'lemon juice', u'simple syrup', u'Gin'],
#  [u'chili powder', u'hot chocolate', u'whipped cream', u'Tequila'],
#  [u'absinthe',
#   u'Angostura Bitters',
#   u'lemon peel',
#   u"Peychaud's Bitters",
#   u'sugar',
#   u'Absinthe,'],
#  [u'ginger syrup',
#   u'Grade A maple syrup',
#   u'grapefruit juice',
#   u'The Dead Rabbit Orinoco Bitters',
#   u'Bourbon'],
#  [u'orange bitters', u'orange liqueur', u'raisin', u'sherry', u'Gin'],
#  [u'kaffir lime leaf', u'tangerine', u'Tequila'],
#  [u'absinthe',
#   u'Angostura Bitters',
#   u'dry vermouth',
#   u'lemon peel',
#   u'orange bitters',
#   u'sherry',
#   u'thyme liqueur',
#   u'Gin'],
#  [u'cayenne pepper', u'Green Chartreuse', u'Liqueurs,'],
#  [u'apple chip',
#   u'Green Chartreuse',
#   u'mint',
#   u'simple syrup',
#   u'sparkling apple cider',
#   u'sparkling pear cider',
#   u'Liqueurs'],
#  [u'chocolate bitters',
#   u'cr\xe8me de cacao',
#   u'milk',
#   u'orange liqueur',
#   u'red Fresno chile pepper',
#   u'Vodka'],
#  [u'cucumber vodka', u'mint', u'simple syrup', u'sour mix', u'Gin'],
#  [u'grapefruit',
#   u'grapefruit juice',
#   u'lemon',
#   u'lemon juice',
#   u'pilsner',
#   u'sugar',
#   u'Beer,'],
#  [u'cr\xe8me de cacao',
#   u'raspberry',
#   u'raspberry liqueur',
#   u'white chocolate liqueur',
#   u'Liqueurs,'],
#  [u'lime juice', u'pineapple juice', u'rosemary', u'simple syrup', u'Tequila'],
#  [u'absinthe',
#   u'Angostura Bitters',
#   u'Green Chartreuse',
#   u'grenadine',
#   u'lemon juice',
#   u'mint bitters',
#   u"Peychaud's Bitters",
#   u'simple syrup',
#   u'Bourbon'],
#  [u'brown sugar',
#   u'clove',
#   u'Demerara sugar',
#   u'lemon juice',
#   u'lemon twist',
#   u'Bourbon'],
#  [u'ginger ale', u'lime juice', u'lime wheel', u'Irish'],
#  [u'agave nectar',
#   u'egg white',
#   u'grapefruit juice',
#   u'Green Chartreuse',
#   u'lemon',
#   u'lemon juice',
#   u'mint',
#   u'Bourbon'],
#  [u'aperol', u'jalape\xf1o', u'lemon juice', u'mango syrup', u'Vodka'],
#  [u'Champagne', u'lemon juice', u'lemon twist', u'simple syrup', u'Gin'],
#  [u'Campari',
#   u'egg white',
#   u'honey',
#   u'Meyer lemon juice',
#   u'rosemary',
#   u'Liqueurs'],
#  [u'Baileys with a Hint of Coffee',
#   u'banana',
#   u'chocolate syrup',
#   u'coffee bean',
#   u'vanilla ice cream',
#   u'Liqueurs'],
#  [u'Dry Riesling',
#   u'honey syrup',
#   u'orange Cura\xe7ao',
#   u"Peychaud's Bitters",
#   u'Vermouth'],
#  [u'ginger beer', u'lime', u'Vodka'],
#  [u'grape',
#   u'lime',
#   u'orange',
#   u'orange liqueur',
#   u'peach',
#   u'wine',
#   u'Liqueurs'],
#  [u'', u'Bourbon'],
#  [u'Demerara sugar',
#   u'lemon',
#   u'lemon juice',
#   u'nutmeg',
#   u'peach brand',
#   u'Brandy'],
#  [u'cherry', u'ginger liqueur', u'lemon juice', u'Bourbon'],
#  [u'Angostura Bitters',
#   u'chamomile tea',
#   u'lemon juice',
#   u'sherry',
#   u'simple syrup',
#   u'Yellow Chartreuse',
#   u'Rye'],
#  [u'agave nectar',
#   u'black peppercorn',
#   u'chile powder',
#   u'cinnamon',
#   u'corn chip',
#   u'cumin',
#   u'evaporated milk',
#   u'guajillo chile',
#   u'Mexican hot chocolate mix',
#   u'oregano',
#   u'peanut butter',
#   u'Tequila'],
#  [u'Champagne',
#   u'club soda',
#   u'lemon',
#   u'nutmeg',
#   u'orange liqueur',
#   u'port',
#   u'sugar',
#   u'tea',
#   u'Brandy'],
#  [u'', u'Liqueurs'],
#  [u'Chateau Montifaud Pineau de Charentes Rosso',
#   u'Gran Classico Bitter',
#   u'luxardo cherry',
#   u'Luxardo Maraschino Liqueur',
#   u'Other'],
#  [u'', u'Tequila'],
#  [u'Campari', u'lemon juice', u'mint', u'prosecco', u'simple syrup', u'Rum'],
#  [u'chamomile tea',
#   u'evaporated cane juice',
#   u'lemon',
#   u'pommeau de Normandie',
#   u'Tequila'],
#  [u'aperol', u'cointreau', u'dry vermouth', u'water', u'Gin'],
#  [u'absinthe',
#   u'chamomile flowers',
#   u'Cherry Heering',
#   u'Everclear',
#   u'green tea bags',
#   u'honey liqueur',
#   u'lemon juice',
#   u'lemon sherbet',
#   u'nutmeg',
#   u'Vodka'],
#  [u'honey', u'lemon juice', u'Moroccan bitters', u'pomegranate', u'Vodka'],
#  [u'B\xe9n\xe9dictine',
#   u'blood orange juice',
#   u'blood orange twist',
#   u'brandied cherries',
#   u'Cherry Heering',
#   u'lemon juice',
#   u'Scotch'],
#  [u'ginger beer', u'lime juice', u'simple syrup', u'Vodka'],
#  [u'absinthe',
#   u'Angostura Bitters',
#   u'lemon twist',
#   u'sweet vermouth',
#   u'Irish'],
#  [u'Fernet-Branca',
#   u'lemon',
#   u'lemon juice',
#   u'pear brandy',
#   u'prosecco',
#   u'simple syrup',
#   u'Gin'],
#  [u'apple brandy',
#   u'coffee',
#   u'lemon twist',
#   u'Yellow Chartreuse',
#   u'Liqueurs'],
#  [u'cherry',
#   u'lemon juice',
#   u'orange',
#   u'pomegranate liqueur',
#   u'simple syrup',
#   u'Bourbon'],
#  [u'Angostura Bitters', u'lemon twist', u"Peychaud's Bitters", u''],
#  [u'applejack', u'cherry', u'cherry liqueur', u'lemon twist', u'Brandy'],
#  [u'amaro',
#   u'Angostura Bitters',
#   u'honey liqueur',
#   u'orange bitters',
#   u'sherry',
#   u'Scotch'],
#  [u'anise liqueur', u'lemon peel', u"Peychaud's Bitters", u'sugar', u'Rye'],
#  [u'Demerara syrup',
#   u'fresh lemon juice',
#   u'Fresh pineapple juice',
#   u'pineapple core',
#   u'Brandy'],
#  [u'cocktail onion', u'dry vermouth', u'Gin,'],
#  [u'cinnamon stick', u'honey', u'lemon', u'lemon juice', u'tea', u'Tequila'],
#  [u'dried cherry',
#   u'Dubonnet Rouge',
#   u'peach bitters',
#   u'sugar',
#   u'sweet vermouth',
#   u'Bourbon'],
#  [u'7UP',
#   u'Campari',
#   u'clementine',
#   u'edible pansy',
#   u'ground ginger',
#   u'orange juice',
#   u'strawberry',
#   u'Liqueurs'],
#  [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'cherry',
#   u'egg white',
#   u'lemon juice',
#   u'orange',
#   u'simple syrup',
#   u'Gin'],
#  [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u"Peychaud's Bitters",
#   u'sweet vermouth',
#   u'Brandy'],
#  [u'club soda', u'lime', u'Bourbon'],
#  [u'basil',
#   u'blue Cura\xe7ao',
#   u'blueberries',
#   u'club soda',
#   u'concord grapes',
#   u'lemon',
#   u'plum',
#   u'sugar',
#   u'tea',
#   u''],
#  [u'cherry',
#   u'cherry liqueur',
#   u'club soda',
#   u'lime',
#   u'lime juice',
#   u'Cacha\xe7a'],
#  [u'brandied cherry', u'Champagne', u'lemon juice', u'simple syrup', u'Gin'],
#  [u'', u'Liqueurs'],
#  [u'lemon juice', u'lemon peel', u'simple syrup', u'Brandy'],
#  [u'Campari',
#   u'cinnamon',
#   u'orange',
#   u'orange bitters',
#   u'orange blossom water',
#   u'port',
#   u'Liqueurs,'],
#  [u'ginger', u'lime juice', u'raspberry', u'sugar', u'tonic water', u'Vodka'],
#  [u'Angostura Bitters',
#   u'Green Chartreuse',
#   u'orange peel',
#   u'sweet vermouth',
#   u'Irish'],
#  [u'pineapple', u'Rum,'],
#  [u'black tea',
#   u'cardamom',
#   u'chai',
#   u'cinnamon stick',
#   u'clove',
#   u'dried rose buds',
#   u'ginger',
#   u'lemon juice',
#   u'pomegranate juice',
#   u'simple syrup',
#   u'sweet vermouth',
#   u'Brandy'],
#  [u'aperol',
#   u'Champagne',
#   u'Cynar',
#   u'grapefruit twist',
#   u'Lillet Blanc',
#   u"Peychaud's Bitters",
#   u'Gin,'],
#  [u'Champagne', u'honey syrup', u'lime juice', u'nutmeg', u'Rum'],
#  [u'Champagne',
#   u'lime juice',
#   u'mint',
#   u'raspberry',
#   u'simple syrup',
#   u'Vodka'],
#  [u'black pepper',
#   u'celery salt',
#   u'crawfish tail',
#   u'horseradish',
#   u'lemon juice',
#   u'olive',
#   u'pickled string bean',
#   u'Tabasco Sauce',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Vodka'],
#  [u'cranberry juice',
#   u'Grand Marnier',
#   u'lemon twist',
#   u'lime juice',
#   u'orange liqueur',
#   u'strawberry',
#   u'VeeV A\xe7ai Spirit',
#   u'Liqueurs'],
#  [u'chile de arbol', u'lime juice', u'st. germain', u'Absinthe,'],
#  [u'Dubonnet Rouge',
#   u'orange liqueur',
#   u'orange twist',
#   u"Peychaud's Bitters",
#   u'Rye'],
#  [u'amaro',
#   u'lime',
#   u'lime juice',
#   u'pimento dram',
#   u'prosecco',
#   u'simple syrup',
#   u'sparkling wine',
#   u'Rum'],
#  [u'Campari',
#   u'lime juice',
#   u'mezcal',
#   u'passion fruit syrup',
#   u'pineapple juice',
#   u'simple syrup',
#   u''],
#  [u'club soda',
#   u'grapefruit juice',
#   u'lemon',
#   u'lime',
#   u'orange liqueur',
#   u'Tequila'],
#  [u'a\xe7ai juice', u'Champagne', u'lime juice', u'VeeV', u'Liqueurs'],
#  [u'Campari', u'orange slice', u'orange twist', u'sweet vermouth', u'Gin,'],
#  [u'mint', u'moonshine', u'sugar', u'white dog', u'Bourbon'],
#  [u'lemon twist', u'pineapple juice', u'raspberry liqueur', u'Vodka'],
#  [u'blueberry',
#   u'club soda',
#   u'lime juice',
#   u'mint',
#   u'simple syrup',
#   u'Vodka'],
#  [u'agave nectar',
#   u'lime juice',
#   u'orange',
#   u'orange liqueur',
#   u'orange marmalade',
#   u'Tequila'],
#  [u'lemon', u'lemonade', u'Vodka'],
#  [u'beer', u'ginger beer', u'lime', u'Tabasco Sauce', u'Beer,'],
#  [u'lemon juice', u'orange liqueur', u'simple syrup', u'sugar', u'Liqueurs'],
#  [u'Green Chartreuse', u'lime juice', u'maraschino liqueur', u'Gin,'],
#  [u'7UP',
#   u'bitters',
#   u'grenadine',
#   u'lemon',
#   u'lime',
#   u'lime juice',
#   u'orange',
#   u'simple syrup',
#   u'Tequila'],
#  [u'cherry', u'Cynar', u'maraschino liqueur', u'sweet vermouth', u'Bourbon'],
#  [u'concord grape', u'concord grape puree', u'sugar', u'Thai basil', u'Gin'],
#  [u'agave nectar',
#   u'lime',
#   u'lime juice',
#   u'orange liqueur',
#   u'simple syrup',
#   u'Tequila'],
#  [u'aperol',
#   u'cilantro',
#   u'lime juice',
#   u'orange bitters',
#   u'simple syrup',
#   u'strawberry',
#   u'Tequila'],
#  [u'club soda', u'lime', u'lime juice', u'sour mix', u'Gin'],
#  [u'Galliano', u'lime', u'lime juice', u'triple sec', u'Rum'],
#  [u'lime', u'lime juice', u'orange liqueur', u'triple sec', u'Tequila'],
#  [u'berries',
#   u'grape',
#   u'mint',
#   u'orange',
#   u'st. germain',
#   u'tarragon',
#   u'white wine',
#   u'Vodka'],
#  [u'Angostura Bitters',
#   u'beer',
#   u'lemon juice',
#   u'maple syrup',
#   u'orange',
#   u'Beer,'],
#  [u'almond',
#   u'Baileys with a Hint of Caramel',
#   u'half and half',
#   u'hazelnut liqueur',
#   u'honey',
#   u'vanilla liqueur',
#   u'Liqueurs'],
#  [u'fig preserves',
#   u'ginger',
#   u'orange juice',
#   u'rosemary',
#   u'sugar',
#   u'Tequila'],
#  [u'cinnamon',
#   u'cranberry sauce',
#   u'Fee Brothers Cranberry Bitters',
#   u'lemon juice',
#   u'sugar',
#   u'Brandy'],
#  [u'Angostura Bitters',
#   u'apple juice',
#   u'cherry',
#   u"Peychaud's Bitters",
#   u'Rum'],
#  [u'absinthe',
#   u'cinnamon sticks',
#   u'concord grapes',
#   u'lemon juice',
#   u'lemon twist',
#   u'star anise',
#   u'sugar',
#   u'Brandy'],
#  [u'basil', u'club soda', u'lemonade', u'strawberry', u'Gin'],
#  [u'lime', u'tonic water', u'Gin'],
#  [u'dry vermouth', u'lemon twist', u'orange bitters', u'Gin,'],
#  [u'absinthe',
#   u'blueberry',
#   u'ginger beer',
#   u'lemon juice',
#   u'raspberry brandy',
#   u'simple syrup',
#   u'sugar',
#   u'Absinthe,'],
#  [u'Angostura Bitters',
#   u'cinnamon syrup',
#   u'concord grapes',
#   u'Demerara syrup',
#   u'lemon juice',
#   u'sorghum syrup',
#   u'Liqueurs'],
#  [u'', u'Liqueurs'],
#  [u'peach', u'prosecco', u'white peach puree', u''],
#  [u'kumquats', u'vodka', u'water', u'white sugar', u''],
#  [u'', u'Bourbon'],
#  [u'hellfire bitters',
#   u'honey-pinapple syrup',
#   u'lime juice',
#   u'mezcal',
#   u'pineapple juice',
#   u'Mezcal'],
#  [u'7UP', u'lime', u'mint', u'pineapple juice', u'Sprite', u'Absinthe'],
#  [u'allspice',
#   u'apple juice',
#   u'cinnamon',
#   u'clove',
#   u'heavy cream',
#   u'nutmeg',
#   u'orange peel',
#   u'Tequila'],
#  [u'bacon',
#   u'beef straw',
#   u'bloody mary mix',
#   u'celery',
#   u'celery salt',
#   u'cocktail onion',
#   u'lemon',
#   u'lime',
#   u'pickled green bean',
#   u'pickled okra',
#   u'prepared horseradish',
#   u'sea salt',
#   u'Sriracha',
#   u'Tabasco Sauce',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Vodka'],
#  [u'aperol', u'orange bitters', u'sweet vermouth', u'Bourbon'],
#  [u'agave nectar', u'cucumber slices', u'dill', u'lime juice', u'Vodka'],
#  [u'club soda',
#   u'grenadine',
#   u'lime juice',
#   u'orange flower water',
#   u'watermelon juice',
#   u'Tequila'],
#  [u'B\xe9n\xe9dictine', u"Peychaud's Bitters", u'Irish'],
#  [u'agave nectar',
#   u'beef jerky',
#   u'bell pepper',
#   u'chipotle pepper',
#   u'ginger syrup',
#   u'lemon',
#   u'lemon juice',
#   u'lime',
#   u'lime wedge',
#   u'Mezcal'],
#  [u'elderflower liqueur',
#   u'grapefruit peel',
#   u'orgeat syrup',
#   u'rosemary',
#   u'ruby red grapefruit juice',
#   u'salt',
#   u'Vodka'],
#  [u'brandied cherries', u'sweet vermouth', u'Rye'],
#  [u'Angostura Bitters',
#   u'lime juice',
#   u'orange peel',
#   u'simple syrup',
#   u'St. Elizabeth Allspice Dram',
#   u'Bourbon'],
#  [u'Angostura Bitters', u'vermouth', u'Bourbon'],
#  [u'brown sugar',
#   u'butter',
#   u'cinnamon',
#   u'cloves',
#   u'ice cream',
#   u'nutmeg',
#   u'sugar',
#   u'Rum'],
#  [u'Absolut Smoked Tea',
#   u'Coconut-lychee milk*',
#   u'Fresh lime juice',
#   u'Salted pistachio syrup*',
#   u'Vodka'],
#  [u'Demerara sugar', u'green tea', u'Rum'],
#  [u'bitters',
#   u'ginger',
#   u'lemon juice',
#   u'oloroso sherry',
#   u'orange-ginger marmalade',
#   u'sugar',
#   u'Irish'],
#  [u'agave nectar', u'sparkling wine', u'strawberry', u'wine', u''],
#  [u'Campari', u'club soda', u'orange twist', u'sweet vermouth', u'Liqueurs,'],
#  [u'dry vermouth',
#   u'lemon juice',
#   u'lemon twist',
#   u'maraschino liqueur',
#   u'Gin,'],
#  [u'amarena cherry',
#   u'Angostura Bitters',
#   u'orange',
#   u'sugar cube',
#   u'Brandy'],
#  [u'', u'Vermouth'],
#  [u'seltzer', u'Liqueurs,'],
#  [u'cucumber',
#   u'Fernet-Branca',
#   u'lime juice',
#   u'maraschino liqueur',
#   u'sparkling wine',
#   u'Tequila'],
#  [u'apple juice',
#   u'black tea',
#   u'cinnamon',
#   u'lemon',
#   u'lemon juice',
#   u'nutmeg',
#   u'star anise',
#   u'Irish'],
#  [u'Angostura Bitters',
#   u'lemon juice',
#   u'maraschino liqueur',
#   u'simple syrup',
#   u'triple sec',
#   u'Brandy'],
#  [u'dry vermouth', u'sweet vermouth', u'Brandy'],
#  [u'black tea', u'lemon juice', u'lime juice', u'mint', u'sugar', u'Bourbon'],
#  [u'black pepper',
#   u'cinnamon',
#   u'egg',
#   u'heavy cream',
#   u'nutmeg',
#   u'sugar',
#   u'Brandy'],
#  [u'The Dead Rabbit Orinoco Bitters', u'tonic water', u'Bourbon'],
#  [u'cinnamon',
#   u'coffee',
#   u'Demerara sugar',
#   u'orange juice',
#   u'orange peel',
#   u'simple syrup',
#   u'sweet vermouth',
#   u'Rum,'],
#  [u'apple', u'grape', u'lemon', u'mint', u'simple syrup', u'Gin'],
#  [u'chile pepper', u'lime juice', u'simple syrup', u'Gin'],
#  [u'cherry',
#   u'grenadine',
#   u'lime juice',
#   u'orange',
#   u'orange juice',
#   u'passion fruit juice',
#   u'simple syrup',
#   u'Rum'],
#  [u'bitters', u'lemon twist', u'simple syrup', u'Absinthe,'],
#  [u'basil leaves', u'club soda', u'lemon juice', u'pineapple syrup', u'Vodka'],
#  [u'aperol',
#   u'Champagne',
#   u'elderflower liqueur',
#   u'lemon juice',
#   u'lime twist',
#   u'Gin,'],
#  [u'Peppermint tea', u'sugar', u'water', u''],
#  [u'brewed coffee', u'ground cinnamon', u'milk', u'Liqueurs'],
#  [u'apple juice',
#   u'blueberry',
#   u'cherry bitters',
#   u'pineapple juice',
#   u'sugar',
#   u'Irish'],
#  [u'Amaro Montenegro', u'brown sugar syrup', u'lime juice', u'Vodka'],
#  [u'Angostura Bitters',
#   u'cranberry juice',
#   u'ginger ale',
#   u'lemon juice',
#   u'mint',
#   u'raspberry',
#   u'simple syrup',
#   u'Rum'],
#  [u'apple cider', u'honey syrup', u'lemon juice', u'pear brandy', u'Vodka'],
#  [u'basil', u'sugar', u'water', u'Non-alcoholic'],
#  [u'elderflower liqueur', u'lime', u'lime juice', u'salt', u'Liqueurs,'],
#  [u'B\xe9n\xe9dictine',
#   u'Campari',
#   u'club soda',
#   u'Lillet Blanc',
#   u'orange liqueur',
#   u'orange twist',
#   u'Gin,'],
#  [u'Amontillado sherry',
#   u'apple bitters',
#   u'Clear Creek Pear Brandy',
#   u'maple syrup',
#   u'Brandy'],
#  [u'cherry', u'sweet vermouth', u'Bourbon'],
#  [u'agave nectar', u'basil', u'blackberry', u'lime juice', u'Tequila'],
#  [u'blanched almonds',
#   u'mulling spices',
#   u'orange zest',
#   u'raisin',
#   u'sugar',
#   u'wine',
#   u'Vodka'],
#  [u'agave nectar',
#   u'habanero pepper',
#   u'lime juice',
#   u'tangerine',
#   u'Tequila'],
#  [u'grenadine', u'peach', u'peach puree', u'Rum'],
#  [u'guava puree', u'lime juice', u'rose petal', u'rose syrup', u'Cacha\xe7a'],
#  [u'Baileys', u'coffee liqueur', u'orange liqueur', u'Liqueurs'],
#  [u'agave nectar', u'cranberry', u'jalape\xf1o', u'lime juice', u'Tequila'],
#  [u'raspberry', u'sparkling wine', u'white peach', u'Vodka'],
#  [u'agave nectar', u'Angostura Bitters', u'orange', u'Tequila'],
#  [u'Angostura Bitters', u'sweet vermouth', u'Bourbon'],
#  [u'blood orange',
#   u'egg white',
#   u'lime juice',
#   u'sage',
#   u'simple syrup',
#   u'Gin'],
#  [u'club soda', u'ginger', u'grape', u'lemon', u'mint', u'raw sugar', u'Gin'],
#  [u'B\xe9n\xe9dictine',
#   u'lemon juice',
#   u'lemon twist',
#   u'Yellow Chartreuse',
#   u'Liqueurs,'],
#  [u'B\xe9n\xe9dictine', u'lemon juice', u'Yellow Chartreuse', u'Gin'],
#  [u'fresh grapefruit juice',
#   u'grapefruit peel',
#   u'sparkling wine',
#   u'Vermouth'],
#  [u'beer', u'Beer,'],
#  [u'cucumber', u'lime juice', u'mint', u'Truvia', u'watermelon', u'Vodka'],
#  [u'apple',
#   u'brown sugar',
#   u'cinnamon',
#   u'clove',
#   u'guava',
#   u'hibiscus',
#   u'pear',
#   u'pink peppercorn',
#   u'star anise',
#   u'sugar cane',
#   u'tamarind',
#   u'tejocote',
#   u'walnut',
#   u'Brandy'],
#  [u'asparagus',
#   u'balsamic vinegar',
#   u'black pepper',
#   u'carrot',
#   u'celery',
#   u'celery salt',
#   u'dill pickle',
#   u'garlic',
#   u'horseradish',
#   u'lemon juice',
#   u'olive',
#   u'pickled okra',
#   u'Tabasco Sauce',
#   u'tomato',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Gin'],
#  [u'cinnamon',
#   u'nutmeg',
#   u'pear brandy',
#   u'Pear puree or nectar',
#   u'sparkling wine',
#   u''],
#  [u'chocolate syrup', u'cream', u'ice', u'milk', u'Liqueurs,'],
#  [u'dry vermouth', u'orange bitters', u'orange peel', u'Tequila,'],
#  [u'brown sugar', u'coffee', u'orange liqueur', u'whipped cream', u'Liqueurs'],
#  [u'sugar', u'tarragon', u'water', u'Non-alcoholic'],
#  [u'B\xe9n\xe9dictine',
#   u'Dubonnet Rouge',
#   u'orange liqueur',
#   u'orange twist',
#   u'Rum'],
#  [u'Angostura Bitters',
#   u'lemon',
#   u'lemon juice',
#   u'lychee juice',
#   u'orange',
#   u'rose petal',
#   u'simple syrup',
#   u'Gin'],
#  [u'fig',
#   u'lemon juice',
#   u'lime',
#   u'nutmeg',
#   u'orange juice',
#   u'simple syrup',
#   u'Bourbon'],
#  [u'bitter lemon soda',
#   u'dry vermouth',
#   u'grenadine',
#   u'lemon',
#   u'lemon juice',
#   u'Gin,'],
#  [u'cinnamon', u'fruit', u'prosecco', u'Liqueurs,'],
#  [u'Campari',
#   u'grapefruit juice',
#   u'mint',
#   u'orange',
#   u'passion fruit puree',
#   u'prosecco',
#   u'raspberry',
#   u'Liqueurs'],
#  [u'ginger liqueur',
#   u'lime',
#   u'sweetened lime juice',
#   u'tonic water',
#   u'Bourbon'],
#  [u'candied ginger',
#   u'club soda',
#   u'ginger syrup',
#   u'lemon juice',
#   u'Bourbon'],
#  [u'apple',
#   u'lemon',
#   u'lime',
#   u'orange',
#   u'strawberry',
#   u'white cranberry juice',
#   u'wine',
#   u'Vodka'],
#  [u'agave nectar',
#   u'blackberry',
#   u'blackberry liqueur',
#   u'lemon juice',
#   u'lemon twist',
#   u'lime juice',
#   u'Tequila'],
#  [u'club soda', u'Grand Marnier', u'lemon juice', u'sugar', u'Tequila'],
#  [u'B\xe9n\xe9dictine',
#   u'cherry',
#   u'cherry brandy',
#   u'club soda',
#   u'lime',
#   u'Gin'],
#  [u'7UP',
#   u'cucumber',
#   u'lemon',
#   u'mint',
#   u'orange',
#   u"Pimm's No. 1",
#   u'Sprite',
#   u'strawberry',
#   u'Liqueurs'],
#  [u'Bittermens Burlesque Bitters',
#   u'egg white',
#   u'hibiscus-rosehip tea',
#   u'lemon juice',
#   u'pear liqueur',
#   u'strawberry',
#   u'sugar',
#   u'vodka',
#   u'Vodka'],
#  [u'bitters',
#   u'lemon juice',
#   u'Organic maple syrup',
#   u'Purely Syrup Vanilla Bean',
#   u'vanilla bean',
#   u'Bourbon'],
#  [u'lemon juice',
#   u'Licor 43',
#   u'orange juice',
#   u'passion fruit puree',
#   u'pineapple juice',
#   u'Rum'],
#  [u'egg white',
#   u'fresh lemon juice',
#   u'pineapple juice',
#   u'rose petals',
#   u'rose syrup',
#   u'strawberry',
#   u'Gin'],
#  [u'amaro', u'Angostura Bitters', u'lemon twist', u'sherry', u'Bourbon'],
#  [u'amaretto', u'lime', u'mint', u'orange juice', u'Tequila'],
#  [u'cranberry juice',
#   u'elderflower liqueur',
#   u'orange bitters',
#   u'sparkling wine',
#   u'sugar',
#   u'Liqueurs'],
#  [u'fresh grapefruit wheel',
#   u'lemon juice',
#   u'lemon simple syrup',
#   u'maraschino liqueur',
#   u'Gin'],
#  [u'Angostura Bitters',
#   u'Demarara Syrup',
#   u"regan's orange bitters no. 6",
#   u'Bourbon'],
#  [u'Campari', u'grapefruit juice', u'lime', u'Gin'],
#  [u'club soda',
#   u'grenadine',
#   u'lemon juice',
#   u'orange juice',
#   u'orange peel',
#   u'Non-alcoholic'],
#  [u'ginger ale', u'lemon peel', u'Bourbon'],
#  [u'cassis',
#   u'lemon juice',
#   u'orange liqueur',
#   u'ruby red grapefruit juice',
#   u'Tequila'],
#  [u'cherry', u'club soda', u'lemon', u'lemon juice', u'simple syrup', u'Gin'],
#  [u'lime', u'lime juice', u'pomegranate juice', u'simple syrup', u'Tequila'],
#  [u'apple cider', u'cinnamon stick', u'orange', u'VeeV', u'Liqueurs'],
#  [u'Angostura Bitters',
#   u'boiling water',
#   u'lemon juice',
#   u'maple syrup',
#   u'pumpkin puree',
#   u'Bourbon'],
#  [u'Coconut-pistachio puree*',
#   u'Del Maguey Vida Mezcal',
#   u'fresh lemon juice',
#   u'King\u2019s Ginger',
#   u'Mezcal'],
#  [u'Champagne', u'lemon juice', u'lemon peel', u'simple syrup', u'Brandy'],
#  [u'apple slice', u'cranberry juice', u'Canadian'],
#  [u'Angostura Bitters', u'Champagne', u'lemon twist', u'sugar cube', u''],
#  [u'Campari', u'lime juice', u'orange liqueur', u'Liqueurs,'],
#  [u'cherry',
#   u'lime juice',
#   u'pineapple',
#   u'pineapple juice',
#   u'pisco',
#   u'simple syrup',
#   u'Pisco'],
#  [u'Angostura Bitters',
#   u'lemon juice',
#   u'lemon twist',
#   u'rose petal',
#   u'simple syrup',
#   u'sparkling wine',
#   u''],
#  [u'cr\xe8me de violette',
#   u'lemon juice',
#   u'lemon twist',
#   u'maraschino cherry',
#   u'maraschino liqueur',
#   u'Gin'],
#  [u'agave nectar', u'chocolate milk', u'cognac', u'nutmeg', u'Tequila'],
#  [u'club soda',
#   u'lemon juice',
#   u'Meyer lemon vodka',
#   u'mint',
#   u'simple syrup',
#   u'Vodka'],
#  [u'dry vermouth', u'Gin'],
#  [u'club soda',
#   u'elderflower liqueur',
#   u'kiwi',
#   u'simple syrup',
#   u'sparkling wine',
#   u'Liqueurs'],
#  [u'cinnamon stick',
#   u'cocoa powder',
#   u'green tea liqueur',
#   u'matcha powder',
#   u'simple syrup',
#   u'steamed milk',
#   u'Irish'],
#  [u'Angostura Bitters', u'ginger ale', u'lime', u'lime juice', u'Pisco'],
#  [u'Angostura Bitters',
#   u'Gran Gala',
#   u'lemon juice',
#   u'nutmeg',
#   u'orange peel',
#   u'Punt e Mes',
#   u'seltzer',
#   u'sugar',
#   u'Bourbon'],
#  [u'brandied cherry',
#   u'lemon juice',
#   u'maraschino liqueur',
#   u'mint',
#   u'Bourbon'],
#  [u'agave syrup', u'cinnamon', u'cloves', u'honey', u'lemon', u'Tequila'],
#  [u'Champagne', u'Bourbon'],
#  [u'Angostura Bitters', u'Dubonnet Rouge', u'Gin,'],
#  [u'celery bitters', u'lemon twist', u'olive', u'sherry', u'Gin'],
#  [u'Baileys with a Hint of Mint Chocolate',
#   u'candy cane',
#   u'hot chocolate',
#   u'mint',
#   u'whipped cream',
#   u'Liqueurs'],
#  [u'sencha tea', u'Gin'],
#  [u'bitters', u'dry vermouth', u'sweet vermouth', u'Rum'],
#  [u'espresso', u'Kahlua', u'Liqueurs,'],
#  [u'club soda',
#   u'orange',
#   u'orange juice',
#   u'orange liqueur',
#   u'triple sec',
#   u'Vodka'],
#  [u'apple cider',
#   u'chamomile buds',
#   u'Fresh lime juice',
#   u'pineapple juice',
#   u'simple syrup',
#   u'Gin'],
#  [u'Champagne', u'simple syrup', u'strawberry', u'Tequila'],
#  [u'Bittermens Tiki Bitters',
#   u'dried pineapple',
#   u'fresh lemon juice',
#   u'granulated sugar',
#   u'milk',
#   u'oloroso sherry',
#   u'pineapple puree',
#   u'rosemary',
#   u'rosemary syrup',
#   u'salt',
#   u'salted caramel syrup',
#   u'vanilla extract',
#   u'Vodka'],
#  [u'lime juice', u'simple syrup', u'strawberry', u'Rum'],
#  [u'Angostura Bitters',
#   u'calvados',
#   u'Grand Marnier',
#   u'orange twist',
#   u'Brandy'],
#  [u'banana',
#   u'cinnamon',
#   u'lemon bitters',
#   u'lemon juice',
#   u'mint',
#   u'nutmeg',
#   u'sugar',
#   u'Bourbon'],
#  [u'apple cider',
#   u'cranberry juice',
#   u'ginger ale',
#   u'ginger liqueur',
#   u'lemon',
#   u'pomegranate juice',
#   u'Gin'],
#  [u'', u''],
#  [u'7UP', u'Bourbon'],
#  [u'simple chocolate syrup', u'vanilla ice cream', u'whole milk', u'Bourbon'],
#  [u'blanched almonds',
#   u'brandy',
#   u'orange flower water',
#   u'sugar',
#   u'water',
#   u'Brandy'],
#  [u'cranberry juice',
#   u'red wine',
#   u'strawberry',
#   u'VeeV A\xe7ai Spirit',
#   u'Liqueurs'],
#  [u'agave nectar', u'coffee bean', u'coffee liqueur', u'Tequila'],
#  [u'orange twist', u'Canadian'],
#  [u'black pepper',
#   u'celery salt',
#   u'cucumber',
#   u'dried basil',
#   u'dried oregano',
#   u'hot sauce',
#   u'lemon',
#   u'lemon juice',
#   u'lime juice',
#   u'olive',
#   u'olive oil',
#   u'olive tapenade',
#   u'salt',
#   u'sherry',
#   u'tomato juice',
#   u'Vodka'],
#  [u'absinthe', u'lime juice', u'Pear puree', u'simple syrup', u'Gin'],
#  [u'basil', u'lime juice', u'passion fruit puree', u'simple syrup', u'Rum'],
#  [u'Cynar', u'orange twist', u'sweet vermouth', u'Liqueurs,'],
#  [u'', u'Mezcal'],
#  [u'apple juice', u'ginger ale', u'ginger beer', u'lemon', u'Bourbon'],
#  [u'Drambuie',
#   u'lemon juice',
#   u'maraschino liqueur',
#   u"Peychaud's Bitters",
#   u'Liqueurs,'],
#  [u'cr\xe8me de menthe', u'Brandy'],
#  [u'Angostura Bitters',
#   u'beer',
#   u'cinnamon',
#   u'lemon juice',
#   u'lemon peel',
#   u'pale ale',
#   u'Sauternes',
#   u'wine',
#   u'Gin'],
#  [u'aperol',
#   u'club soda',
#   u'grapefruit juice',
#   u'honey',
#   u'lemon juice',
#   u'Vodka'],
#  [u'amaro', u'port', u'Bourbon'],
#  [u'black pepper',
#   u'honey',
#   u'lemon juice',
#   u'watermelon',
#   u'watermelon juice',
#   u'Gin'],
#  [u'lemon', u'mint leaves', u'seltzer water', u'simple syrup', u'Scotch'],
#  [u'lemon juice',
#   u'luxardo amaretto',
#   u'Rothman &amp; Winter Orchard Apricot',
#   u'Brandy'],
#  [u'', u'Liqueurs'],
#  [u'Amaro Nonino', u'aperol', u'lemon juice', u'Bourbon'],
#  [u'The Dead Rabbit Orinoco Bitters', u'Bourbon'],
#  [u'Lillet Blanc', u'Lillet Rouge', u'Bourbon'],
#  [u'Angostura Bitters', u'orange Cura\xe7ao', u'port', u'Brandy'],
#  [u'cider',
#   u'lemon juice',
#   u"Pimm's No. 1",
#   u'simple syrup',
#   u'vermouth',
#   u'Vodka'],
#  [u'dry vermouth', u'olive', u'Gin,'],
#  [u'Ancho Chile Liqueur',
#   u'Bittermen\u2019s Mol\xe9 Bitters',
#   u'Campari',
#   u'Pierde Almas +9 Mezcal-Gin',
#   u'sweet vermouth',
#   u'Gin,'],
#  [u'lime', u'salt', u'Tabasco Sauce', u'Tequila'],
#  [u'Creme Yvette',
#   u'lime juice',
#   u'orange bitters',
#   u'vanilla syrup',
#   u'Vodka'],
#  [u'Campari',
#   u'lime juice',
#   u'mint',
#   u'rum',
#   u'simple syrup',
#   u'sugar cane syrup',
#   u'sugar cube',
#   u'Scotch'],
#  [u'Angostura Bitters',
#   u'chocolate bitters',
#   u'cinnamon',
#   u'cocktail cranberry',
#   u'orange twist',
#   u'orgeat',
#   u'Bourbon'],
#  [u'dry vermouth', u'orange bitters', u'Vodka'],
#  [u'', u'Tequila'],
#  [u'grenadine',
#   u'lemon',
#   u'lemon juice',
#   u'maraschino liqueur',
#   u'orange juice',
#   u'raspberry syrup',
#   u'Liqueurs'],
#  [u'blueberry juice',
#   u'orange juice',
#   u'orange liqueur',
#   u'watermelon',
#   u'Vodka'],
#  [u'Lemon-lime soda', u'lime', u'mint', u'pear syrup', u'Rum'],
#  [u'balsamic vinegar',
#   u'basil',
#   u'black peppercorn',
#   u'club soda',
#   u'lemon juice',
#   u'sugar',
#   u'tomato',
#   u'Gin'],
#  [u'Angostura Bitters',
#   u"regan's orange bitters no. 6",
#   u'vermouth',
#   u'Bourbon'],
#  [u'bitter aperitif',
#   u'lemon juice',
#   u'lemon twist',
#   u'orange liqueur',
#   u'Tequila'],
#  [u'Kahlua', u'Vodka'],
#  [u'Hershey\u2019s chocolate syrup', u'Kahlua', u'Vodka'],
#  [u'cinnamon stick',
#   u'lemon peel',
#   u'orange peel',
#   u'star anise',
#   u'sugar',
#   u'wine',
#   u'Bourbon'],
#  [u'black pepper',
#   u'lemon juice',
#   u'orchid',
#   u'simple syrup',
#   u'watermelon',
#   u'Rum'],
#  [u'aloe vera juice',
#   u'fresh lemon juice',
#   u'lemon twist',
#   u'maraschino liqueur',
#   u'orange bitters',
#   u'orange twist',
#   u"Peychaud's Bitters",
#   u'pomegranate juice',
#   u'Tequila'],
#  [u'pineapple', u'pineapple juice', u'Tequila'],
#  [u'grapefruit soda', u'lime juice', u'salt', u'Tequila'],
#  [u'Angostura Bitters',
#   u'elderflower liqueur',
#   u'lime juice',
#   u'pear',
#   u'Vodka'],
#  [u'egg', u'nutmeg', u'port', u'simple syrup', u'Brandy'],
#  [u'bitters', u'ginger syrup', u'lemon juice', u'orange peel', u'Scotch'],
#  [u'ginger ale', u'Rum'],
#  [u'Amaro Montenegro', u'apple cider', u'lemon juice', u'Vodka'],
#  [u'absinthe',
#   u'lemon juice',
#   u'Lillet Blanc',
#   u'orange liqueur',
#   u'Absinthe,'],
#  [u'Angostura Bitters',
#   u'ginger liqueur',
#   u'lemon juice',
#   u'lemon twist',
#   u'Liqueurs'],
#  [u'ginger beer', u'lime', u'Bourbon'],
#  [u'Fernet-Branca', u'orange twist', u'sweet vermouth', u'Gin'],
#  [u'cherry liqueur', u'egg', u'orange juice', u'Irish'],
#  [u'', u'Rum'],
#  [u'apple juice', u'cinnamon stick', u'lemon', u'Liqueurs'],
#  [u'club soda', u'ginger ale', u'Bourbon'],
#  [u'absinthe',
#   u'lemon juice',
#   u'sparkling ros\xe9 wine',
#   u'strawberry puree',
#   u'Brandy'],
#  [u'egg white', u'lime juice', u'strawberry-rose syrup', u'Pisco'],
#  [u'cocktail onions', u'olive', u'red food dye', u''],
#  [u'absinthe', u'averna', u'oloroso sherry', u'vermouth', u'Bourbon'],
#  [u'allspice berries',
#   u'cherries',
#   u'cinnamon sticks',
#   u'juniper berries',
#   u'lemon juice',
#   u'star anise',
#   u'sugar',
#   u'water',
#   u'Brandy'],
#  [u'cucumber', u'lime juice', u'simple syrup', u'Absinthe'],
#  [u'ginger beer', u'lemon juice', u'pomegranate liqueur', u'Liqueurs,'],
#  [u'egg white',
#   u'elderflower liqueur',
#   u'lavender bitters',
#   u'lemon juice',
#   u'lemongrass',
#   u'mint',
#   u'sugar',
#   u'Gin'],
#  [u'egg', u'maple sugar', u'mint bitters', u'port', u'Irish'],
#  [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'cherry liqueur',
#   u'club soda',
#   u'Demerara sugar',
#   u'lemon',
#   u'lemon juice',
#   u'orange bitters',
#   u'Gin'],
#  [u'agave nectar',
#   u'jalape\xf1o',
#   u'lime juice',
#   u'mango nectar',
#   u'orange bitters',
#   u'Vodka'],
#  [u'grapefruit soda', u'lime juice', u'sale', u'Tequila'],
#  [u"Dale DeGroff's Pimento Bitters", u'orange peel', u'Liqueurs'],
#  [u'coffee liqueur', u'heavy cream', u'vanilla cognac', u'Tequila'],
#  [u'cranberry juice',
#   u'lime juice',
#   u'lime wheel',
#   u'orange liqueur',
#   u'Vodka'],
#  [u'Campari', u'grapefruit twist', u'sweet vermouth', u'Tequila'],
#  [u'apple cider', u'cranberries', u'gingerroot', u'lemon juice', u'Gin'],
#  [u'aperol',
#   u'cardamaro amaro',
#   u'gum syrup',
#   u'lemon juice',
#   u'lemon peel',
#   u'Gin'],
#  [u'dry vermouth', u'Kalamata olive', u'olive juice', u'Mezcal'],
#  [u'allspice',
#   u'apple',
#   u'cinnamon',
#   u'cloves',
#   u'honey',
#   u'ruby red grapefruit juice',
#   u'sweet tea',
#   u'Bourbon'],
#  [u'blueberry',
#   u'elderflower liqueur',
#   u'orange',
#   u'orange juice',
#   u'sparkling wine',
#   u'strawberry',
#   u'VeeV',
#   u'Liqueurs'],
#  [u'cr\xe8me de cacao', u'fig syrup', u'port', u'vanilla bitters', u'Bourbon'],
#  [u'dry vermouth', u'pineapple juice', u'pineapple leaf', u'Brandy'],
#  [u'absinthe',
#   u'lemon twist',
#   u"Peychaud's Bitters",
#   u'simple syrup',
#   u'Absinthe,'],
#  [u'absinthe',
#   u'aquavit',
#   u'lemon-thyme syrup',
#   u'lime juice',
#   u'maldon salt',
#   u'manzanilla sherry',
#   u'sea salt',
#   u'sugar snap peas',
#   u'verjus',
#   u'Liqueurs,'],
#  [u'Champagne',
#   u'cranberry juice',
#   u'orange liqueur',
#   u'orange twist',
#   u'passion fruit juice',
#   u'passion fruit puree',
#   u'Liqueurs'],
#  [u'apple juice',
#   u'Champagne',
#   u'lemon',
#   u'lemonade',
#   u'sugar',
#   u'tea',
#   u'thistle',
#   u'Scotch'],
#  [u'apple cider', u'fresh lemon juice', u'lemon wedge', u'Scotch'],
#  [u'cream of coconut',
#   u'cr\xe8me de banane',
#   u'peanut rum cr\xe8me liqueur',
#   u'pineapple',
#   u'pineapple juice',
#   u'Rum'],
#  [u'cream', u'Galliano', u'orange juice', u'orange liqueur', u'Liqueurs'],
#  [u'agave nectar',
#   u'elderflower liqueur',
#   u'lime juice',
#   u'sparkling wine',
#   u'thyme',
#   u'Vodka'],
#  [u'blood orange', u'ginger ale', u'maraschino liqueur', u'wine', u'Brandy'],
#  [u'club soda', u'grape', u'simple syrup', u'wine', u'Brandy'],
#  [u'brandied cherry',
#   u'club soda',
#   u'tamarind syrup',
#   u'vanilla liqueur',
#   u'Bourbon'],
#  [u'Angostura Bitters', u'ginger ale', u'Rum'],
#  [u'agave nectar', u'coconut water', u'ginger', u'lemon juice', u''],
#  [u'brown sugar',
#   u'butter',
#   u'caramel vodka',
#   u'cinnamon',
#   u'clove',
#   u'honey',
#   u'nutmeg',
#   u'Rum,'],
#  [u'agave nectar', u'cucumber', u'lime', u'water', u'Tequila'],
#  [u'7UP',
#   u'Angostura Bitters',
#   u'cherry',
#   u'orange',
#   u'Sprite',
#   u'sugar',
#   u'Brandy'],
#  [u'Baileys', u'candy cane', u'cr\xe8me de menthe', u'milk', u'Vodka'],
#  [u'maraschino cherry', u'maraschino liqueur', u'Punt e Mes', u'Rye'],
#  [u'black pepper',
#   u'celesalt',
#   u'cucumber',
#   u'horseradish',
#   u'jalape\xf1o pepper',
#   u'lemon',
#   u'lemon juice',
#   u'lime',
#   u'queso fresco',
#   u'sweet pepper',
#   u'Tabasco Sauce',
#   u'Tapatio Hot Sauce',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Tequila'],
#  [u'basil', u'lemon peel', u'lemonade', u'simple syrup', u'Vodka'],
#  [u'Champagne', u'cranberry juice', u'raspberry', u'Vodka'],
#  [u'Amaro Nonino',
#   u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'oloroso sherry',
#   u'orange bitters',
#   u'red wine',
#   u'wine',
#   u'Bourbon'],
#  [u'cranberry', u'sparkling cider', u'tonic water', u'Vodka'],
#  [u'Aliz\xe9', u'Champagne', u'passion fruit puree', u'simple syrup', u''],
#  [u'Champagne',
#   u'club soda',
#   u'elderflower liqueur',
#   u'lemon twist',
#   u'wine',
#   u'Liqueurs'],
#  [u'club soda',
#   u'grenadine',
#   u'lemon juice',
#   u'orange peel',
#   u'pineapple juice',
#   u'Cacha\xe7a'],
#  [u"creme d'framboise",
#   u'grapefruit peel',
#   u'grapefruit soda',
#   u'lime juice',
#   u'sugar syrup',
#   u'Suze',
#   u'Liqueurs,'],
#  [u'agave nectar',
#   u'honey sugar',
#   u'lime juice',
#   u'mint',
#   u'serrano chile',
#   u'simple syrup',
#   u'watermelon',
#   u'Liqueurs'],
#  [u'lemon juice', u'lemon peel', u'pomegranate juice', u'port', u'Japanese'],
#  [u'club soda', u'lime', u'mint', u'Liqueurs'],
#  [u'bitters', u'grapefruit peel', u'Purely Syrup Grapefruit', u'Absinthe,'],
#  [u'absinthe',
#   u"boker's bitters",
#   u'femet branca',
#   u'lemon oils',
#   u'lime juice',
#   u'oloroso sherry',
#   u'orgeat',
#   u'rosemary',
#   u'Rye'],
#  [u'absinthe',
#   u'Angostura Bitters',
#   u'cherry',
#   u'maraschino liqueur',
#   u'orange',
#   u'simple syrup',
#   u'Bourbon'],
#  [u'Angostura Bitters',
#   u'dark maple syrup',
#   u'pineapple juice',
#   u'yuzu juice',
#   u'Rye'],
#  [u'chardonnay',
#   u'club soda',
#   u'hibiscus',
#   u'pomegranate',
#   u'rose petals',
#   u'simple syrup',
#   u'tarragon',
#   u'Liqueurs'],
#  [u'B\xe9n\xe9dictine',
#   u'bitters',
#   u'cherry vodka',
#   u'lemon juice',
#   u'simple syrup',
#   u'Vodka'],
#  [u'lime',
#   u'lime juice',
#   u'orange liqueur',
#   u'salt',
#   u'simple syrup',
#   u'Tequila'],
#  [u'club soda',
#   u'cucumber',
#   u'elderflower liqueur',
#   u'lime juice',
#   u'mint',
#   u'simple syrup',
#   u'Rum'],
#  [u'heavy cream', u'Kahlua', u'Vodka'],
#  [u'almond extract',
#   u'Angostura Bitters',
#   u'cinnamon syrup',
#   u'fresh lemon juice',
#   u'Fresh pineapple juice',
#   u'tiki bitters',
#   u'Rum,'],
#  [u'aperol', u'sweet vermouth', u'whiskey barrel-aged bitters', u'Liqueurs,'],
#  [u'Four Roses Yellow Label Bourbon',
#   u'Luxardo Bitter Liqueur',
#   u'Pistachio-infused Oloroso sherry*',
#   u'rhubarb bitters',
#   u'Liqueurs'],
#  [u'Angostura Bitters',
#   u'ginger beer',
#   u'lime',
#   u'lime juice',
#   u'orange liqueur',
#   u'Liqueurs'],
#  [u'cinnamon stick',
#   u'cranberry',
#   u'melon',
#   u'melon liqueur',
#   u'pear',
#   u'pear juice',
#   u'pear liqueur',
#   u'white cranberry juice',
#   u'Liqueurs,'],
#  [u'lemon', u'mint', u'vanilla liqueur', u'Liqueurs'],
#  [u'Oleo saccharum sour mix', u'Gin,'],
#  [u'bitters',
#   u'club soda',
#   u'honey',
#   u'honeydew melon',
#   u'lemon juice',
#   u'tarragon',
#   u'Yellow Chartreuse',
#   u'Gin'],
#  [u'absinthe', u'anisette', u'Absinthe'],
#  [u'club soda', u'lemon', u'lemon juice', u'simple syrup', u'Gin'],
#  [u'blue cheese-stuffed olive',
#   u'celery',
#   u'celery salt',
#   u'hot sauce',
#   u'lime',
#   u'tomato juice',
#   u'wasabi',
#   u'Worcestershire sauce',
#   u'Bourbon'],
#  [u'Averna Amaro', u'honey', u'lemon juice', u'Bourbon'],
#  [u'absinthe', u'lemon juice', u'mint leaves', u'seltzer', u'Tequila,'],
#  [u'chocolate bitters', u'maraschino cherry', u'sherry', u'Rye'],
#  [u'martini bianco', u'orange bitters', u''],
#  [u'bacon', u'egg', u'lemon juice', u'maple syrup', u'orange juice', u'Irish'],
#  [u'cucumber peel',
#   u'ginger',
#   u'lemon-flavored club soda',
#   u'lime peel',
#   u'Brandy'],
#  [u'dry curacao',
#   u'dry vermouth',
#   u'peach liqueur',
#   u"regan's orange bitters no. 6",
#   u'Vodka'],
#  [u'amaretto',
#   u'Baileys',
#   u'caramel sauce',
#   u'chocolate liqueur',
#   u'chocolate sauce',
#   u'cream',
#   u'Liqueurs,'],
#  [u'apple',
#   u'lemon juice',
#   u'rhubarb juice',
#   u'rosemary',
#   u'simple syrup',
#   u'Vodka'],
#  [u'', u''],
#  [u'aperol', u'Cherry Heering', u'lemon juice', u'Mezcal,'],
#  [u'honey syrup', u'lemon juice', u'Gin'],
#  [u'agave nectar', u'lime', u'lime juice', u'salt', u'Tequila'],
#  [u'apple liqueur',
#   u'ginger',
#   u'lime juice',
#   u'maraschino liqueur',
#   u'pineapple',
#   u'pineapple leaf',
#   u'sugar',
#   u'Rum'],
#  [u'fresh lemon juice',
#   u'Hakkaisan Premium Japanese Sake',
#   u'Kirsch Soaked Griotte Cherry',
#   u'Sakura Liqueur',
#   u''],
#  [u'', u'Gin'],
#  [u'dry vermouth',
#   u'lemon juice',
#   u'simple syrup',
#   u'sugar snap peas',
#   u'tarragon',
#   u'Gin'],
#  [u'club soda', u'maraschino cherry', u'orange', u'sugar', u'Bourbon'],
#  [u'lime juice',
#   u'orange liqueur',
#   u'pomegranate',
#   u'pomegranate juice',
#   u'Tequila'],
#  [u'dark maple syrup', u'pineau des charentes', u'walnut liqueur', u'Bourbon'],
#  [u'benne seeds',
#   u'clement creole shrubb orange liqueur',
#   u'dr. adam elmegirab dandelion and burdock bitters',
#   u'lemon juice',
#   u'turbinado sugar',
#   u'Rum'],
#  [u'brandied cherry',
#   u'lemon juice',
#   u'lemon twist',
#   u'orange Cura\xe7ao',
#   u'orange twist',
#   u'sweet vermouth',
#   u'triple sec',
#   u'Bourbon'],
#  [u'a\xe7a\xed sugar',
#   u'agave nectar',
#   u'mint',
#   u'orange juice',
#   u'simple syrup',
#   u'Liqueurs'],
#  [u'Champagne', u'peach puree', u'Vodka'],
#  [u'club soda',
#   u'ginger',
#   u'ginger syrup',
#   u'lime juice',
#   u'raspberry',
#   u'raspberry syrup',
#   u'Gin'],
#  [u'amaro',
#   u'Averna Limoni',
#   u'basil',
#   u'blood orange',
#   u'blood orange juice',
#   u'club soda',
#   u'egg white',
#   u'lime juice',
#   u'Liqueurs'],
#  [u'cardamom pods',
#   u'cucumber',
#   u'Green Chartreuse',
#   u'lemon juice',
#   u'mint',
#   u'simple syrup',
#   u'Gin'],
#  [u'allspice liqueur',
#   u'Angostura Bitters',
#   u'cherry',
#   u'honey',
#   u'lime juice',
#   u'nutmeg',
#   u'Scotch'],
#  [u'apple',
#   u'apple juice',
#   u'lemon',
#   u'orange liqueur',
#   u'simple syrup',
#   u'triple sec',
#   u'Gin'],
#  [u'Angostura Bitters',
#   u'Fresh lime juice',
#   u'Fresh pineapple juice',
#   u'honey syrup',
#   u'mint sprig',
#   u'pilsner',
#   u'Liqueurs,'],
#  [u'egg white', u'lemon juice', u'simple syrup', u'Bourbon'],
#  [u'absinthe',
#   u'egg white',
#   u'lime juice',
#   u'nutmeg',
#   u"Peychaud's Bitters",
#   u'simple syrup',
#   u'Absinthe,'],
#  [u'bitters',
#   u'maple syrup',
#   u'orange bitters',
#   u'orange liqueur',
#   u'orange twist',
#   u'Punt e Mes',
#   u'Rye'],
#  [u'cherries',
#   u'cherry liqueur',
#   u'cilantro',
#   u'lime juice',
#   u'passion fruit puree',
#   u'simple syrup',
#   u'Sriracha',
#   u'Cacha\xe7a'],
#  [u'Campari', u'club soda', u'grenadine', u'lemon juice', u'Rye'],
#  [u'brandy',
#   u'orange flower water',
#   u'roasted hazelnut',
#   u'sugar',
#   u'water',
#   u'Brandy'],
#  [u'', u'Liqueurs'],
#  [u'Champagne',
#   u'grapefruit juice',
#   u'lemon juice',
#   u'orange bitters',
#   u'orange liqueur',
#   u'Tequila'],
#  [u'lemon juice',
#   u'Marie Brizard Orange Cura\xe7ao',
#   u'Pistachio syrup*',
#   u'simple syrup',
#   u'Brandy'],
#  [u'blue Cura\xe7ao',
#   u'Champagne',
#   u'cherry',
#   u'lemon',
#   u'lime juice',
#   u'mint',
#   u'orange',
#   u'Tequila'],
#  [u'cointreau', u'lime', u'lime juice', u'orange liqueur', u'sugar', u'Rum'],
#  [u'bitter liqueur', u'orange twist', u'sweet vermouth', u'Gin'],
#  [u'Baileys Original Irish Cream',
#   u'brown sugar',
#   u'chai tea',
#   u'cinnamon stick',
#   u'Liqueurs'],
#  [u'chile pepper',
#   u'coconut milk',
#   u'lime juice',
#   u'orange liqueur',
#   u'pineapple juice',
#   u'pineapple leaf',
#   u'Rum'],
#  [u'Angostura Bitters',
#   u"regan's orange bitters no. 6",
#   u'vermouth',
#   u'Bourbon'],
#  [u'cayenne pepper',
#   u'chili powder',
#   u'lemon juice',
#   u'maple syrup',
#   u'Pisco'],
#  [u'blood orange liqueur',
#   u'lemon juice',
#   u'Lillet Rouge',
#   u'maraschino cherry',
#   u'orange',
#   u'orange bitters',
#   u'pink grapefruit juice',
#   u'Scotch'],
#  [u'lime syrup', u'orchid', u'simple syrup', u'strawberry', u'Rum'],
#  [u'apple cider',
#   u'bitters',
#   u'cinnamon',
#   u'fresh lemon juice',
#   u'honey syrup',
#   u'Gin'],
#  [u'cherry', u'coconut milk', u'pineapple', u'pineapple juice', u'Rum'],
#  [u'club soda', u'Scotch'],
#  [u'egg white',
#   u'lavender simple syrup',
#   u'lemon juice',
#   u'peach shrub',
#   u'Gin'],
#  [u'Angostura Bitters',
#   u'club soda',
#   u'elderflower liqueur',
#   u'orange peel',
#   u'Bourbon'],
#  [u'aperol',
#   u'grapefruit peel',
#   u'lemon',
#   u'simple syrup',
#   u'Thai basil',
#   u'Bourbon'],
#  [u'Green Chartreuse',
#   u'lime juice',
#   u'maraschino liqueur',
#   u'pineapple',
#   u'Mezcal'],
#  [u'orange', u'orange juice', u'sparkling wine', u'Vodka'],
#  [u'cayenne pepper',
#   u'lime',
#   u'lime juice',
#   u'orange liqueur',
#   u'simple syrup',
#   u'triple sec',
#   u'Rum'],
#  [u'brown sugar', u'coffee', u'cream', u'Irish'],
#  [u'cherry', u'lime twist', u'orange bitters', u'sweet vermouth', u'Tequila'],
#  [u'coffee',
#   u'coffee beans',
#   u'Demerara sugar',
#   u'lime juice',
#   u'pineapple',
#   u'pineapple juice',
#   u'sugar',
#   u'Rum'],
#  [u'lemon', u'lemonade', u'Gin'],
#  [u'calvados',
#   u'cardamom',
#   u'cinnamon stick',
#   u'clove',
#   u'egg white',
#   u'falernum',
#   u'lemon juice',
#   u'nutmeg',
#   u'orgeat',
#   u'star anise',
#   u'sugar',
#   u'Brandy'],
#  [u'Champagne', u'Absinthe'],
#  [u'', u'Bourbon'],
#  [u'Drambuie', u'Scotch'],
#  [u'Dale DeGroff Pimento Bitters',
#   u'ginger root',
#   u'kumquats',
#   u'lime juice',
#   u'Rhum Clement Creole Shrub',
#   u'superfine sugar',
#   u'Tequila'],
#  [u'bitters',
#   u'lemon',
#   u'lime',
#   u'maraschino cherry',
#   u'orange',
#   u'sweet vermouth',
#   u'Bourbon'],
#  [u'burnt rosemary',
#   u'chamomile dust',
#   u'egg white',
#   u'fresh lemon juice',
#   u'turbinado sugar',
#   u'Gin'],
#  [u'brown sugar',
#   u'chocolate liqueur',
#   u'cinnamon',
#   u'habanero',
#   u'milk',
#   u'pistachio',
#   u'whipped cream',
#   u'Rum'],
#  [u'almond milk', u'egg white', u'lemon juice', u'Gin'],
#  [u'lemon juice', u'Lemon-lime soda', u'simple syrup', u'Vodka'],
#  [u'cranberry juice', u'lime', u'lime juice', u'orange liqueur', u'Vodka'],
#  [u'ancho chile powder',
#   u'apple',
#   u'apple cider',
#   u'cinnamon',
#   u'ginger beer',
#   u'lemon juice',
#   u'nutmeg',
#   u'sugar',
#   u'Mezcal,'],
#  [u'cardamom pods',
# ...
#  [u'Stiegl Radler Grapefruit Beer', u'strawberrry-infused aperol', u'Gin'],
#  [u'Champagne', u'lemon juice', u'Pear puree', u'Gin'],
#  [u'agave nectar',
#   u'chai tea',
#   u'lemon juice',
#   u'mint',
#   u'strawberry',
#   u'Vodka'],
#  [u'agave nectar', u'club soda', u'lime', u'mint', u'Rum'],
#  [u'apple bitters', u'apple cider', u'lemon peel', u'Scotch'],
#  [u'dry vermouth', u'olive', u'olive brine', u'Gin,'],
#  [u'cilantro',
#   u'honey',
#   u'lime',
#   u'lime juice',
#   u'red bell pepper juice',
#   u'Tequila'],
#  [u'bitters',
#   u'dry vermouth',
#   u'honey syrup',
#   u'orange twist',
#   u'sweet vermouth',
#   u'Rum,'],
#  [u'almond',
#   u'brown sugar',
#   u'cardamom',
#   u'cinnamon',
#   u'clove',
#   u'dried fig',
#   u'long pepper',
#   u'orange',
#   u'port',
#   u'raisin',
#   u'star anise',
#   u'wine',
#   u'Vodka'],
#  [u'lime', u'lime juice', u'simple syrup', u'Gin'],
#  [u'bitters', u'orange peel oil', u'Brandy'],
#  [u'egg', u'heavy cream', u'nutmeg', u'sugar', u'Rum'],
#  [u'Angostura Bitters', u'cava', u'sparklins wine', u'sugar', u'Rum'],
#  [u'B\xc3\xa9n\xc3\xa9dictine',
#   u'golden apple',
#   u'honey syrup',
#   u'lemon juice',
#   u'Brandy'],
#  [u'Champagne', u'cucumber', u'mint', u"Pimm's No. 1", u'Liqueurs'],
#  [u'grenadine', u'pastis', u'water', u''],
#  [u'Champagne',
#   u'orange juice',
#   u'raspberry',
#   u'raspberry liqueur',
#   u'Liqueurs'],
#  [u'black pepper', u'Vodka'],
#  [u'absinthe', u'edible flower', u'genepy', u'mezcal', u'Soju'],
#  [u'Angostura Bitters',
#   u'apple',
#   u'apple brandy',
#   u'cinnamon',
#   u'maple syrup',
#   u'sloe gin',
#   u'wine',
#   u'Brandy'],
#  [u'Becherovka', u'lime juice', u'peach nectar', u'simple syrup', u'Tequila'],
#  [u'black pepper',
#   u'celery',
#   u'celery bitters',
#   u'cocktail onion',
#   u'ginger',
#   u'lemon',
#   u'lemon juice',
#   u'Maggi Seasoning',
#   u'olive',
#   u'sea salt',
#   u'sriracha hot sauce',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Vodka'],
#  [u'Champagne', u'Dubonnet Rouge', u'lemon twist', u'Vermouth'],
#  [u'club soda',
#   u'lemon juice',
#   u'maraschino cherry',
#   u'orange',
#   u'sugar',
#   u'Bourbon'],
#  [u'absinthe',
#   u'bitters',
#   u'Green Chartreuse',
#   u'orange bitters',
#   u'orange twist',
#   u'sweet vermouth',
#   u'Irish'],
#  [u'kumquats',
#   u'lemon uice',
#   u'Luxardo Maraschino Liqueur',
#   u'nutmeg',
#   u'powdered sugar',
#   u'Gin'],
#  [u'cherry',
#   u'cranberry juice',
#   u'orange liqueur',
#   u'pineapple juice',
#   u'triple sec',
#   u'Vodka'],
#  [u'concord grape jelly',
#   u'concord grape juice',
#   u'lemon juice',
#   u'smoked salt',
#   u'Tequila'],
#  [u'agave nectar', u'blueberry', u'lemon', u'thyme', u'Vodka'],
#  [u'fresh lemon juice',
#   u'orange bitters',
#   u'pomegranate syrup',
#   u'raspberry liqueur',
#   u'Gin'],
#  [u'', u'Vodka'],
#  [u'cr\xe8me de cassis', u'pineapple juice', u'Vodka'],
#  [u'cream', u'cr\xe8me de cacao', u'nutmeg', u'Brandy'],
#  [u'dry vemouth', u'grenadine', u'orange liqueur', u'Rum,'],
#  [u'cucumber', u"Pimm's No. 1", u'Sprite', u'Gin'],
#  [u'orange juice', u'peach schnapps', u'Liqueurs'],
#  [u'cranberry juice', u'ginger ale', u'Canadian'],
#  [u'club soda',
#   u'cucumber',
#   u'elderflower liqueur',
#   u'lemon juice',
#   u'lemon zest',
#   u'lemonade',
#   u'mint',
#   u'simple syrup',
#   u'Vodka'],
#  [u'B\xe9n\xe9dictine', u'cinnamon stick', u'milk', u'orange', u'Liqueurs'],
#  [u'Aveze Gentian Liqueur',
#   u'lemon peel',
#   u'Luxardo Maraschino Liqueur',
#   u'manzanilla sherry',
#   u'tarragon',
#   u'Liqueurs,'],
#  [u'Fresh pineapple juice',
#   u'juice from brandied cherries',
#   u'mint leaves',
#   u'mint sprig',
#   u'Rye'],
#  [u'absinthe',
#   u'Canadian whisky',
#   u'dry vermouth',
#   u'orange',
#   u'orange bitters',
#   u'simple syrup',
#   u'sweet vermouth',
#   u'Absinthe,'],
#  [u'ginger liqueur', u'honey', u'lavender', u'lemon juice', u'Bourbon'],
#  [u"Demitri's Bloody Mary Seasoning",
#   u'fennel',
#   u'lemon',
#   u'lemon juice',
#   u'pink peppercorn',
#   u'sea salt',
#   u'shrimp',
#   u'tomato juice',
#   u'Vodka'],
#  [u'absinthe',
#   u'Angostura Bitters',
#   u'butter',
#   u'club',
#   u'lemon',
#   u'lime juice',
#   u'mint',
#   u'pineapple',
#   u'pineapple juice',
#   u'soda',
#   u'sugar',
#   u'Rum'],
#  [u'amaretto',
#   u'cherry',
#   u'orange',
#   u'orange juice',
#   u'sloe gin',
#   u'Southern Comfort',
#   u'Liqueurs'],
#  [u'cranberry juice', u'grapefruit juice', u'lime', u'Vodka'],
#  [u'armagnac', u'lemon', u'lemon juice', u'nutmeg', u'Brandy'],
#  [u'fee brothers rhubarb bitters',
#   u'fresh lemon juice',
#   u'fresh mango puree',
#   u'simple syrup',
#   u'Gin'],
#  [u'ginger beer', u'grapefruit', u'mint', u'Gin'],
#  [u'celery',
#   u'horseradish',
#   u'hot sauce',
#   u'lemon juice',
#   u'olive',
#   u'pepper',
#   u'salt',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Vodka'],
#  [u'chocolate liqueur',
#   u'coffee liqueur',
#   u'crushed red pepper',
#   u'whipped cream',
#   u'Liqueurs,'],
#  [u'ginger beer', u'lime', u'lime juice', u'Vodka'],
#  [u'cr\xe8me de menthe',
#   u'dried angelica root',
#   u'dry vermouth',
#   u'Everclear',
#   u'Mezcal'],
#  [u'cherry vodka', u'club soda', u'lemon juice', u'simple syrup', u'Vodka'],
#  [u'Campari', u'orange', u'sweet vermouth', u'Gin,'],
#  [u'Galliano', u'orange', u'orange juice', u'Vodka'],
#  [u'apple brandy',
#   u'calvados',
#   u'dry vermouth',
#   u'Dubonnet Rouge',
#   u'orange peel',
#   u'Brandy'],
#  [u'Angostura Bitters',
#   u'lemon juice',
#   u"Peychaud's Bitters",
#   u'simple syrup',
#   u'Bourbon'],
#  [u'mint', u'peach liqueur', u'wine', u'Liqueurs'],
#  [u'lime', u'sugar', u'Cacha\xe7a'],
#  [u'lemon juice',
#   u'orange liqueur',
#   u'pomegranate liqueur',
#   u'sugar',
#   u'triple sec',
#   u'Brandy'],
#  [u'fresh lemon juice', u'grenadine', u'lemon juice', u'Bourbon'],
#  [u'fig',
#   u'lemon',
#   u'lemon juice',
#   u'orange peel',
#   u'sparkling wine',
#   u'sugar',
#   u'tea',
#   u'Vodka'],
#  [u'cucumber', u'lime juice', u'mint', u'simple syrup', u'Vodka'],
#  [u'apple',
#   u'apple juice',
#   u'cinnamon sticks',
#   u'cloves',
#   u'club soda',
#   u'lemon juice',
#   u'nutmeg',
#   u'pumpkin seeds',
#   u'sugar',
#   u'Rum'],
#  [u'lemon peel', u'Lillet Blanc', u'Gin,'],
#  [u'Champagne',
#   u'orange juice',
#   u'orange liqueur',
#   u'strawberry',
#   u'Liqueurs'],
#  [u'vanilla vodka', u'Liqueurs,'],
#  [u'cardamaro',
#   u'Fresh lime juice',
#   u'ginger syrup',
#   u'nutmeg',
#   u'orinoco bitters',
#   u'tamarind chutney',
#   u'vanilla soda',
#   u'Irish'],
#  [u'ginger ale', u'white grape juice', u'Vodka'],
#  [u'Amaro Nonino',
#   u'Angostura Bitters',
#   u'bitters',
#   u'honey',
#   u'lemon juice',
#   u'rosemary',
#   u'star anise',
#   u'Gin'],
#  [u'honey',
#   u'lemon juice',
#   u'orange juice',
#   u'star anise powder',
#   u'triple sec',
#   u'water',
#   u'Vodka'],
#  [u'iced tea', u'lemon', u'lemonade', u'spiced rum', u'Rum'],
#  [u'fermented concord grape soda',
#   u'lime juice',
#   u'simple syrup',
#   u'vermouth',
#   u'Gin'],
#  [u'', u'Vodka'],
#  [u'Angostura Bitters',
#   u'apple',
#   u'hard cider',
#   u'lime juice',
#   u'nutmeg',
#   u'pear juice',
#   u'sugar',
#   u'vanilla bean',
#   u'Vodka'],
#  [u'grapefruit juice', u'orange juice', u'Gin'],
#  [u'berries', u'club soda', u'raspberry liqueur', u'Vodka'],
#  [u'Angostura Bitters',
#   u'Champagne',
#   u'lime',
#   u'lime juice',
#   u'mint',
#   u'simple syrup',
#   u'Mezcal'],
#  [u'absinthe', u'lemon twist', u'rhubarb amaro', u'sweet vermouth', u'Rye'],
#  [u'cherry', u'cranberry juice', u'orange liqueur', u'triple sec', u'Vodka'],
#  [u'lemon juice', u'orange peel', u'triple sec', u'Brandy'],
#  [u'Angostura Bitters',
#   u'lime juice',
#   u'orange bitters',
#   u'orange Cura\xe7ao',
#   u'Gin'],
#  [u'egg white',
#   u'lime juice',
#   u'maraschino liqueur',
#   u'nutmeg',
#   u'simple syrup',
#   u'Rum'],
#  [u'Angostura Bitters',
#   u'cherry bitters',
#   u'Cherry Heering',
#   u'orange juice',
#   u'sweet vermouth',
#   u'Brandy'],
#  [u'La Boite 37 Spice and Salt Blend',
#   u'lime juice',
#   u'Pok Pok Pineapple Drinking Vinegar',
#   u'Beer,'],
#  [u'basil', u'lime juice', u'simple syrup', u'Liqueurs'],
#  [u'basil', u'cucumber', u'lemonade', u'lime', u'lime juice', u'Vodka'],
#  [u'bitters', u'lemon peel', u'simple syrup', u'Bourbon'],
#  [u'bitters',
#   u'dry vermouth',
#   u'egg white',
#   u'lemon juice',
#   u'rhubarb',
#   u'sugar',
#   u'Gin'],
#  [u'lemon juice',
#   u'maple syrup',
#   u'nutmeg',
#   u'pear fan',
#   u'seltzer',
#   u'spiced pear liqueur',
#   u'Vodka'],
#  [u'dry vermouth',
#   u'Green Chartreuse',
#   u'lime juice',
#   u'mint leaves',
#   u'Pea Shrub',
#   u'Tequila'],
#  [u'ginger juice', u'prosecco', u'strawberry', u''],
#  [u'lemon',
#   u'lemon juice',
#   u'orange juice',
#   u'pom wonderful',
#   u'pomegranate juice',
#   u'Bourbon'],
#  [u'amaro',
#   u'lime juice',
#   u'mineral water',
#   u'orange bitters',
#   u'orange peel',
#   u'velvet falernum',
#   u'Liqueurs,'],
#  [u'lemon twist', u'Gin,'],
#  [u'amaretto',
#   u'grape',
#   u'lemon',
#   u'lemon juice',
#   u'white grape juice',
#   u'Vodka'],
#  [u'club soda',
#   u'ginger simple syrup',
#   u'lemon juice',
#   u'Yellow Chartreuse',
#   u'Vodka'],
#  [u'Hibiscus iced tea', u'mint', u'passion fruit iced tea', u'Rum'],
#  [u'cranberry juice',
#   u'lemon',
#   u'orange juice',
#   u'simple syrup',
#   u'triple sec',
#   u'Bourbon'],
#  [u'allspice liqueur',
#   u'apple',
#   u'apple cider',
#   u'pear brandy',
#   u'sherry',
#   u'Rum'],
#  [u'lemon juice', u'ros\xe9 sparkling wine', u'simple syrup', u'Tequila'],
#  [u'absinthe',
#   u'Angostura Bitters',
#   u'lemon peel',
#   u'orange liqueur',
#   u'simple syrup',
#   u'Gin'],
#  [u'brandied cherries', u'grenadine', u'lemon juice', u'sherry', u'Tequila'],
#  [u'black pepper',
#   u'celery salt',
#   u'horseradish',
#   u'lemon',
#   u'lime juice',
#   u'Tabasco Sauce',
#   u'tomato',
#   u'tomato juice',
#   u'Worcestershire sauce',
#   u'Tequila'],
#  [u'amaro', u'blackberry', u'ginger beer', u'Meyer lemon', u'Liqueurs,'],
#  [u'absinthe',
#   u'grapefruit juice',
#   u'grapefruit twise',
#   u'lemon juice',
#   u'Lillet Blanc',
#   u'orange marmalade',
#   u'Absinthe,'],
#  [u'club soda', u'lime juice', u'mint', u'simple syrup', u'Vodka'],
#  [u'black pepper',
#   u'grapefruit juice',
#   u'hot sauce',
#   u'jalape\xf1o',
#   u'lime juice',
#   u'orange juice',
#   u'salt',
#   u'Tabasco Sauce',
#   u'tomato juice',
#   u'Tequila'],
#  [u'amaro',
#   u'Amaro Montenegro',
#   u'Giffard Banane du Br\xe9sil Liqueur',
#   u'Hella Bitter Aromatic bitters',
#   u'lemon juice',
#   u'orange twist',
#   u'Cacha\xe7a'],
#  [u'B\xe9n\xe9dictine', u'dry vermouth', u'lime juice', u'Liqueurs,'],
#  [u'corn syrup',
#   u'cr\xe8me de violette',
#   u'gelatin',
#   u'ginger liqueur',
#   u'orange liqueur',
#   u'sugar',
#   u'Liqueurs'],
#  [u'', u'Bourbon'],
#  [u'dry vermouth', u'sweet vermouth', u'Gin'],
#  [u'Angostura Bitters',
#   u'egg white',
#   u'lemon juice',
#   u'orange juice',
#   u'simple syrup',
#   u'Bourbon'],
#  [u'egg white',
#   u'heavy cream',
#   u'honey',
#   u'lavender blossom',
#   u'Square One Botanical Spirit',
#   u'Vodka'],
#  [u'Cholula hot sauce',
#   u'grapefruit juice',
#   u'jalape\xf1o',
#   u'lime juice',
#   u'orange juice',
#   u'Pinch Smoked paprika',
#   u'Pinch White pepper',
#   u'salt',
#   u'Tabasco hot sauce',
#   u'tomato juice',
#   u'Non-alcoholic'],
#  [u'Angostura Bitters', u'carpano vermouth', u'dry vermouth', u'Bourbon'],
#  [u'apple',
#   u'apple juice',
#   u'bitters',
#   u'elderflower cordial',
#   u'lemon juice',
#   u'simple syrup',
#   u'Bourbon'],
#  [u'apple',
#   u'Dubonnet Rouge',
#   u'maraschino liqueur',
#   u'sweet vermouth',
#   u'Gin,'],
#  [u'blackberries',
#   u'concord grapes',
#   u'egg white',
#   u'lemon juice',
#   u'Liqueurs,'],
#  [u'grapefruit juice', u'lemon juice', u'Pamplemousse Rose Liqueur', u'Vodka'],
#  [u'apricot preserves',
#   u'bitters',
#   u'cara cara orange juice',
#   u'cara cara orange twist',
#   u'cherry',
#   u'egg white',
#   u'Fee Brothers Whiskey Barrel Aged Bitters',
#   u'lemon juice',
#   u'oloroso sherry',
#   u'orange juice',
#   u'orange twist',
#   u'Bourbon'],
#  [u'egg white', u'lemon juice', u'red wine', u'simple syrup', u'Rye'],
#  [u'lemon peel', u'maraschino liqueur', u'pineau des charentes', u'Gin'],
#  [u'Angostura Bitters', u'Punt e Mes', u'vermouth', u'Bourbon'],
#  [u'chocolate liqueur',
#   u'cream',
#   u'cr\xe8me de menthe',
#   u'Peppermint Pattie',
#   u'Vodka'],
#  [u'lemon twist', u'lime juice', u'simple syrup', u'triple sec', u'Rum'],
#  [u'cilantro', u'lemon juice', u'simple syrup', u'Non-alcoholic'],
#  [u'Chambord', u'honeydew', u'lemonade', u'raspberry liqueur', u'Vodka'],
#  [u'7UP', u'peppermint schnapps', u'raspberry liqueur', u'Gin'],
#  [u'lime', u'orange liqueur', u'pomegranate juice', u'Tequila'],
#  [u'Campari', u'raspberries', u'sloe gin', u'Gin'],
#  [u'dry vermouth', u'lemon twist', u'orange bitters', u'Gin'],
#  [u'agave nectar', u'blood orange', u'Champagne', u'orange twist', u'Rum'],
#  [u'apple',
#   u'apple juice',
#   u'cinnamon',
#   u'cranberry juice',
#   u'sugar',
#   u'tea',
#   u'Gin'],
#  [u'lemon', u'mint', u'orange liqueur', u'Liqueurs'],
#  [u'dry vermouth', u'lemon peel', u'olive', u'orange bitters', u'Gin,'],
#  [u'blanc vermouth',
#   u'cardamom bitters',
#   u'concord grapes',
#   u'vermont maple syrup',
#   u'Brandy'],
#  [u'Angostura Bitters',
#   u'B\xe9n\xe9dictine',
#   u'orange bitters',
#   u'orange slice',
#   u'Irish'],
#  [u'club soda',
#   u'honey syrup',
#   u'lemon juice',
#   u'pear liqueur',
#   u'Pear puree',
#   u'Gin,'],
#  [u'club soda',
#   u'dry vermouth',
#   u'grapefruit juice',
#   u'lemon juice',
#   u'lemon twist',
#   u'orange bitters',
#   u'simple syrup',
#   u'Irish'],
#  [u'grenadine', u'pineapple', u'pineapple juice', u'Vodka'],
#  [u'agave nectar', u'club soda', u'grapefruit', u'lime', u'mint', u'Tequila'],
#  [u'cayenne pepper',
#   u'club soda',
#   u'lime juice',
#   u'pineapple',
#   u'strawberry',
#   u'sugar',
#   u'watermelon',
#   u'Rum'],
#  [u'blackberry', u'dry vermouth', u'raspberry', u'Gin'],
#  [u'egg white',
#   u'ginger',
#   u'lime juice',
#   u'orange liqueur',
#   u'salt',
#   u'sugar',
#   u'Tequila'],
#  [u'Fee Brothers Whiskey Barrel Aged Bitters',
#   u'fresh lemon juice',
#   u'honey syrup',
#   u'lemon wheel',
#   u'Rye'],
#  [u'mint', u'sugar', u'water', u'Non-alcoholic'],
#  [u'absinthe',
#   u'lemon juice',
#   u'maraschino cherry',
#   u'orange bitters',
#   u'sloe gin',
#   u'sugar',
#   u'Absinthe,'],
#  [u'absinthe',
#   u'Campari',
#   u'cocoa nibs',
#   u'Giffard Banane du Br\xe9sil',
#   u'white cocoa marie brizard',
#   u'Irish'],
#  [u'agave nectar', u'lemon', u'lime', u'Tequila'],
#  [u'agave nectar', u'lime', u'lime juice', u'Gin'],
#  [u'apple butter', u'lemon juice', u'maple syrup', u'port', u'Scotch'],
#  [u'bitters',
#   u'Campari',
#   u'carpano antica',
#   u'lemon pigtail',
#   u'salt',
#   u'Gin'],
#  [u'club soda', u'lime', u'lime juice', u'maple syrup', u'Bourbon'],
#  [u'lemon juice', u'orange liqueur', u'orange peel', u'sugar', u'Brandy'],
#  [u'bitters',
#   u'calvados',
#   u'lemon juice',
#   u'rye whiskey',
#   u'sherry',
#   u'Liqueurs'],
#  [u'Angostura Bitters',
#   u'apple cider',
#   u'lemon juice',
#   u'maple syrup',
#   u'Rum'],
#  [u'Angostura Bitters', u'orange peel', u'sugar', u'Rum'],
#  [u'Champagne', u'fresh lemon juice', u'simple syrup', u'Gin'],
#  [u'coffee bitters', u'dry curacao', u'vermouth', u'Bourbon'],
#  [u'coconut water', u'lime', u'lime juice', u'simple syrup', u'Rum'],
#  [u'bitters',
#   u'cranberry',
#   u'cranberry bitters',
#   u'cranberry juice',
#   u'lemon juice',
#   u'pear',
#   u'pear liqueur',
#   u'Vodka'],
#  [u'Angostura Bitters',
#   u"B.G Reynolds Don's Spices #2",
#   u'brewed coffee',
#   u'cinnamon',
#   u'Demerara sugar',
#   u'heavy cream',
#   u'St. Elizabeth Allspice Dram',
#   u'sugar',
#   u'velvet falernum',
#   u'Rum'],
#  [u'coffee', u'Demerara sugar', u'heavy cream', u'Irish'],
#  [u'aperol', u'bitters', u'grapefruit', u''],
#  [u'', u''],
#  [u'Angostura Bitters',
#   u'apple brandy',
#   u'ginger beer',
#   u'lemon',
#   u'lemon juice',
#   u"Peychaud's Bitters",
#   u"Pimm's No. 1",
#   u'simple syrup',
#   u'Brandy'],
#  [u'dry vermouth',
#   u'orange liqueur',
#   u'orange peel',
#   u'sherry',
#   u'sugar cane syrup',
#   u'Scotch,'],
#  [u'Demerara sugar', u'lemon juice', u'lemon peel', u'lemonade', u'Rum'],
#  [u'apple',
#   u'apple cider',
#   u'baked apple bitters',
#   u'bitters',
#   u'cinnamon',
#   u'lemon juice',
#   u'velvet falernum',
#   u'Vodka'],
#  [u'dry vermouth',
#   u'grenadine',
#   u'lemon juice',
#   u'orange bitters',
#   u'Bourbon'],
#  [u'cranberry juice',
#   u'lemon',
#   u'lemonade',
#   u'VeeV A\xe7ai Spirit',
#   u'Liqueurs'],
#  [u'almond orgeat',
#   u'lime',
#   u'lime juice',
#   u'mint',
#   u'orange liqueur',
#   u'simple syrup',
#   u'Rum'],
#  [u'', u'Japanese'],
#  [u'egg white', u'lemon juice', u'raspberry simple syrup', u'Gin'],
#  ...]

# %%
cocktail_set.intersection(fen_set)
# Out:
# {u'almond',
#  u'apple',
#  u'apple brandy',
#  u'apple juice',
#  u'armagnac',
#  u'asparagus',
#  u'bacon',
#  u'banana',
#  u'basil',
#  u'beer',
#  u'beet juice',
#  u'bell pepper',
#  u'berries',
#  u'black pepper',
#  u'black tea',
#  u'blackberries',
#  u'blackberry',
#  u'blackcurrant',
#  u'blueberries',
#  u'blueberry',
#  u'bourbon',
#  u'brandy',
#  u'butter',
#  u'cardamom',
#  u'carrot',
#  u'celery',
#  u'cherry',
#  u'cherry brandy',
#  u'chocolate',
#  u'cider',
#  u'cinnamon',
#  u'clove',
#  u'cloves',
#  u'cocoa powder',
#  u'coconut',
#  u'coconut milk',
#  u'coffee',
#  u'cognac',
#  u'concord grape',
#  u'concord grapes',
#  u'coriander',
#  u'cranberry',
#  u'cream',
#  u'cucumber',
#  u'cumin',
#  u'dill',
#  u'dried fig',
#  u'egg',
#  u'eggs',
#  u'fennel',
#  u'fig',
#  u'fruit',
#  u'garlic',
#  u'gelatin',
#  u'gin',
#  u'ginger',
#  u'grape',
#  u'grapefruit',
#  u'grapefruit juice',
#  u'grapefruit peel',
#  u'green tea',
#  u'guava',
#  u'honey',
#  u'honeydew',
#  u'horseradish',
#  u'japanese',
#  u'kiwi',
#  u'kumquat',
#  u'lavender',
#  u'lemon',
#  u'lemon juice',
#  u'lemon peel',
#  u'lemongrass',
#  u'lime',
#  u'lime juice',
#  u'mandarin',
#  u'mango',
#  u'maple syrup',
#  u'melon',
#  u'milk',
#  u'mint',
#  u'nutmeg',
#  u'olive',
#  u'olive oil',
#  u'olives',
#  u'orange',
#  u'orange juice',
#  u'orange peel',
#  u'orange peel oil',
#  u'oregano',
#  u'oysters',
#  u'parsley',
#  u'passion fruit',
#  u'passion fruit juice',
#  u'peach',
#  u'peanut',
#  u'peanut butter',
#  u'pear',
#  u'pear brandy',
#  u'pepper',
#  u'pineapple',
#  u'plum',
#  u'port',
#  u'pumpkin',
#  u'raisin',
#  u'raspberry',
#  u'raspberry brandy',
#  u'red wine',
#  u'rhubarb',
#  u'roasted hazelnut',
#  u'rosemary',
#  u'rum',
#  u'rye',
#  u'sage',
#  u'sake',
#  u'scotch',
#  u'sherry',
#  u'shrimp',
#  u'soy sauce',
#  u'sparkling wine',
#  u'star anise',
#  u'star fruit',
#  u'starfruit',
#  u'strawberry',
#  u'strawberry juice',
#  u'tamarind',
#  u'tangerine',
#  u'tangerine juice',
#  u'tarragon',
#  u'tea',
#  u'tequila',
#  u'thyme',
#  u'tomato',
#  u'tomato juice',
#  u'vanilla bean',
#  u'vanilla extract',
#  u'vinegar',
#  u'walnut',
#  u'wasabi',
#  u'watermelon',
#  u'white wine',
#  u'wine'}

# %%
compute_single_avg_weight()

# %%
match_ratios = []
for ing in comp_ing_dict.keys():
    match_ratios.append((('earl grey tea syrup', ing), ing))

# %%
len(cocktail_set)
# Out:
# 936

# %%
cocktail_set
# Out:
# {u'3 cardamom pods',
#  u'7up',
#  u'absinthe',
#  u'absinthe,',
#  u'absolut smoked tea',
#  u'acid phosphate',
#  u'activated charcoal',
#  u'agave',
#  u'agave nectar',
#  u'agave syrup',
#  u'aged balsamic vinegar',
#  u'aleppo pepper',
#  u'aliz\xe9',
#  u'allspice',
#  u'allspice berries',
#  u'allspice dram',
#  u'allspice essential oil',
#  u'allspice liqueur',
#  u'almond',
#  u'almond extract',
#  u'almond milk',
#  u'almond orgeat',
#  u'almond syrup',
#  u'aloe vera juice',
#  u'amarena cherries',
#  u'amarena cherry',
#  u'amaretto',
#  u'amaro',
#  u'amaro montenegro',
#  u'amaro nonino',
#  u'amontillado sherry',
#  u'ancho chile liqueur',
#  u'ancho chile powder',
#  u'ancho reyes ancho chile liqueur',
#  u'anchor christmas ale',
#  u'angostura bitters',
#  u'anise liqueur',
#  u'anisette',
#  u'aperitif',
#  u'aperol',
#  u'apple',
#  u'apple bitters',
#  u'apple brandy',
#  u'apple butter',
#  u'apple chip',
#  u'apple cider',
#  u'apple cider syrup',
#  u'apple juice',
#  u'apple liqueur',
#  u'apple slice',
#  u'apple slices',
#  u'applejack',
#  u'apricot brandy',
#  u'apricot liqueur',
#  u'apricot preserves',
#  u'aquavit',
#  u'armagnac',
#  u'asparagus',
#  u'averna',
#  u'averna amaro',
#  u'averna limoni',
#  u'aveze gentian liqueur',
#  u'a\xe7ai juice',
#  u'a\xe7a\xed sugar',
#  u"b.g reynolds don's spices #2",
#  u'bacon',
#  u'baileys',
#  u'baileys original irish cream',
#  u'baileys with a hint of caramel',
#  u'baileys with a hint of coffee',
#  u'baileys with a hint of mint chocolate',
#  u'baked apple bitters',
#  u'balsamic vinegar',
#  u'banana',
#  u'banana liqueur',
#  u'bar keep organic lavender bitters',
#  u'barbecue bitters',
#  u'barolo chinato',
#  u'basil',
#  u'basil leaves',
#  u'bay leaf',
#  u'becherovka',
#  u'beef jerky',
#  u'beef straw',
#  u'beer',
#  u'beer,',
#  u'beet juice',
#  u'belgian tripel beer',
#  u'bell pepper',
#  u'benne seeds',
#  u'berries',
#  u'bitter aperitif',
#  u'bitter lemon soda',
#  u'bitter liqueur',
#  u'bittermens am\xe9re nouvelle',
#  u'bittermens burlesque bitters',
#  u'bittermens tepache liqueur',
#  u'bittermens tiki bitters',
#  u'bittermen\u2019s mol\xe9 bitters',
#  u'bitters',
#  u'black cherry',
#  u'black pepper',
#  u'black peppercorn',
#  u'black plum',
#  u'black tea',
#  u'black walnut bitters',
#  u'black walnuts',
#  u'blackberries',
#  u'blackberry',
#  u'blackberry liqueur',
#  u'blackcurrant',
#  u'blanc vermouth',
#  u'blanched almonds',
#  u'blood orange',
#  u'blood orange bitters',
#  u'blood orange juice',
#  u'blood orange liqueur',
#  u'blood orange oleo saccharum',
#  u'blood orange twist',
#  u'bloody mary mix',
#  u'blue cheese-stuffed olive',
#  u'blue cura\xe7ao',
#  u'blueberries',
#  u'blueberry',
#  u'blueberry jam',
#  u'blueberry juice',
#  u'blume marillen apricot eau de vie',
#  u'boiling water',
#  u"boker's bitters",
#  u'bonal gentiane quina',
#  u'bourbon',
#  u"brady's irish cream",
#  u'brandied cherries',
#  u'brandied cherry',
#  u'brandy',
#  u'brazilian espresso',
#  u'brewed coffee',
#  u'brown simple syrup',
#  u'brown sugar',
#  u'brown sugar syrup',
#  u'burnt rosemary',
#  u'butter',
#  u'b\xe3\xa9n\xe3\xa9dictine',
#  u'b\xe9n\xe9dictine',
#  u'cacha\xe7a',
#  u'cacha\xe7a,',
#  u'calvados',
#  u'campari',
#  u'canadian',
#  u'canadian whisky',
#  u'candied ginger',
#  u'candy cane',
#  u'cane syrup',
#  u'capers',
#  u'cara cara orange juice',
#  u'cara cara orange twist',
#  u'caramel sauce',
#  u'caramel vodka',
#  u'cardamaro',
#  u'cardamaro amaro',
#  u'cardamom',
#  u'cardamom bitters',
#  u'cardamom pods',
#  u'cardamom rock candy syrup',
#  u'cardamom syrup*',
#  u'carpano antica',
#  u'carpano vermouth',
#  u'carrot',
#  u'cassis',
#  u'cava',
#  u'cayenne pepper',
#  u'celery',
#  u'celery bitters',
#  u'celery salt',
#  u'celery seef',
#  u'celesalt',
#  u'chai',
#  u'chai tea',
#  u'chambord',
#  u'chamomile buds',
#  u'chamomile dust',
#  u'chamomile flowers',
#  u'chamomile tea',
#  u'champagne',
#  u'chardonnay',
#  u'chateau montifaud pineau de charentes rosso',
#  u'cherries',
#  u'cherry',
#  u'cherry bitters',
#  u'cherry brandy',
#  u'cherry heering',
#  u'cherry juice',
#  u'cherry liqueur',
#  u'cherry vodka',
#  u'chile de arbol',
#  u'chile pepper',
#  u'chile powder',
#  u'chili pepper',
#  u'chili powder',
#  u'chinese bitters',
#  u'chinese five-spice powder',
#  u'chipotle chile powder',
#  u'chipotle hot sauce',
#  u'chipotle pepper',
#  u'chocolate',
#  u'chocolate bitters',
#  u'chocolate liqueur',
#  u'chocolate milk',
#  u'chocolate sauce',
#  u'chocolate syrup',
#  u'chocolate vodka',
#  u'cholula hot sauce',
#  u'cider',
#  u'cilantro',
#  u'cinnamon',
#  u'cinnamon liqueur',
#  u'cinnamon stick',
#  u'cinnamon sticks',
#  u'cinnamon syrup',
#  u'citrus cordial',
#  u'citrus vodka',
#  u'clamato',
#  u'clear creek pear brandy',
#  u'clement creole shrubb orange liqueur',
#  u'clementine',
#  u'clove',
#  u'cloves',
#  u'club',
#  u'club soda',
#  u'coca-cola',
#  u'cocchi americano',
#  u'cocchi rosa',
#  u'cocktail cranberry',
#  u'cocktail onion',
#  u'cocktail onions',
#  u'coco lopez',
#  u'cocoa nibs',
#  u'cocoa powder',
#  u'coconut',
#  u'coconut cream',
#  u'coconut milk',
#  u'coconut sorbet',
#  u'coconut water',
#  u'coconut water with tangerine',
#  u'coconut-lychee milk*',
#  u'coconut-pistachio puree*',
#  u'coffee',
#  u'coffee bean',
#  u'coffee beans',
#  u'coffee bitters',
#  u'coffee liqueur',
#  u'cognac',
#  u'cointreau',
#  u'cola',
#  u'combier',
#  u'combier creme de pechel',
#  u'concord grape',
#  u'concord grape jelly',
#  u'concord grape juice',
#  u'concord grape puree',
#  u'concord grapes',
#  u'coriander',
#  u'corn chip',
#  u'corn syrup',
#  u'cranberries',
#  u'cranberry',
#  u'cranberry bitters',
#  u'cranberry jelly',
#  u'cranberry juice',
#  u'cranberry sauce',
#  u'cranberry syrup',
#  u'crawfish tail',
#  u'cream',
#  u'cream of coconut',
#  u'cream of tartar',
#  u'cream soda',
#  u"creme d'framboise",
#  u'creme de mure',
#  u'creme yvette',
#  u'crushed red pepper',
#  u'crystallized ginger',
#  u'cr\xe8me de banane',
#  u'cr\xe8me de cacao',
#  u'cr\xe8me de cassis',
#  u'cr\xe8me de menthe',
#  u'cr\xe8me de peche',
#  u'cr\xe8me de violette',
#  u'cucumber',
#  u'cucumber juice',
#  u'cucumber peel',
#  u'cucumber slices',
#  u'cucumber vodka',
#  u'cumin',
#  u'curry powder',
#  u'cynar',
#  u'dale degroff pimento bitters',
#  u"dale degroff's allspice bitters",
#  u"dale degroff's pimento bitters",
#  u'dark maple syrup',
#  u'date molasses syrup',
#  u'dead rabbit orinoco bitters',
#  u'del maguey vida mezcal',
#  u'demarara syrup',
#  u'demerara sugar',
#  u'demerara syrup',
#  u"demitri's bloody mary seasoning",
#  u'devil\u2019s larder root beer bitters',
#  u'dill',
#  u'dill pickle',
#  u'disaronno',
#  u'dolin blanc',
#  u'dr. adam elmegirab dandelion and burdock bitters',
#  u'drambuie',
#  u'dried angelica root',
#  u'dried apricots',
#  u'dried basil',
#  u'dried cherry',
#  u'dried coconut',
#  u'dried dill',
#  u'dried fig',
#  u'dried lavender blossoms',
#  u'dried mango',
#  u'dried oregano',
#  u'dried pineapple',
#  u'dried rose buds',
#  u'dry curacao',
#  u'dry madeira wine',
#  u'dry riesling',
#  u'dry rub spice mixture',
#  u'dry vemouth',
#  u'dry vermouth',
#  u'dubonnet rouge',
#  u'earl grey tea syrup',
#  u'edible flower',
#  u'edible pansy',
#  u'edible silver powder',
#  u'egg',
#  u'egg white',
#  u'eggs',
#  u'el guapo tex-mex bitters',
#  u'elderflower cordial',
#  u'elderflower liqueur',
#  u'espresso',
#  u'evaporated cane juice',
#  u'evaporated milk',
#  u'everclear',
#  u'falernum',
#  u'fee brothers cranberry bitters',
#  u'fee brothers rhubarb bitters',
#  u'fee brothers whiskey barrel aged bitters',
#  u'femet branca',
#  u'fennel',
#  u'fermented concord grape soda',
#  u'fernet branca',
#  u'fernet-branca',
#  u'fernet-vallet',
#  u'fig',
#  u'fig preserves',
#  u'fig syrup',
#  u'fino sherry',
#  u'four roses yellow label bourbon',
#  u'frangelico',
#  u'fresh curry leaves',
#  u'fresh ginger',
#  u'fresh grapefruit juice',
#  u'fresh grapefruit wheel',
#  u'fresh lemon juice',
#  u'fresh lime juice',
#  u'fresh mango puree',
#  u'fresh pineapple juice',
#  u'freshly grated cinnamon',
#  u'fresno chile',
#  u'fruit',
#  u'galliano',
#  u'garlic',
#  u'gelatin',
#  u'genepy',
#  u'genever',
#  u'giffard banane du br\xe9sil',
#  u'giffard banane du br\xe9sil liqueur',
#  u'giffard vanilla syrup orgeat',
#  u'gin',
#  u'gin,',
#  u'ginger',
#  u'ginger ale',
#  u'ginger beer',
#  u'ginger juice',
#  u'ginger liqueur',
#  u'ginger powder',
#  u'ginger root',
#  u'ginger simple syrup',
#  u'ginger syrup',
#  u'gingerroot',
#  u'golden apple',
#  u'grade a maple syrup',
#  u'grade b maple syrup',
#  u'gran classico bitter',
#  u'gran gala',
#  u'grand marnier',
#  u'granulated sugar',
#  u'grape',
#  u'grapefruit',
#  u'grapefruit bitters',
#  u'grapefruit juice',
#  u'grapefruit peel',
#  u'grapefruit soda',
#  u'grapefruit twise',
#  u'grapefruit twist',
#  u'green cardamom',
#  u'green chartreuse',
#  u'green creme de menthe',
#  u'green spot irish whiskey',
#  u'green tea',
#  u'green tea bags',
#  u'green tea liqueur',
#  u'grenadine',
#  u'ground cinnamon',
#  u'ground ginger',
#  u'guajillo chile',
#  u'guava',
#  u'guava juice',
#  u'guava puree',
#  u'gum syrup',
#  u'habanero',
#  u'habanero pepper',
#  u'hakkaisan premium japanese sake',
#  u'half and half',
#  u'hard cider',
#  u'hazelnut liqueur',
#  u'heavy cream',
#  u'hella bitter aromatic bitters',
#  u'hellfire bitters',
#  u'herbal liqueur',
#  u'herbal tea bag',
#  u'hershey\u2019s chocolate syrup',
#  u'hibiscus',
#  u'hibiscus iced tea',
#  u'hibiscus tea',
#  u'hibiscus-rosehip tea',
#  u'holiday syrup',
#  u'honey',
#  u'honey liqueur',
#  u'honey sugar',
#  u'honey syrup',
#  u'honey-pinapple syrup',
#  u'honeydew',
#  u'honeydew melon',
#  u'horseradish',
#  u'hot chocolate',
#  u'hot sauce',
#  u'ice',
#  u'ice cream',
#  u'iced tea',
#  u'in a rocks glass',
#  u'irish',
#  u'irish cream liqueur',
#  u'irish whiskey liqueur',
#  u'jalape\xf1o',
#  u'jalape\xf1o pepper',
#  u'jameson black barrel irish whiskey',
#  u'japanese',
#  u'japanese plum wine',
#  u'jell-o',
#  u'juice from brandied cherries',
#  u'juniper berries',
#  u'juniper syrup',
#  u'kaffir',
#  u'kaffir lime leaf',
#  u'kahlua',
#  u'kalamata olive',
#  u'key lime juice',
#  u'king\u2019s ginger',
#  u'kirsch',
#  u'kirsch soaked griotte cherry',
#  u'kirschwasser',
#  u'kiwi',
#  u'kumquat',
#  u'kumquats',
#  u'la boite 37 spice and salt blend',
#  u'lapsang souchong tea',
#  u'large eggs',
#  u'lavender',
#  u'lavender bitters',
#  u'lavender blossom',
#  u'lavender simple syrup',
#  u'lavender soda',
#  u'lavender sugar',
#  u'lemon',
#  u'lemon bitters',
#  u'lemon juice',
#  u'lemon oils',
#  u'lemon peel',
#  u'lemon pigtail',
#  u'lemon sherbet',
#  u'lemon simple syrup',
#  u'lemon slices',
#  u'lemon twist',
#  u'lemon uice',
#  u'lemon wedge',
#  u'lemon wheel',
#  u'lemon zest',
#  u'lemon-flavored club soda',
#  u'lemon-lime soda',
#  u'lemon-thyme syrup',
#  u'lemonade',
#  u'lemongrass',
#  u'licor 43',
#  u'lillet blanc',
#  u'lillet rose',
#  u'lillet rouge',
#  u'lime',
#  u'lime juice',
#  u'lime peel',
#  u'lime syrup',
#  u'lime twist',
#  u'lime wedge',
#  u'lime wheel',
#  u'lime zest',
#  u'liqueurs',
#  u'liqueurs,',
#  u'liquore strega',
#  u'long pepper',
#  u'lucano amaro',
#  u'luxardo amaretto',
#  u'luxardo amaro abano',
#  u'luxardo bitter liqueur',
#  u'luxardo cherry',
#  u'luxardo maraschino liqueur',
#  u'lychee juice',
#  u'madeira',
#  u'madiera',
#  u'maggi seasoning',
#  u'maldon salt',
#  u'mandarin',
#  u'mango',
#  u'mango juice',
#  u'mango nectar',
#  u'mango syrup',
#  u'manzanilla sherry',
#  u'maple simple syrup',
#  u'maple sugar',
#  u'maple syrup',
#  u'maraschino cherry',
#  u'maraschino liqueur',
#  u'marie brizard apry',
#  u'marie brizard creme de cacao blanc',
#  u'marie brizard orange cura\xe7ao',
#  u'martini bianco',
#  u'martini rosso',
#  u'matcha green tea powder',
#  u'matcha powder',
#  u'mayhaw jelly',
#  u'melon',
#  u'melon liqueur',
#  u'merlot',
#  u'mesquite salt',
#  u'mexican hot chocolate mix',
#  u'meyer lemon',
#  u'meyer lemon juice',
#  u'meyer lemon vodka',
#  u'mezcal',
#  u'mezcal,',
#  u'milk',
#  u'mineral water',
#  u'mint',
#  u'mint bitters',
#  u'mint leaves',
#  u'mint sprig',
#  u'mint syrup',
#  u'molasses',
#  u'mole bitters',
#  u'moonshine',
#  u'moroccan bitters',
#  u'muddle the mint leaves and simple syrup. add the rye and fill with crushed ice. stir well and garnish with a sprig of mint.',
#  u'mulled cider',
#  u'mulling spices',
#  u'noilly prat rouge',
#  u'non-alcoholic',
#  u'nutmeg',
#  u'old bay seasoning',
#  u'oleo saccharum sour mix',
#  u'olive',
#  u'olive brine',
#  u'olive juice',
#  u'olive oil',
#  u'olive tapenade',
#  u'olives',
#  u'oloroso sherry',
#  u'orange',
#  u'orange bitters',
#  u'orange blossom water',
#  u'orange cura\xe7ao',
#  u'orange flower water',
#  u'orange juice',
#  u'orange liqueur',
#  u'orange marmalade',
#  u'orange peel',
#  u'orange peel oil',
#  u'orange sherbet',
#  u'orange slice',
#  u'orange twist',
#  u'orange zest',
#  u'orange-ginger marmalade',
#  u'orchid',
#  u'oregano',
#  u'oregano leaves',
#  u'organic maple syrup',
#  u'orgeat',
#  u'orgeat syrup',
#  u'orinoco bitters',
#  u'other',
#  u"owl's brew coco-lada",
#  u"owl's brew pink and black",
#  u"owl's brew the classic",
#  u'oysters',
#  u'pale ale',
#  u'palm sugar',
#  u'pama pomegranate liqueur',
#  u'pamplemousse rose liqueur',
#  u'parsley',
#  u'passion fruit',
#  u'passion fruit iced tea',
#  u'passion fruit juice',
#  u'passion fruit puree',
#  u'passion fruit syrup',
#  u'pastis',
#  u'pea puree',
#  u'pea shrub',
#  u'peach',
#  u'peach bitters',
#  u'peach brand',
#  u'peach liqueur',
#  u'peach nectar',
#  u'peach preserves',
#  u'peach puree',
#  u'peach schnapps',
#  u'peach shrub',
#  u'peanut',
#  u'peanut butter',
#  u'peanut butter cup',
#  u'peanut orgeat',
#  u'peanut rum cr\xe8me liqueur',
#  u'pear',
#  u'pear brandy',
#  u'pear fan',
#  u'pear juice',
#  u'pear liqueur',
#  u'pear puree',
#  u'pear puree or nectar',
#  u'pear syrup',
#  u'pear vodka',
#  u'pecan liqueur',
#  u'pepper',
#  u'peppermint pattie',
#  u'peppermint schnapps',
#  u'peppermint tea',
#  u'pernod pastis',
#  u"peychaud's bitters",
#  u'pickle brine',
#  u'pickled green bean',
#  u'pickled okra',
#  u'pickled peppers',
#  u'pickled string bean',
#  u'pierde almas +9 mezcal-gin',
#  u'pilsner',
#  u'pimento bitters',
#  u'pimento dram',
#  u"pimm's no. 1",
#  u'pinch smoked paprika',
#  u'pinch white pepper',
#  u'pineapple',
#  u'pineapple core',
#  u'pineapple gomme syrup',
#  u'pineapple juice',
#  u'pineapple leaf',
#  u'pineapple puree',
#  u'pineapple syrup',
#  u'pineau des charentes',
#  u'pink grapefruit',
#  u'pink grapefruit juice',
#  u'pink lemonade',
#  u'pink peppercorn',
#  u'pink peppercorns',
#  u'pisco',
#  u'pistachio',
#  u'pistachio fat-washed vodka*',
#  u'pistachio orgeat',
#  u'pistachio syrup*',
#  u'pistachio-infused oloroso sherry*',
#  u'plum',
#  u'poblano pepper',
#  u'pok pok pineapple drinking vinegar',
#  u'pom wonderful',
#  u'pomegranate',
#  u'pomegranate juice',
#  u'pomegranate liqueur',
#  u'pomegranate soda',
#  u'pomegranate syrup',
#  u'pommeau de normandie',
#  u'port',
#  u'powdered sugar',
#  u'powered sugar',
#  u'prepared horseradish',
#  u'prosecco',
#  u'pumpkin',
#  u'pumpkin ale',
#  u'pumpkin beer',
#  u'pumpkin butter',
#  u'pumpkin puree',
#  u'pumpkin seeds',
#  u'pumpkin spice liqueur',
#  u'punt e mes',
#  u'pure maple syrup',
#  u'purely syrup grapefruit',
#  u'purely syrup vanilla bean',
#  u'queso fresco',
#  u'raisin',
#  u'raspberries',
#  u'raspberry',
#  u'raspberry brandy',
#  u'raspberry jam',
#  u'raspberry liqueur',
#  u'raspberry preserves',
#  u'raspberry simple syrup',
#  u'raspberry syrup',
#  u'raspberry vinegar',
#  u'raw oats',
#  u'raw sugar',
#  u'raw sugar syrup',
#  u'red apple',
#  u'red bell pepper',
#  u'red bell pepper juice',
#  u'red food dye',
#  u'red fresno chile pepper',
#  u'red pepper flakes',
#  u'red tea',
#  u'red wine',
#  u"regan's orange bitters no. 6",
#  u'rhubarb',
#  u'rhubarb amaro',
#  u'rhubarb bitters',
#  u'rhubarb juice',
#  u'rhubarb marmalade',
#  u'rhubarb shrub',
#  u'rhum clement creole shrub',
#  u'rich simple syrup',
#  u'roasted hazelnut',
#  u'root beer',
#  u'rose petal',
#  u'rose petals',
#  u'rose syrup',
#  u"rose's lime juice",
#  u'rosemary',
#  u'rosemary simple syrup',
#  u'rosemary syrup',
#  u'ros\xe9 sparkling wine',
#  u'rothman &amp; winter orchard apricot',
#  u'ruby port',
#  u'ruby red grapefruit',
#  u'ruby red grapefruit juice',
#  u'rum',
#  u'rum,',
#  u'rumchata',
#  u'rye',
#  u'rye whiskey',
#  u'sage',
#  u'sage flower',
#  u'sake',
#  u'sakura liqueur',
#  u'sale',
#  u'salt',
#  u'salted caramel syrup',
#  u'salted pistachio syrup*',
#  u'sambuca',
#  u'sauternes',
#  u'scaldis p\xe3\xaache mel beer',
#  u'scotch',
#  u'scotch whisky',
#  u'scotch,',
#  u'sea salt',
#  u'sel',
#  u'seltzer',
#  u'seltzer water',
#  u'sencha tea',
#  u'serrano chile',
#  u'shelled raw pistachios',
#  u'sherry',
#  u'shiso',
#  u'shrimp',
#  u'sidral mundet',
#  u'simple chocolate syrup',
#  u'simple syrup',
#  u'sloe gin',
#  u'smoked black pepper',
#  u'smoked chipotle chile powder',
#  u'smoked honey syrup',
#  u'smoked paprika',
#  u'smoked salt',
#  u'soda',
#  u'soda water',
#  u'soju',
#  u'sorghum syrup',
#  u'sour apple liqueur',
#  u'sour mix',
#  u'sour orange sherbet',
#  u'southern comfort',
#  u'soy sauce',
#  u'sparkling apple cider',
#  u'sparkling apple juice',
#  u'sparkling cider',
#  u'sparkling pear cider',
#  u'sparkling ros\xe9 wine',
#  u'sparkling water',
#  u'sparkling wine',
#  u'sparklins wine',
#  u'spiced black tea',
#  u'spiced pear liqueur',
#  u'spiced poached pear',
#  u'spiced rum',
#  u'sprite',
#  u'square one botanical spirit',
#  u'sriracha',
#  u'sriracha hot sauce',
#  u'st-germain',
#  u'st. elizabeth allspice dram',
#  u'st. germain',
#  u'star anise',
#  u'star anise powder',
#  u'star fruit',
#  u'starfruit',
#  u'steamed milk',
#  u'stiegl radler grapefruit beer',
#  u'strawberrry-infused aperol',
#  u'strawberry',
#  u'strawberry juice',
#  u'strawberry liqueur',
#  u'strawberry puree',
#  u'strawberry syrup',
#  u'strawberry-demerara syrup',
#  u'strawberry-infused blanco tequila',
#  u'strawberry-rose syrup',
#  u'strega',
#  u'sugar',
#  u'sugar cane',
#  u'sugar cane syrup',
#  u'sugar cube',
#  u'sugar snap peas',
#  u'sugar syrup',
#  u'superfine sugar',
#  u'suze',
#  u'sweet pepper',
#  u'sweet tea',
#  u'sweet vermouth',
#  u'sweetened lime juice',
#  u'syrup from poached pears',
#  u'tabasco',
#  u'tabasco hot sauce',
#  u'tabasco sauce',
#  u'tamarind',
#  u'tamarind chutney',
#  u'tamarind concentrate',
#  u'tamarind syrup',
#  u'tangerine',
#  u'tangerine juice',
#  u'tapatio hot sauce',
#  u'tarragon',
#  u'tea',
#  u'tejocote',
#  u'tequila',
#  u'tequila,',
#  u'thai basil',
#  u'thai chile syrup',
#  u'the bitter truth old time aromatic bitters',
#  u'the dead rabbit orinoco bitters',
#  u'thistle',
#  u'thyme',
#  u'thyme liqueur',
#  u'tiki bitters',
#  u'tomato',
#  u'tomato juice',
#  u'tonic water',
#  u'triple sec',
#  u'truvia',
#  u'turbinado sugar',
#  u'vanilla bean',
#  u'vanilla bitters',
#  u'vanilla cognac',
#  u'vanilla extract',
#  u'vanilla ice cream',
#  u'vanilla liqueur',
#  u'vanilla soda',
#  u'vanilla syrup',
#  u'vanilla vodka',
#  u'veev',
#  u'veev a\xe7ai spirit',
#  u'vegetable juice',
#  u'velvet falernum',
#  u'verjus',
#  u'vermont maple syrup',
#  u'vermouth',
#  u'vicaris tripel-geuze',
#  u'vinegar',
#  u'vodka',
#  u'walnut',
#  u'walnut liqueur',
#  u'walnut orgeat',
#  u'wasabi',
#  u'wasabi powder',
#  u'water',
#  u'watermelon',
#  u'watermelon juice',
#  u'whipped cream',
#  u'whiskey barrel-aged bitters',
#  u'white balsamic vinegar',
#  u'white chocolate',
#  u'white chocolate liqueur',
#  u'white cocoa marie brizard',
#  u'white cranberry juice',
#  u'white dog',
#  u'white grape juice',
#  u'white peach',
#  u'white peach puree',
#  u'white pepper',
#  u'white rumskey',
#  u'white sugar',
#  u'white tea liqueur',
#  u'white wine',
#  u'white wine vinegar',
#  u'whole egg',
#  u'whole milk',
#  u'wine',
#  u'worcestershire sauce',
#  u'xant\xe9 liqueur',
#  u'yellow chartreuse',
#  u'yuzu juice',
#  u'zginger liqueur'}

# %%
def find_matches():
    matches = []
    for ing in list(cocktail_set)[300:500]:
        matches.append(process.extractBests(ing, asc_comp_ing.keys(), scorer=fuzz.partial_token_set_ratio, score_cutoff=80))
    return matches

# %%
ingr = 'lemon'
print process.extractBests(ingr, asc_comp_ing.keys(), scorer=fuzz.ratio, score_cutoff=98)
print process.extractBests(ingr, asc_comp_ing.keys(), scorer=fuzz.partial_token_set_ratio, score_cutoff=0)
# Out:
# [(u'lemon', 100)]
# [(u'lemon juice', 100), (u'and extraction products: lemongrass', 100), (u'juice (lemon', 100), (u'lemon peel', 100), (u'lemon petitgrain', 100)]

# %%
# %page match_list

# %%
[match[0] for match in match_list[10]]
# Out:
# [u'strawberry', u'strawberry jam', u'strawberry wine']

# %%
sorted(match_ratios, reverse =True)
# Out:
# [(60, 'maple syrup'),
#  (56, 'several green leaves'),
#  (55, 'parsley leaves'),
#  (52, 'of green tea'),
#  (50, 'green tea'),
#  (50, 'dry red beans'),
#  (50, 'celery leaves'),
#  (49, 'wintergreen leaves'),
#  (48, 'partially fermented tea'),
#  (48, 'bartlett pears'),
#  (47, 'white grape var'),
#  (47, 'tea (green)'),
#  (47, 'red sage (texas sage) (s'),
#  (47, 'pineapple guava (feyoa fruit'),
#  (47, 'pear brandy'),
#  (47, 'oriental styrax'),
#  (47, 'mulberry leaves'),
#  (47, 'fermented soy sauce'),
#  (46, 'parsley seed oil'),
#  (46, 'mackerel keta salmon'),
#  (46, 'green tea cognac'),
#  (46, 'elderberry fruit'),
#  (46, 'barley (roasted)'),
#  (46, 'a grape'),
#  (45, 'wheat breads'),
#  (45, 'tea tree oil'),
#  (45, 'several varieties of mushrooms'),
#  (45, 'prickly pear'),
#  (45, 'orange trees'),
#  (45, 'muscal grape'),
#  (45, 'heated beans'),
#  (45, 'ginger grass'),
#  (45, 'celery stalk'),
#  (44, 'several varieties of honey'),
#  (44, 'several essential oils'),
#  (44, 'natural resources'),
#  (44, 'laurel leaves'),
#  (44, 'heated butter'),
#  (44, 'fermented tea'),
#  (44, 'fermented soybean'),
#  (44, 'coal tar'),
#  (44, 'cherry brandy'),
#  (43, 'several varieties of berries'),
#  (43, 'phebalium dentatum'),
#  (43, 'other varieties of mushrooms'),
#  (43, 'other varieties of mush-room'),
#  (43, 'oils of mentha spp'),
#  (43, 'nearly 300 natural sources including apple'),
#  (43, 'microbial fermented tea'),
#  (43, 'meat aroma model system'),
#  (43, 'maple sap'),
#  (43, 'many other sources'),
#  (43, 'gruyere de comte cheese'),
#  (43, 'dried kidney beans'),
#  (43, 'cranberry press residue'),
#  (43, 'canned red kidney beans'),
#  (43, 'artemisia scoparia'),
#  (42, 'vinifera grape'),
#  (42, 'the free state'),
#  (42, 'roasted shrimp'),
#  (42, 'pelargonium capitau'),
#  (42, 'leaves or bark'),
#  (42, 'heated soybean'),
#  (42, 'fermented soya hydrolysate (shoyu)'),
#  (42, 'chermoya fruit'),
#  (42, 'cheddar cheese'),
#  (42, 'cedar leaf oil'),
#  (42, 'burley tobacco'),
#  (42, 'bilberry wines'),
#  (42, 'ambrette seeds'),
#  (41, 'verlotorum'),
#  (41, 'veal round'),
#  (41, 'traces are also'),
#  (41, 'sparkling wines'),
#  (41, 'several mint species'),
#  (41, 'several essential oils: neroli'),
#  (41, 'rye breads'),
#  (41, 'rose apple (syz'),
#  (41, 'reported to be found'),
#  (41, 'related species'),
#  (41, 'raw shrimp'),
#  (41, 'purple passion fruit'),
#  (41, 'particularly cypress'),
#  (41, 'oriental storax'),
#  (41, 'only the d-form'),
#  (41, 'olive (olea europae)'),
#  (41, 'oat groats (toasted)'),
#  (41, 'oat groats'),
#  (41, 'neroli bigarade'),
#  (41, 'natural sources'),
#  (41, 'natural smoke flavor'),
#  (41, 'microbially fermented tea'),
#  (41, 'meyer oil turkey (39 20%)'),
#  (41, 'many different whisky products'),
#  (41, 'extremely widespread'),
#  (41, 'eucalyptus'),
#  (41, 'corn grits'),
#  (41, 'ceylon tea'),
#  (41, 'brewed tea'),
#  (41, 'black hemiptera bugs'),
#  (41, 'as well as'),
#  (41, 'a large variety of plants'),
#  (41, 'a few essential oils'),
#  (41, 'a few banana species'),
#  (40, 'wild grapes'),
#  (40, 'wheat bread'),
#  (40, 'water bread'),
#  (40, 'vanilla fragrans'),
#  (40, 'types of grape brandy'),
#  (40, 'the pungent principle'),
#  (40, 'the lemon eucalyptus plant'),
#  (40, 'sweet grass'),
#  (40, 'strawberry fruit'),
#  (40, 'strawberry aroma'),
#  (40, 'several stereoisomers'),
#  (40, 'several fermentation pro-cesses'),
#  (40, 'reported as'),
#  (40, 'raspberry brandy'),
#  (40, 'pineapple (anans comoscus)'),
#  (40, 'pineapple (ananas comosus)'),
#  (40, 'orange peel oils'),
#  (40, 'orange leaf'),
#  (40, 'of mentha arvenis var'),
#  (40, 'natural smoke flavors'),
#  (40, 'natural products'),
#  (40, 'naranjilla fruit'),
#  (40, 'myrtle leaf'),
#  (40, 'mozarella cheese'),
#  (40, 'malay apple'),
#  (40, 'lovage leaf'),
#  (40, 'litsea gutalemaleusis'),
#  (40, 'lesquerella seed meal'),
#  (40, 'lavage leaf'),
#  (40, 'jasmine tea'),
#  (40, 'heracleum giganteum l'),
#  (40, 'heated pork meat'),
#  (40, 'heated pork'),
#  (40, 'grape wines'),
#  (40, 'grape vines'),
#  (40, 'grape musts'),
#  (40, 'gingergrass'),
#  (40, 'frozen peas'),
#  (40, 'fried or grilled beef'),
#  (40, 'feyoa fruit'),
#  (40, 'feta cheese'),
#  (40, 'fermented radish'),
#  (40, 'eucalyptus dives'),
#  (40, 'ethiopian or guinea pepper'),
#  (40, 'essential oils as an ester'),
#  (40, 'elderberry juice'),
#  (40, 'either free or esterified: rose'),
#  (40, 'cured meats'),
#  (40, 'cherry (prunus cerasus l )'),
#  (40, 'celery seed'),
#  (40, 'celery root'),
#  (40, 'carrot root'),
#  (40, 'canned peas'),
#  (40, 'canned asparagus'),
#  (40, 'butter as a glyceride'),
#  (40, 'bread preferment'),
#  (40, 'bell pepper'),
#  (40, 'been reported in'),
#  (40, 'barley'),
#  (40, 'apple aroma'),
#  (40, 'and several varieties of orchid'),
#  (39, 'various dairy products'),
#  (39, 'udo (aralia cordata thunb )'),
#  (39, 'the natural aromas of apple'),
#  (39, 'strawberry aromas'),
#  (39, 'some varieties of mushrooms'),
#  (39, 'several types of bread'),
#  (39, 'several essential oils: thuja plicata'),
#  (39, 'several essential oils from plants of'),
#  (39, 'reported to be present'),
#  (39, 'pineapple (ananas comoscus)'),
#  (39, 'peru balsam as well as'),
#  (39, 'papaya fruit'),
#  (39, 'other cheese'),
#  (39, 'orange oil from leaves'),
#  (39, 'oak wood tar oils'),
#  (39, 'nobiru (allium grayi regal)'),
#  (39, 'nobira (allium grayi regal)'),
#  (39, 'natural products (pelargonium species)'),
#  (39, 'myrtle berry'),
#  (39, 'muscat grape'),
#  (39, 'mozzarella cheese'),
#  (39, 'meat extract'),
#  (39, 'mat\xc3\xa9 (green'),
#  (39, 'malt whiskey'),
#  (39, 'larger amounts in'),
#  (39, 'kidney beans'),
#  (39, 'jerusalem artichoke (helianthus tuberosus)'),
#  (39, 'hydrolyzed soy protein'),
#  (39, 'hydrolysates'),
#  (39, 'has been reported'),
#  (39, 'green pepper'),
#  (39, 'green bell pepper'),
#  (39, 'grape brandy'),
#  (39, 'elderberries'),
#  (39, 'elder flower'),
#  (39, 'datura stramonium'),
#  (39, 'crisp breads'),
#  (39, 'cream cheese'),
#  (39, 'clary sage bush (salvia sclarea)'),
#  (39, 'caraway herb'),
#  (39, 'caprylic acid has'),
#  (39, 'blackberry brandy'),
#  (39, 'bitter orange peel oil'),
#  (39, 'beechwood tar creosote'),
#  (39, 'artemisia frigida'),
#  (39, 'apple brandy'),
#  (39, 'and some other natural products (grape'),
#  (39, 'and other sources'),
#  (39, 'and lean raw fish'),
#  (39, 'achillea ageratum'),
#  (39, 'absolute concrete'),
#  (39, 'a variety of mint'),
#  (38, 'widely distributed'),
#  (38, 'wheaten bread'),
#  (38, 'weinbrand rum'),
#  (38, 'violet leaves'),
#  (38, 'various eucalyptus oils'),
#  (38, 'vanilla beans'),
#  (38, 'valerian root'),
#  (38, 'tonka bean (dipteryx odorata) seed'),
#  (38, 'the scent of green vegetable nezara viridula'),
#  (38, 'the presence of mineral acids'),
#  (38, 'the form of esters'),
#  (38, 'the bark of sweet birch'),
#  (38, 'tangerine peel oil'),
#  (38, 'several types of brandy'),
#  (38, 'salted salmon'),
#  (38, 'rice husks are reportedly the principal source of vitam'),
#  (38, 'reported used'),
#  (38, 'reported as the odorous component'),
#  (38, 'raw lean fish'),
#  (38, 'raw asparagus'),
#  (38, 'peanut butter'),
#  (38, 'parsley'),
#  (38, 'palm nut oils'),
#  (38, 'other cheeses'),
#  (38, 'of grapefruit'),
#  (38, 'of elettaria cardamomum'),
#  (38, 'muscat grapes'),
#  (38, 'muscat grape juice'),
#  (38, 'marine brouno'),
#  (38, 'many proteins'),
#  (38, 'litsea cubeba'),
#  (38, 'hydrolyzed vegetable protein'),
#  (38, 'heptanal is a constituent of'),
#  (38, 'gruyere'),
#  (38, 'ginger pepper'),
#  (38, 'free or esterified'),
#  (38, 'followed by the racemic form'),
#  (38, 'fairly siz-able amounts'),
#  (38, 'eucalyptus diversicolor'),
#  (38, 'eucalyptus cinerea'),
#  (38, 'erica arborea'),
#  (38, 'depending on the source'),
#  (38, 'containing farnesol are lemongrass'),
#  (38, 'concord grape'),
#  (38, 'cold-stored butter'),
#  (38, 'chinese star anise'),
#  (38, 'cedar: cedrus atlantica'),
#  (38, 'carrots'),
#  (38, 'caraway seeds'),
#  (38, 'capsicum varieties'),
#  (38, 'calamintha nepeta (l ) savi subsp'),
#  (38, 'bitter orange peel'),
#  (38, 'bilberry wine'),
#  (38, 'berries'),
#  (38, 'beli (aegle marmelos correa)'),
#  (38, 'beechwood tar'),
#  (38, 'because of the presence'),
#  (38, 'apple essence'),
#  (38, 'antheum graveolens'),
#  (38, 'and black tea'),
#  (38, 'a proline/glucose maillard system'),
#  (38, 'a few artemisia varieties (a'),
#  (37, 'vertiver'),
#  (37, 'two optically inactive isomers'),
#  (37, 'trametes graveolens'),
#  (37, 'the racemic form are of little importance'),
#  (37, 'the mushroom variety trametes graveolens'),
#  (37, 'the dry distillate of manilla copal'),
#  (37, 'rue (ruta graveolens l )'),
#  (37, 'roasted sesame seed'),
#  (37, 'red meat'),
#  (37, 'raw peas'),
#  (37, 'processed lean fish'),
#  (37, 'pelargonium tomentosum jacquin'),
#  (37, 'paraguay'),
#  (37, 'over 300 natural sources including apples'),
#  (37, 'over 260 natural sources including apple'),
#  (37, 'over 230 natural sources including apple'),
#  (37, 'over 120 natural food products'),
#  (37, 'other vitis species'),
#  (37, 'originally reported'),
#  (37, 'orange (bitter) peel oil'),
#  (37, 'nature has been reported'),
#  (37, 'mentha pulegium var'),
#  (37, 'mastic gum leaf oil'),
#  (37, 'lemon (from different sources)'),
#  (37, 'laurel leaf oil turkey (0 10%)'),
#  (37, 'heracleum candicans'),
#  (37, 'guinea sweet orange'),
#  (37, 'fruital aromas (e g'),
#  (37, 'from angelica roots'),
#  (37, 'fresh salted salmon'),
#  (37, 'french fried potato'),
#  (37, 'fermented beverages'),
#  (37, 'eupatorium fortunei'),
#  (37, 'eucalyptus globulus'),
#  (37, 'eucalyptus globules'),
#  (37, 'essential oils of citrus peels'),
#  (37, 'cooked scented rice'),
#  (37, 'canned orange juice on storage'),
#  (37, 'calytrix'),
#  (37, 'bitter orange juice'),
#  (37, 'back tea'),
#  (37, 'as the odorous component'),
#  (37, 'artemisia diffusa krasch'),
#  (37, 'and heater beef fat'),
#  (37, 'and east indian geranium'),
#  (37, 'and beer'),
#  (37, 'alcoholic beverages'),
#  (37, 'acetic acid or acetates are present'),
#  (36, 'yellow passion fruit'),
#  (36, 'yellow passion friut'),
#  (36, 'whole gra'),
#  (36, 'while the d-form is found'),
#  (36, 'violet (leaves'),
#  (36, 'toasted sesame seeds'),
#  (36, 'the two optically active isomers are found'),
#  (36, 'the trans-form'),
#  (36, 'the trans'),
#  (36, 'the seeds'),
#  (36, 'the racemic form is found'),
#  (36, 'the optically inactive form is found'),
#  (36, 'the major aroma component'),
#  (36, 'the juice of citrus fruits'),
#  (36, 'the fresh roots of rafanus sativus l'),
#  (36, 'the free alcohol has been'),
#  (36, 'the commercial product is the racemic form'),
#  (36, 'the aromas of straw-berry'),
#  (36, 'tara (caesalpinia spinosa)'),
#  (36, 'strawberry jam'),
#  (36, 'spearmint oils'),
#  (36, 'sparkling wine'),
#  (36, 'several plants'),
#  (36, 'salvia sclarea'),
#  (36, 'rye flour'),
#  (36, 'rye bread'),
#  (36, 'roasted turkey'),
#  (36, 'roasted sesame seeds'),
#  (36, 'roasted pecans'),
#  (36, 'roasted peanut'),
#  (36, 'roasted barley'),
#  (36, 'rhodinyl formate as such has not been'),
#  (36, 'reported as responsible for the off-flavor'),
#  (36, 'red algae'),
#  (36, 'raw or cooked potato'),
#  (36, 'raw cured pork'),
#  (36, 'purple passion fruit juice'),
#  (36, 'peru balsam from honduras'),
#  (36, 'peanut (arachis hypogaea)'),
#  (36, 'paste (trassi)'),
#  (36, 'orris absolute'),
#  (36, 'orange essence'),
#  (36, 'of rosa rugosa'),
#  (36, 'of eucalyptus polibrac tea has been reported to conta'),
#  (36, 'ocimum basilicum varieties'),
#  (36, 'neroli oil (with geraniol)'),
#  (36, 'neroi bigarade'),
#  (36, 'nectandra elaiophora'),
#  (36, 'nature as the d- or l-form'),
#  (36, 'natural isopulegone is dextrorotatory'),
#  (36, 'mustard (brassica species)'),
#  (36, 'munster cheese'),
#  (36, 'mentha spicata'),
#  (36, 'mentha species'),
#  (36, 'mentha piperta'),
#  (36, 'melaleuca'),
#  (36, 'meat fats'),
#  (36, 'malt wort'),
#  (36, 'magnolia grandiflora'),
#  (36, 'leek (raw'),
#  (36, 'leaves or bark of monarda fistulosa l'),
#  (36, 'lean fish'),
#  (36, 'juniper essential leaf oil'),
#  (36, 'its salts occur naturally'),
#  (36, 'it has been reported'),
#  (36, 'it had been reported previously'),
#  (36, 'israeli sweet orange'),
#  (36, 'iberis sempervirens seeds'),
#  (36, 'heracleum'),
#  (36, 'has been found'),
#  (36, 'gruyere cheese'),
#  (36, 'geranium petiole oil'),
#  (36, 'garlic (allium sativum l )'),
#  (36, 'fragaria vesca'),
#  (36, 'feyoa fruit (feijoa sellowiana)'),
#  (36, 'fermented'),
#  (36, 'fenugreek'),
#  (36, 'eucalyptus oil'),
#  (36, 'eucalyptus citriodora hook'),
#  (36, 'essential oils'),
#  (36, 'diary products'),
#  (36, 'dairy products'),
#  (36, 'cottage cheese'),
#  (36, 'corn tortillas'),
#  (36, 'concord grapes'),
#  (36, 'clary sage oil'),
#  (36, 'chinese quince fruit'),
#  (36, 'chervil (anthriscus cerefolium)'),
#  (36, 'champaca concrete at 0 01%'),
#  (36, 'cartilage'),
#  (36, 'canned carrots'),
#  (36, 'calcarata'),
#  (36, 'bulgarian clary sage'),
#  (36, 'black tea'),
#  (36, 'black currant grapes'),
#  (36, 'beverages including fresh apple'),
#  (36, 'beverages'),
#  (36, 'beet root'),
#  (36, 'because of the yellow color developed'),
#  (36, 'as the ma'),
#  (36, 'artemisia herba alba'),
#  (36, 'artemisia camphorata'),
#  (36, 'artemisia brevifolia'),
#  (36, 'animal tissues'),
#  (35, '\xce\xb3-caryophyllene) are found'),
#  (35, 'yellow pas-sion fruit'),
#  (35, 'xanthorrhoea hastilis'),
#  (35, 'widely occurring as the free acid'),
#  (35, 'varying amounts'),
#  (35, 'various sumac species'),
#  (35, 'various cheeses'),
#  (35, 'vanilla extract'),
#  (35, 'valencia orange juice'),
#  (35, 'types of thymus'),
#  (35, 'the racemic form is present'),
#  (35, 'the odorous principle obtained by extraction'),
#  (35, 'the east indies'),
#  (35, 'the cultures of certa'),
#  (35, 'the aroma of roasted coffee'),
#  (35, 'tangerine juice'),
#  (35, 'sweet grass oil'),
#  (35, 'sturgeon caviar'),
#  (35, 'strawberry wine'),
#  (35, 'stalk of celery'),
#  (35, 'sopadilla fruit'),
#  (35, 'shoyu (fermented soy hydrolysate)'),
#  (35, 'several types of wine'),
#  (35, 'several peppermint essential oils: american'),
#  (35, 'several food products'),
#  (35, 'several essential oils: arnica montana'),
#  (35, 'sesame seed oil'),
#  (35, 'sapodilla fruit'),
#  (35, 'salvia spinosa)'),
#  (35, 'rosemary oil co2 extract (8 36%)'),
#  (35, 'roasted peanuts'),
#  (35, 'roasted peanut (arachis hypogea)'),
#  (35, 'rhodophyllus icterius'),
#  (35, 'reportedly identified'),
#  (35, 'reported formed'),
#  (35, 'reported as occurring'),
#  (35, 'reported among the constituents of petitgra'),
#  (35, 'probably formed from ferulic acid'),
#  (35, 'peppermint oil (trans-form)'),
#  (35, 'peppermint oil (mentha piperita)'),
#  (35, 'parmesan cheese'),
#  (35, 'oscimum basilicum varieties'),
#  (35, 'orange peel oil'),
#  (35, 'of salvia grandiflora'),
#  (35, 'of leaves of doryphora sassafras'),
#  (35, 'natural borneol can be d or l rotatory'),
#  (35, 'mentha arvensis'),
#  (35, 'matricaria parthenium'),
#  (35, 'mastic gum leaf'),
#  (35, 'many citrus peel oils'),
#  (35, 'lentils were found to conta'),
#  (35, 'lavandula spica'),
#  (35, 'l-bornyl isovalerate has been reported'),
#  (35, 'juniper berry (alcoholic extract)'),
#  (35, 'heated pork fat'),
#  (35, 'heated beef fat'),
#  (35, 'has not been reported'),
#  (35, 'gruyere cheeses'),
#  (35, 'grapefruit peel'),
#  (35, 'fragaria vesca)'),
#  (35, 'eucalyptus goniocalyx'),
#  (35, 'essential oils of tobacco leaves'),
#  (35, 'especially corn'),
#  (35, 'd-bornyl isovalerate is not'),
#  (35, 'crowberry (empetrum nigrum coll )'),
#  (35, 'coriander seeds'),
#  (35, 'clove polianthes tuberosa l'),
#  (35, 'chempedak (arthocarpus polyphema)'),
#  (35, 'ceylon citronella oil'),
#  (35, 'cedrol is found'),
#  (35, 'cardamine amara'),
#  (35, 'cape gooseberry'),
#  (35, 'canned potatoes'),
#  (35, 'brussels sprout'),
#  (35, 'brussel sprouts'),
#  (35, 'bone oil (together with several methyl homologues)'),
#  (35, 'black sea bream'),
#  (35, 'bakery products'),
#  (35, 'artemisia ferganensis'),
#  (35, 'aristolochia clematis'),
#  (35, 'arctic bramble (rubus articus l )'),
#  (35, 'and curcuma aeruginosa roxb'),
#  (35, 'american storax'),
#  (35, 'american potato chips'),
#  (35, 'alpinia species'),
#  (35, 'about 30 varieties of eucalyptus'),
#  (35, 'a mixture of d-'),
#  (35, 'a large number of essential oils'),
#  (34, 'wild rice (zizania aquatuca)'),
#  (34, 'white peru'),
#  (34, 'where it is present chiefly as cetyl palmitate'),
#  (34, 'wheat bran'),
#  (34, 'weinbrand brandy'),
#  (34, 'watercress'),
#  (34, 'two optically active isomers exist'),
#  (34, 'the turpentine of some varieties of pine'),
#  (34, 'the rhizomes of hedychium spicatum'),
#  (34, 'the presence of concentrated h2so4'),
#  (34, 'the natural product is always optically active'),
#  (34, 'the levorotatory'),
#  (34, 'the leaves'),
#  (34, 'the hydrolysates of crucifer seeds'),
#  (34, 'the fruits'),
#  (34, 'texas sage'),
#  (34, 'tangerines'),
#  (34, 'sweet fish'),
#  (34, 'sweet corn'),
#  (34, 'strawberry juice'),
#  (34, 'star fruit'),
#  (34, 'star anise'),
#  (34, 'split peas'),
#  (34, 'soybean products'),
#  (34, 'sopadilla fruit (achras sapota l )'),
#  (34, 'some natural food sources for l-lysine include lima beans'),
#  (34, 'shoyu (fermented soya hydrolysate)'),
#  (34, 'several foods including meat'),
#  (34, 'sauvignon grapes'),
#  (34, 'sauerkraut'),
#  (34, 'satureia montana'),
#  (34, 'sassafras leaves'),
#  (34, 'salmon roe'),
#  (34, 'rose apple'),
#  (34, 'roquefort cheese'),
#  (34, 'reportedly'),
#  (34, 'reported formed during'),
#  (34, 'reported as a constituent of'),
#  (34, 'reported as a constituent in'),
#  (34, 'red pepper'),
#  (34, 'red kidney'),
#  (34, 'raw turkey'),
#  (34, 'raw radish'),
#  (34, 'provolone cheese'),
#  (34, 'persea pubescens'),
#  (34, 'peas by enzymatic formation from lipids'),
#  (34, 'peanut (roasted)'),
#  (34, 'parmesan cheeses'),
#  (34, 'parme-san cheese'),
#  (34, 'originally isolated in'),
#  (34, 'orientalis'),
#  (34, 'oriental tobacco'),
#  (34, 'oil of mentha pulegium'),
#  (34, 'of litsea cubeba'),
#  (34, 'of eucalyptus bakeris (esterified)'),
#  (34, 'of artemisia dracunculus var'),
#  (34, 'not reported not found'),
#  (34, 'nectarines'),
#  (34, 'naturally occurring phytoalexin-like substance'),
#  (34, 'natural smoked flavor banana'),
#  (34, 'naranjilla fruit (solanum quitense lam )'),
#  (34, 'mushroom variety'),
#  (34, 'muscular tissues'),
#  (34, 'mung beans'),
#  (34, 'more than 40 vanilla varieties are cultivated'),
#  (34, 'more than 300 essential oils'),
#  (34, 'monarda fistulos'),
#  (34, 'mastic gum fruit'),
#  (34, 'litsea zeylanica'),
#  (34, 'lemongrass'),
#  (34, 'leek (raw)'),
#  (34, 'lavanda stoechas'),
#  (34, 'l-linalool has been reported'),
#  (34, 'jasmine absolute'),
#  (34, 'japanese whiskey'),
#  (34, 'its presence has'),
#  (34, 'it has been identified (free'),
#  (34, 'it exhibits two optically active isomers'),
#  (34, 'herniaria incana lam oil greece (2 60%)'),
#  (34, 'heated skim milk'),
#  (34, 'has been characterized'),
#  (34, 'grapevines'),
#  (34, 'grapefruit juice (citrus paradisi)'),
#  (34, 'grapefruit juice (citrus paradesi)'),
#  (34, 'grapefruit juice'),
#  (34, 'grapefruit'),
#  (34, 'grape wine'),
#  (34, 'geranium essential oil'),
#  (34, 'from flowers of furcraea gigantean'),
#  (34, 'fried cured pork'),
#  (34, 'fresh strawberry juice'),
#  (34, 'foeniculum vulgare piperitum oil (14 1%)'),
#  (34, 'flower absolutes'),
#  (34, 'fenu-greek'),
#  (34, 'essential oils of orthodon asaroniferum'),
#  (34, 'elderberry'),
#  (34, 'cowberry (vacinium vitis idaea l )'),
#  (34, 'coriander leaves'),
#  (34, 'cooked vegetables of the brassica genus'),
#  (34, 'cooked asparagus'),
#  (34, 'coconut oil has always fetched a premium price'),
#  (34, 'clove stem'),
#  (34, 'clove leaf'),
#  (34, 'clary sage'),
#  (34, 'citrus sinensis leaves'),
#  (34, 'citrus peel oils'),
#  (34, 'celery oil'),
#  (34, 'cape goose-berry'),
#  (34, 'cantaloupe'),
#  (34, 'canned beef stew'),
#  (34, 'camembert cheese'),
#  (34, 'calfornia pepper'),
#  (34, 'butterfat fishy flavor'),
#  (34, 'but detectable amounts'),
#  (34, 'brussels sprouts'),
#  (34, 'bourbon geranium'),
#  (34, 'bilberries'),
#  (34, 'beet juice'),
#  (34, 'beef liver'),
#  (34, 'bantu beer'),
#  (34, 'assorted types of lima'),
#  (34, 'artemisia vestita wall'),
#  (34, 'artemisia hausiliensis'),
#  (34, 'are reportedly the best natural sources of this amino acid'),
#  (34, 'applesauce'),
#  (34, 'apple wine'),
#  (34, 'anise (pimpinella anisum l )'),
#  (34, 'and thomas'),
#  (34, 'and prickly pear (opuntia ficus-indica)'),
#  (34, 'and from the fruits of pastinaca sativa'),
#  (33, 'wild strawberries'),
#  (33, 'white bread'),
#  (33, 'which only traces of cysteine are present'),
#  (33, 'wheat flour'),
#  (33, 'watercress (nasturtium officinale r'),
#  (33, 'violet flowers concrete'),
#  (33, 'verbena oil'),
#  (33, 'various wood distillates'),
#  (33, 'valerian root oil co2 extract'),
#  (33, 'tunisian rosemary'),
#  (33, 'the ripe fruit of capsicum annuum l'),
#  (33, 'the levo form is present'),
#  (33, 'the inactive form has been reported'),
#  (33, 'the bitter orange'),
#  (33, 'the basic fractions of whiskey'),
#  (33, 'tetradec-2-enal (cas no'),
#  (33, 'such as rum'),
#  (33, 'stored veal'),
#  (33, 'stearic acid is naturally present in'),
#  (33, 'stated to be of natural origin'),
#  (33, 'spineless monkey orange'),
#  (33, 'spineless mon-key orange'),
#  (33, 'sopa-dilla fruit (achras sapota l )'),
#  (33, 'some liquors (e g'),
#  (33, 'smoked pork belly'),
#  (33, 'smaller amounts of eugenol are'),
#  (33, 'several natural products: rose concentrate'),
#  (33, 'several distillates of plant origin'),
#  (33, 'sesame seed'),
#  (33, 'santalols are found among the'),
#  (33, 'r\xc3\xa9union geranium'),
#  (33, 'rose-mary oil corsica (10 7%)'),
#  (33, 'rose distillation waters'),
#  (33, 'rhodotorula glutinis var'),
#  (33, 'reported in'),
#  (33, 'reported found at'),
#  (33, 'reported as occurring in'),
#  (33, 'rancid oils has been observed'),
#  (33, 'provolone cheeses'),
#  (33, 'produced by some animals'),
#  (33, 'plum brandy'),
#  (33, 'piper officinarum'),
#  (33, 'peru balsam'),
#  (33, 'pennyroyal oil (mentha pulegium l )'),
#  (33, 'peel (feijoa sellowiana)'),
#  (33, 'peated malt'),
#  (33, 'pears'),
#  (33, 'passiflora edulis fruit juice'),
#  (33, 'over 100 natural products including apple'),
#  (33, 'other citrus species (flowers'),
#  (33, 'orris derivatives'),
#  (33, 'orange peel'),
#  (33, 'oil of citronella'),
#  (33, 'of spirea ulmaria'),
#  (33, 'of schizandra nigra max'),
#  (33, 'of ledum palustre'),
#  (33, 'of andropogon iwarancusa'),
#  (33, 'occurs frequently'),
#  (33, 'occurring as an ester or'),
#  (33, 'oak musk concrete'),
#  (33, 'nepeta betonicifolia c a'),
#  (33, 'nature: lavandula'),
#  (33, 'natural sources including cranberry'),
#  (33, 'mixture with the l-form'),
#  (33, 'mexican goosefoot'),
#  (33, 'methyliso-eugenoliferum'),
#  (33, 'metha vifidis var'),
#  (33, 'mentha oils'),
#  (33, 'mentha longifolia from south africa'),
#  (33, 'melanocarpa ell )'),
#  (33, 'meats'),
#  (33, 'many plants'),
#  (33, 'many fruits'),
#  (33, 'lovage seed'),
#  (33, 'lovage root'),
#  (33, 'lingonberry juice'),
#  (33, 'l-menthone is a constituent of'),
#  (33, 'kumquat peel oils'),
#  (33, 'kabosu peel oil (citrus spaerocarpa)'),
#  (33, 'heated leek'),
#  (33, 'heated blackberry'),
#  (33, 'heated beef'),
#  (33, 'guava fruit'),
#  (33, 'green mat\xc3\xa9'),
#  (33, 'green'),
#  (33, 'greece (1%)'),
#  (33, 'grape-fruit juice'),
#  (33, 'grape brandy (weinbrand)'),
#  (33, 'grape'),
#  (33, 'goat cheese'),
#  (33, 'geranium stem oil'),
#  (33, 'geranium leaf oil'),
#  (33, 'from a few plants'),
#  (33, 'fresh apple'),
#  (33, 'frankfurter'),
#  (33, 'eugenol probably occurs as glucoside'),
#  (33, 'ergot'),
#  (33, 'egg noodles'),
#  (33, 'dried bonito fish'),
#  (33, 'dates'),
#  (33, 'custard apple (annona atemoya)'),
#  (33, 'crisp bread'),
#  (33, 'corn mint oil (mentha arvenis)'),
#  (33, 'cooked pork liver'),
#  (33, 'cooked cured pork'),
#  (33, 'connective tissue'),
#  (33, 'cocoa beans'),
#  (33, 'citrus peel oils (orange'),
#  (33, 'citrus medica var'),
#  (33, 'citrus aurantium leaves'),
#  (33, 'citronellyl formate have been found'),
#  (33, 'champaca concrete (0 1%)'),
#  (33, 'champaca concrete'),
#  (33, 'ceylon citronella'),
#  (33, 'ceylon cardamom essential oil'),
#  (33, 'certa'),
#  (33, 'carob fruits (siliqua dulcis)'),
#  (33, 'canned sweet corn'),
#  (33, 'canned snap beans'),
#  (33, 'canned lima beans'),
#  (33, 'calabash nutmeg (monadora myristica dunal)'),
#  (33, 'caja fruit (spondias lutea l )'),
#  (33, 'cabernet sauvignon wine'),
#  (33, 'bulgarian tobacco'),
#  (33, 'boswellia serrata'),
#  (33, 'boletus edulis mushrooms'),
#  (33, 'boiled meat'),
#  (33, 'boiled eggs'),
#  (33, 'blueberries'),
#  (33, 'blue cheese'),
#  (33, 'black chokeberry (aronia'),
#  (33, 'black choke berry'),
#  (33, 'black beans'),
#  (33, 'bitter orange oil'),
#  (33, 'berry'),
#  (33, 'benzoic acid occurs naturally'),
#  (33, 'beer cognac'),
#  (33, 'beef tallow'),
#  (33, 'bachang (mangifera foetida l )'),
#  (33, 'as a volatile flavor component'),
#  (33, 'artemisia transiliensis'),
#  (33, 'artemisia arborescens l'),
#  (33, 'are formed by the action of lactic acid\xe2\x80\x93producing bacteria'),
#  (33, 'aqueous orange essence (trans-form)'),
#  (33, 'apricot (prunus armeniaca l )'),
#  (33, 'apricot (prunis armeniaca l )'),
#  (33, 'apple juice'),
#  (33, 'anise seeds'),
#  (33, 'angelica root oil'),
#  (33, 'and related species (zingiberaceae)'),
#  (33, 'algae'),
#  (33, 'agaricus mushroom'),
#  (33, 'a derivative of naturally occurring starch'),
#  (33, '(garcinia mangostana l )'),
#  (32, 'wild berries'),
#  (32, 'wheat flakes'),
#  (32, 'violet roots'),
#  (32, 'vanilla bean'),
#  (32, 'uncured smoked pork'),
#  (32, 'uncured boiled pork'),
#  (32, 'tomato puree'),
#  (32, 'toasted oats'),
#  (32, 'thuja occidentalis'),
#  (32, 'three isomers (\xce\xb1-'),
#  (32, 'their juices'),
#  (32, 'the \xce\xb2-isomer is the most frequently encoun-'),
#  (32, 'the seeds of various cruciferae'),
#  (32, 'the seeds of brassica napus var'),
#  (32, 'the racemic form has been'),
#  (32, 'the leaves of rhododendron fauriae var'),
#  (32, 'the largest amounts (80 to 85%)'),
#  (32, 'the l-isomer'),
#  (32, 'the l-form is found'),
#  (32, 'the l-form has been'),
#  (32, 'the essence of seseli tortuosum'),
#  (32, 'the essence of artemisia santolinoflia'),
#  (32, 'the d-form has been found'),
#  (32, 'the d-form has been'),
#  (32, 'the commercial product is a mixture of cis-'),
#  (32, 'teucrium chamaedrys'),
#  (32, 'tapereba (spondias lutea)'),
#  (32, 'sweet potato'),
#  (32, 'sweet orange'),
#  (32, 'sweet cherry'),
#  (32, 'strawberries'),
#  (32, 'spineless monkey orange (strychnos madagasc)'),
#  (32, 'southern pea'),
#  (32, 'some citrus fruits'),
#  (32, 'sherry'),
#  (32, 'sheep cheese'),
#  (32, 'salted'),
#  (32, 'russian star anise'),
#  (32, 'rosemary oil'),
#  (32, 'roasted pork'),
#  (32, 'roasted nuts'),
#  (32, 'roasted meat'),
#  (32, 'roast peanut'),
#  (32, 'roast barley'),
#  (32, 'reported identified'),
#  (32, 'reported found as a constituent'),
#  (32, 'reported found among the volatile components'),
#  (32, 'reported as occurring naturally'),
#  (32, 'reported as naturally occurring'),
#  (32, 'red currants'),
#  (32, 'rabbiteye blueberry'),
#  (32, 'pummelo peel'),
#  (32, 'prepared from wood'),
#  (32, 'pouching tea'),
#  (32, 'plum (fresh)'),
#  (32, 'piper longum'),
#  (32, 'peel oils of orange'),
#  (32, 'pawpaw (asemina triloba dunal )'),
#  (32, 'passion fruit juice'),
#  (32, 'parsnip root'),
#  (32, 'oyster'),
#  (32, 'over 170 natural products including apricot'),
#  (32, 'over 150 natural products including apricot'),
#  (32, 'other plants'),
#  (32, 'origanum (spanish)'),
#  (32, 'orange juice (citrus sinensis l'),
#  (32, 'orange juice'),
#  (32, 'oil grosso (0 05%)'),
#  (32, 'of mentha arvensis'),
#  (32, 'of litsea odorifera'),
#  (32, 'of eryngium facidum'),
#  (32, 'of callitris glauca'),
#  (32, 'occurring as the d-'),
#  (32, 'oat products'),
#  (32, 'not reported found nature'),
#  (32, 'naturally occurring'),
#  (32, 'more than 250 distillates from plants'),
#  (32, 'more than 150 derivatives from leaves'),
#  (32, 'many cheeses'),
#  (32, 'many berries'),
#  (32, 'mammee apple'),
#  (32, 'loganberries'),
#  (32, 'lime oil distilled peru (0 06%)'),
#  (32, 'lime essence'),
#  (32, 'lemon papaya'),
#  (32, 'leaves'),
#  (32, 'leaf oil cameroon (10 9%)'),
#  (32, 'leaf oil cameroon (1 20%)'),
#  (32, 'jamaican rum'),
#  (32, 'isolated from cane sugar fermentation broth'),
#  (32, 'hop oil beer'),
#  (32, 'heated'),
#  (32, 'grilled pork'),
#  (32, 'grilled beef'),
#  (32, 'greece'),
#  (32, 'grapes'),
#  (32, 'grapefruit peel oil'),
#  (32, 'grapefruit essence'),
#  (32, 'grapefruit blossoms'),
#  (32, 'gardenia flower oil'),
#  (32, 'from seeds of nectandra puchury'),
#  (32, 'from raisins'),
#  (32, 'fried potato'),
#  (32, 'fried garlic'),
#  (32, 'fresh strawberries'),
#  (32, 'french fries'),
#  (32, 'frankfurters'),
#  (32, 'food research) (tno'),
#  (32, 'filbert nuts'),
#  (32, 'feijoa fruit'),
#  (32, 'european cranberry'),
#  (32, 'currant buds'),
#  (32, 'coriander seed (coriandrum sativum l )'),
#  (32, 'coriander leaf (coriandrum sativum l )'),
#  (32, 'cooked raspberries'),
#  (32, 'cooked meats'),
#  (32, 'coffee aroma'),
#  (32, 'cocoa leaves'),
#  (32, 'clove essential oil'),
#  (32, 'cloudberries'),
#  (32, 'citrus fruit juices'),
#  (32, 'cinnamon root bark'),
#  (32, 'chive (allium schoenoprasum l )'),
#  (32, 'chinese quince peel'),
#  (32, 'cherry'),
#  (32, 'celery'),
#  (32, 'cassis fruit juice'),
#  (32, 'cashew apple'),
#  (32, 'carrot'),
#  (32, 'carphephorus'),
#  (32, 'caraway seed'),
#  (32, 'canned beets'),
#  (32, 'burley'),
#  (32, 'breads'),
#  (32, 'boletus scaber boll'),
#  (32, 'blue cheeses'),
#  (32, 'blackberries'),
#  (32, 'black pepper'),
#  (32, 'black currant buds'),
#  (32, 'black currant berry juice'),
#  (32, 'black choke cherry'),
#  (32, 'bergamot oil'),
#  (32, 'beef extract'),
#  (32, 'barely'),
#  (32, 'baked potato'),
#  (32, 'as a volatile flavor components'),
#  (32, 'arrack'),
#  (32, 'aromas'),
#  (32, 'apples'),
#  (32, 'antheum sowa'),
#  (32, 'anise hyssop'),
#  (32, 'anise brandy'),
#  (32, 'and petitgra'),
#  (32, 'american peppermint'),
#  (32, 'american cranberry'),
#  (32, 'acacial farnesiana'),
#  (32, 'a volatile flavor component of potato chips'),
#  (31, 'ylang-ylang oil (probably as p-cresyl acetate)'),
#  (31, 'yellow passion fruit juice'),
#  (31, 'yellow passion fruit aroma'),
#  (31, 'winter savory'),
#  (31, 'white truffle'),
#  (31, 'wheaten'),
#  (31, 'vinegar'),
#  (31, 'various spice'),
#  (31, 'variable amounts it is a constituent of yeast'),
#  (31, 'valerian root oil at 0 1 to 0 4%'),
#  (31, 'up to 91% eucalyptol'),
#  (31, 'trace amounts'),
#  (31, 'tilsit cheese'),
#  (31, 'the salt is not found to occur naturally'),
#  (31, 'the red algae of polysiphonia fastigiata'),
#  (31, 'the racemic form are known'),
#  (31, 'the most common is the l-iso-mer'),
#  (31, 'the leaves of phebalium dentatum'),
#  (31, 'the l-form is'),
#  (31, 'the distillate from flowers of boronia megatisma nees'),
#  (31, 'the dextro form is present'),
#  (31, 'sweet pep-per'),
#  (31, 'summer savory'),
#  (31, 'starfruit (averrhoa carambola l)'),
#  (31, 'spineless monkey orange (strychnos madagasc )'),
#  (31, 'spearmint oil'),
#  (31, 'sour cherries'),
#  (31, 'sometimes esterified'),
#  (31, 'small amounts'),
#  (31, 'several volatile oils: clove oil'),
#  (31, 'several food products including papayas'),
#  (31, 'sesquiterpene'),
#  (31, 'seaweed'),
#  (31, 'sea buckthorn'),
#  (31, 'scrambled egg'),
#  (31, 'saxifragaceae'),
#  (31, 'satsuma'),
#  (31, 'rooibus tea (aspalathus linearis)'),
#  (31, 'romano cheese'),
#  (31, 'roasted uncured pork'),
#  ...]

# %%
asc_comp_ing = {k.decode('utf-8'):v for k,v in comp_ing_dict.iteritems()}

# %%
asc_comp_ing.keys()
# Out:
# [u'macadamia nuts',
#  u'mackerel',
#  u'yellow',
#  u'naranjilla fruit (solanum quitense lam )',
#  u'asian',
#  u'grapefruit peel oil',
#  u'mandarin) to as low as 1% (palmarosa)',
#  u'black chokeberry',
#  u'the product obtained from natural sources is probably levorotatory',
#  u'hyssop',
#  u'over 300 natural sources including apples',
#  u'it exhibits a positive optical rotation',
#  u'mate',
#  u'leaf oil (2%)',
#  u'aromas:',
#  u'sweet fish',
#  u'several natural products: rose concentrate',
#  u'buchu',
#  u'the seeds of brassica napus var',
#  u'reported as occurring',
#  u'brandy distillate',
#  u'raw lean fish',
#  u'several plants',
#  u'reported as the most abundant free amino acid',
#  u'figs',
#  u'alpinia',
#  u'strawberry jam',
#  u'sheep milk',
#  u'free or esterified borneol has been identified',
#  u'petitgrain',
#  u'such as rum',
#  u'cassia oil',
#  u'addition to the optically inactive form',
#  u'carnosine',
#  u'ruta pinnata leaf oil',
#  u'salvia sclarea',
#  u'(vaccinium',
#  u'almond',
#  u'lesquerella seed meal',
#  u'lavender',
#  u'japanese whiskey',
#  u'japanese seafood',
#  u'phenylalanine is the most commonly found aromatic amino acid',
#  u'of hops (humulus lupulus)',
#  u'blue',
#  u'raw chicken',
#  u'canned orange juice on storage',
#  u'umbelliferae',
#  u'tolu',
#  u'white wine',
#  u'white grape var',
#  u'salvia spinosa)',
#  u'grapefruit essence',
#  u'litchi',
#  u'spineless mon-key orange',
#  u'garde-nia',
#  u'roasted filberts as well',
#  u'filbert',
#  u'jasmine',
#  u'pimento berry',
#  u'(raw',
#  u'reported',
#  u'pepper-mint oil',
#  u'(allium',
#  u'cooked mutton fat',
#  u'leaves',
#  u'cooked cabbage',
#  u'methyliso-eugenoliferum',
#  u'chicken liver',
#  u'tomato paste',
#  u'narcissus absolute (0 09%)',
#  u'melaleuca',
#  u'acetic acid or acetates are present',
#  u'of zingiber officinale',
#  u'butter oil',
#  u'metha vifidis var',
#  u'sparkling wines',
#  u'neroli oil (with geraniol)',
#  u'the trans',
#  u'aqueous orange essence (trans-form)',
#  u'meats',
#  u'soybean',
#  u'shoyu',
#  u'feyoa fruit (feijoa sellowiana)',
#  u'brown rice',
#  u'yellow passion friut',
#  u'flower oil (3 2%)',
#  u'china (0 14%)',
#  u'several foods including meat',
#  u'the essence of the blenheim variety of apricot',
#  u'smoked fatty fish',
#  u'blueberry',
#  u'fractions',
#  u'sauvignon',
#  u'tahitian',
#  u'myrrh',
#  u'pecan',
#  u'sri lanka (0 09\u20130 15%)',
#  u'scallop',
#  u'present in',
#  u'vitis species',
#  u'pickled ham',
#  u'because of the presence',
#  u'cinnamon oil (cinnamomum cassia nees ex bl ) from which it is separated as stearoptene',
#  u'lamb\u2019s',
#  u'roman chamomile',
#  u'honey-suckle',
#  u'wort',
#  u'paste (trassi)',
#  u'root',
#  u'nature (salvia officinalis',
#  u'chayote',
#  u'india (0 22%)',
#  u'cockroaches as attractant pheromone',
#  u'cranberry press residue',
#  u'honey',
#  u'apple wine',
#  u'it is one of the active constituents of creosote',
#  u'the synthetic product is optically levorotatory',
#  u'pinto',
#  u'piper lowong bi',
#  u'milkfat lipids',
#  u'nuts',
#  u'guava peel',
#  u'while the d-form is found',
#  u'esterified)',
#  u'widespread',
#  u'pentaphylla',
#  u'fried beef',
#  u'wild rice (zizania aquatuca)',
#  u'botryized wine',
#  u'the autooxidation of lard',
#  u'of artemisia dracunculus var',
#  u'cape goose-berry',
#  u'essential oils of orthodon asaroniferum',
#  u'frozen peas',
#  u'custard apple (annona atemoya)',
#  u'nobiru (allium grayi regal)',
#  u'russian star anise',
#  u'fish products',
#  u'roots of atropa belladonna',
#  u'soy bean',
#  u'hyssop oil (17 4%)',
#  u'green',
#  u'orange (bitter) peel oil',
#  u'lime oil distilled mexico (0 07%)',
#  u'oysters',
#  u'of the three possible isomers of n-valeric acid',
#  u'buchu leaf oil (22 3%)',
#  u'and bourbon vanilla',
#  u'raspberry brandy',
#  u'leaf oil',
#  u'the mushroom variety trametes graveolens',
#  u'and patchouli',
#  u'artemisia vestita wall',
#  u'russian cheeses',
#  u'peru balsam from honduras',
#  u'japan',
#  u'winter savory',
#  u'the levorotatory',
#  u'(flowers)',
#  u'ylang ylang oil iii (0 27%)',
#  u'but-ter',
#  u'udo (aralia cordata thunb )',
#  u'various dairy products',
#  u'of cinnamomum cassia nees ex bi',
#  u'avocado',
#  u'bigarade',
#  u'carvi',
#  u'fig',
#  u'hirsuta',
#  u'antheum graveolens',
#  u'caprifoliaceae)',
#  u'coffee',
#  u'lentils were found to conta',
#  u'eucalyptus amigdalina',
#  u'heated beef fat',
#  u'cardamine amara',
#  u'wheaten',
#  u'lippia alnifolia schau',
#  u'peel oil',
#  u'bread',
#  u'ing between 111',
#  u'lanb\u2019s lettuce',
#  u'meat',
#  u'thyme',
#  u'(durio',
#  u'potatoes',
#  u'mounta',
#  u'black currant berry juice',
#  u'and several varieties of orchid',
#  u'some plants',
#  u'reported found among the steam-distillable phenols from the alcoholic fermentation of cereal grains',
#  u'pompona)',
#  u'rosemary',
#  u'bone',
#  u'the free state',
#  u'reported found among the volatile components of hop',
#  u'milk powder (skim)',
#  u'mustard (brassica species)',
#  u'a few banana species',
#  u'prawn',
#  u'spineless monkey orange',
#  u'turnip',
#  u'navy',
#  u'a volatile flavor component of potato chips',
#  u'hirtum',
#  u'pawpaw (asemina triloba dunal )',
#  u'mentha',
#  u'raw cured pork',
#  u'their juices',
#  u'reported as a component of mastic leaf oil at 0 07%',
#  u'of bergamot',
#  u'angelica seed oil co2 extract (0 50%)',
#  u'spineless monkey orange (strychnos madagasc )',
#  u'champaca concrete (0 1%)',
#  u'swiss cheese',
#  u'extremely widespread',
#  u'eucalyptus globules',
#  u'clove buds',
#  u'agaricus mushroom',
#  u'the world market because of its high (45%) lauric acid content',
#  u'other plants (coffee',
#  u'pork (fried)',
#  u'the basic fractions of whiskey',
#  u'corresponds to the dl-form of dihydro-citronellol',
#  u'grapes',
#  u'grape brandy',
#  u'(annona',
#  u'peppermint oils',
#  u'coffee aroma',
#  u'raisin',
#  u'feijoa fruit',
#  u'fistulosa',
#  u'ciliata',
#  u'garlic',
#  u'reported as a major constituent of spermaceti oil',
#  u'apricot (prunis armeniaca l )',
#  u'citronella oils',
#  u'bicyclic',
#  u'japanese peppermint',
#  u'citrus fruits',
#  u'grilled beef',
#  u'jambos alston)',
#  u'bois de rose',
#  u'lettuce',
#  u'its presence has',
#  u'of litsea cubeba',
#  u'tamarind',
#  u'sour cherries',
#  u'fresh plum',
#  u'distilled lime peel oil',
#  u'oatmeal (cooked)',
#  u'provolone',
#  u'bonito',
#  u'licorice',
#  u'roasted filbert (corylus avellano)',
#  u'lime oil',
#  u'heated beans',
#  u'roasted peanut (0 02 to 0 11 ppm)',
#  u'bitter',
#  u'kiwi',
#  u'nearly 300 natural sources including apple',
#  u'lavender essence',
#  u'bacon',
#  u'of juniperus sabina l',
#  u'japanese',
#  u'beer cognac',
#  u'hazelnut',
#  u'fatty fish',
#  u'cured pork',
#  u'mustard oil',
#  u'geranium leaf oil',
#  u'citronellyl formate have been found',
#  u'condiments',
#  u'jam',
#  u'crispbread',
#  u'red currant',
#  u'french fries',
#  u'wheat bread',
#  u'potato products',
#  u'dihydro-\u03b3-ionone has been reported as a constituent',
#  u'heated pork meat',
#  u'ex murr )',
#  u'ginger',
#  u'lemon juice',
#  u'seed',
#  u'chrysanthemum japonicum sinense',
#  u'orange leaf',
#  u'spearmint oil',
#  u'mint',
#  u'beet root',
#  u'of morus bombysic',
#  u'(psidium',
#  u'hyssop oil co2 extract (16 5%)',
#  u'asymmetric',
#  u'clove polianthes tuberosa l',
#  u'kiwifruit',
#  u'stated to be of natural origin',
#  u'black-berry',
#  u'several distillates of plant origin',
#  u'ceylon cinnamon',
#  u'lovage seed',
#  u'scrambled egg',
#  u'elderberry juice',
#  u'cupressus lusitanica',
#  u'over 150 natural products including apricot',
#  u'shallots',
#  u'coriander leaves',
#  u'litsea cubeba',
#  u'watercress',
#  u'verbena oil',
#  u'nobira (allium grayi regal)',
#  u'herniaria incana lam oil greece (2 60%)',
#  u'rue oil cuba (0 07%)',
#  u'pineapple',
#  u'lambs\u2019 lettuce (valerianella locusta)',
#  u'ocimum canum',
#  u'black currant (buds)',
#  u'rhodinyl formate as such has not been',
#  u'the seeds',
#  u'mastic gum fruit',
#  u'currants',
#  u'the commercial product is the racemic form',
#  u'filbert nuts',
#  u'wood spirit',
#  u'roasted pecan',
#  u'tequila',
#  u'sage',
#  u'roasted hazelnuts',
#  u'as a component in',
#  u'fresh strawberries',
#  u'fennel',
#  u'fragaria vesca)',
#  u'mastic gum leaf oil',
#  u'rose wine',
#  u'xanthorrhoea hastilis',
#  u'chamomile',
#  u'shellfish',
#  u'various plants',
#  u'celery',
#  u'several varieties of mushrooms',
#  u'animal tissues',
#  u'tea (black)',
#  u'cherry brandy',
#  u'mentha species',
#  u'canned sweet corn',
#  u'piperascens',
#  u'rice',
#  u'raw cabbage',
#  u'microbial fermented tea',
#  u'guaiene',
#  u'either free or esterified: rose',
#  u'heated skim milk',
#  u'hog plum (spondias mombins l )',
#  u'durian (durian zibethinus)',
#  u'of curcuma longa l',
#  u'passiflora mollisima',
#  u'watermelon',
#  u'cherimoya (annona cherimola)',
#  u'muscat grape',
#  u'botanical',
#  u'cooked potato',
#  u'chinese cinnamon',
#  u'india (0 11%)',
#  u'soybean oil',
#  u'of rosa rugosa',
#  u'4-carvomenthenol (dextro) has been',
#  u'lepidium sativum',
#  u'hatsutake)',
#  u'grapefruit juice (vitis labrusca l ) papaya (carica papaya l )',
#  u'roasted filberts',
#  u'rose distillation waters',
#  u'grilled',
#  u'of bitter almonds',
#  u'of betel',
#  u'roasted',
#  u'laurel leaves',
#  u'chicory root',
#  u'violet roots',
#  u'juniper oil',
#  u'over 100 natural products including apple',
#  u'raw shrimp',
#  u'gruyere cheeses',
#  u'natural borneol can be d or l rotatory',
#  u'verlotorum',
#  u'leaf oil cameroon (1 20%)',
#  u'yogurt',
#  u'dried kidney beans',
#  u'pineapple (anans comoscus)',
#  u'cloudberry (rubus chamaemorus l )',
#  u'satureia montana',
#  u'nature',
#  u'cunninghamii',
#  u'clove bud',
#  u'however',
#  u'buchu leaf',
#  u'feta cheese',
#  u'carbon',
#  u'cinnamomum camphora var',
#  u'narcissus jonquilla l',
#  u'essential oils of citrus peels',
#  u'various wood distillates',
#  u'cured ham',
#  u'probably formed from ferulic acid',
#  u'cow',
#  u'extracts',
#  u'yellow passion fruit juice',
#  u'katsuo-bishi (dried bonito)',
#  u'meyer oil turkey (39 20%)',
#  u'ocimum sanctum l',
#  u'cod',
#  u'cartilage',
#  u'roasted turkey',
#  u'sopadilla fruit',
#  u'olive oil',
#  u'calamus',
#  u'black chokeberry (aronia melanocarpa ell )',
#  u'the presence of mineral acids',
#  u'corn grits',
#  u'boletus edulis mushrooms',
#  u'elderberry fruit',
#  u'pepino fruit',
#  u'chinese quince fruit',
#  u'pineapple guava (feyoa fruit',
#  u'roasted coffee',
#  u'from roots of valerian',
#  u'beef',
#  u'caraway seed',
#  u'parsley',
#  u'been',
#  u'beer',
#  u'phebalium dentatum',
#  u'other plants',
#  u'peas by enzymatic formation from lipids',
#  u'marine brouno',
#  u'blackberry brandy',
#  u'raw cauliflower',
#  u'veal round',
#  u'mushroom',
#  u'of bitter orange',
#  u'over 230 natural sources including apple',
#  u'black beans',
#  u'some varieties of mushrooms',
#  u'the odorous principle obtained by extraction',
#  u'roasted onion',
#  u'milk powder',
#  u'it is a constituent of wine',
#  u'fermented beverages',
#  u'the two optically active isomers are found',
#  u'botrytised wine',
#  u'wheaten bread',
#  u'ylang ylang oil i',
#  u'reported found among the volatile constituents of grape var',
#  u'guajava',
#  u'canned potatoes',
#  u'and extraction products: lemongrass',
#  u'jackfruit (artocarpus heterophyllus larn )',
#  u'sweet grass oil',
#  u'pine needle',
#  u'corn mint',
#  u'chervil',
#  u'tonka bean (dipteryx odorata) seed',
#  u'juice (lemon',
#  u'has been reported',
#  u'tissue',
#  u'found in',
#  u'heated milk fat',
#  u'cinnamon leaf oil',
#  u'(byrsinoma crassifolia)',
#  u'japonicum albi-florum',
#  u'cooked pork',
#  u'several stereoisomers',
#  u'papayas',
#  u'sweet fennel',
#  u'laurel (laurus nobilis l )',
#  u'salted salmon',
#  u'many plants',
#  u'jamaican rum',
#  u'pennyroyal oil',
#  u'european',
#  u'ylang ylang oil iii (0 02%)',
#  u'boiled',
#  u'papaya',
#  u'cistus labdanum and',
#  u'romano cheeses',
#  u'roasted peanut',
#  u'rutaceae',
#  u'flavor component of onion oil (trans-form)',
#  u'tuna',
#  u'acacia farnesiana willd',
#  u'butter',
#  u'other varieties of mush-room',
#  u'cymbopogon javanensis',
#  u'passiflora edulis fruit juice',
#  u'cooked egg',
#  u'juice (passiflora edulis l )',
#  u'(0 08%)',
#  u'of palmarosa',
#  u'red pepper',
#  u'japanese peppermint oil',
#  u'the bark of sweet birch',
#  u'smoked',
#  u'milk products',
#  u'crisp-bread',
#  u'kale',
#  u'cooked pork liver',
#  u'roasted)',
#  u'bulgarian tobacco',
#  u'many berries',
#  u'ham',
#  u'cherry',
#  u'two optically active forms have been isolated',
#  u'roast beef',
#  u'artemisia brevifolia',
#  u'cognac',
#  u'kelp',
#  u'galanga',
#  u'from seeds of nectandra puchury',
#  u'from which benzoic acid is extracted by sublimation',
#  u'mulberry leaves',
#  u'lovage oil',
#  u'russian cheese',
#  u'port wine',
#  u'the auto-oxidation of lipids',
#  u'lemon peel',
#  u'pulegioides',
#  u'katsuobushi (dried bonito)',
#  u'guava fruit (psidium guajava l )',
#  u'mentha piperta',
#  u'monarda fistulos',
#  u'occurring',
#  u'flavoring',
#  u'chinese star anise',
#  u'cornmint oil',
#  u'soursop',
#  u'as well as',
#  u'nira (allium tuberosum rotti)',
#  u'nira (allium tuberosum rottl )',
#  u'corn mint oil (mentha arvensis l',
#  u'has been characterized',
#  u'acacia dealbata',
#  u'baked potato',
#  u'roasted peanut (arachis hypogea)',
#  u'reported used',
#  u'black currant buds',
#  u'the racemic form are known',
#  u'distilled liquors',
#  u'carrot root',
#  u'okra',
#  u'the d-isomer has not been',
#  u'roasted almonds',
#  u'from leaves of eriostemon coxii',
#  u'autooxidized lard',
#  u'grapefruit',
#  u'lemon petitgrain',
#  u'mush-room',
#  u'artemisia herba alba',
#  u'peel',
#  u'orange juice (citrus sinensis l',
#  u'the seeds of various cruciferae',
#  u'corn',
#  u'and related species (zingiberaceae)',
#  u'the l-form is found',
#  u'apple essence',
#  u'goshizanese',
#  u'red currants',
#  u'ed egg',
#  u'constituent of copaiba balsam',
#  u'tea (green)',
#  u'lingonberry',
#  u'yellow passion fruit aroma',
#  u'plum',
#  u'italy (7 98%)',
#  u'lime peel oil',
#  u'romano)',
#  u'naturally occurring',
#  u'hyssopus officinalis l',
#  u'octopus',
#  u'gingergrass',
#  u'artemisia ferganensis',
#  u'storax',
#  u'smoked pork',
#  u'leek (raw)',
#  u'buckthorn (hippophae rhamnoides l )',
#  u'cyanuric',
#  u'the aromas of straw-berry',
#  u'it has',
#  u'pears',
#  u'of illicium religiosum',
#  u'clove stem',
#  u'many fruits',
#  u'scotch whis-key',
#  u'patchouli',
#  u'roasted peanuts',
#  u'cassis fruit juice',
#  u'blue cheese',
#  u'the racemic form is present',
#  u'avocados',
#  u'laurus nobilis',
#  u'of eucalyptus bakeris (esterified)',
#  u'mushroom variety',
#  u'galbanum oil',
#  u'form',
#  u'several food products',
#  u'spike',
#  u'artichoke',
#  u'parsnip root',
#  u'orthodon linalooliferum (80%)',
#  u'grilled pork',
#  u'currant buds',
#  u'roasted uncured pork',
#  u'china (0 01%)',
#  u'are formed by the action of lactic acid\u2013producing bacteria',
#  u'sopa-dilla fruit (achras sapota l )',
#  u'the dry distillate of manilla copal',
#  u'meat fats',
#  u'eucalyptus globulus',
#  u'vivo',
#  u'whiskey',
#  u'rasp-berry',
#  u'heated soybean',
#  u'brewed tea',
#  u'of callitris glauca',
#  u'more',
#  u'beverages including fresh apple',
#  u'mangos (fresh)',
#  u'raspberry (rubus idaecus l )',
#  u'eggs (boiled)',
#  u'fresh plums',
#  u'urtica dioica',
#  u'roasted barley',
#  u'the optically inactive form is found',
#  u'canned peas',
#  u'oxidized flavor of skim milk',
#  u'heated chicken',
#  u'cassia',
#  u'acacia',
#  u'starfruit',
#  u'cloud-berry oil',
#  u'salmon oil',
#  u'starfruit (averrhoa carambola l)',
#  u'leek',
#  u'optically',
#  u'truffles',
#  u'myrtle oil',
#  u'widely distributed',
#  u'citrus limonia form california',
#  u'pouching tea',
#  u'black choke cherry',
#  u'several varieties of berries',
#  u'smoked pork belly',
#  u'rapeseed',
#  u'sturgeon caviar',
#  u'grapevines',
#  u'rancid oils has been observed',
#  u'only isovaleric acid has extensive application',
#  u'radishes',
#  u'potato',
#  u'fresh mango',
#  u'guava fruit',
#  u'verva',
#  u'of camphor',
#  u'particularly cypress',
#  u'boiled mutton',
#  u'bitter fennel',
#  u'calfornia pepper',
#  u'potato (boiled',
#  u'beet juice',
#  u'oil of lavandin',
#  u'connective tissue',
#  u'odorata',
#  u'guava',
#  u'and chiefly vanilla pods (vanilla planifolia',
#  u'milk',
#  u'mentha longifolia from south africa',
#  u'sour milk',
#  u'grape',
#  u'pennyroyal oil (mentha pulegium l )',
#  u'trans-isomers',
#  u'bracteata',
#  u'more than 50% l-citronellol',
#  u'orthodon methylisoeugenoliferum f',
#  u'of niaouli',
#  u'bitter orange juice',
#  u'hyacinth (hyacinthus orientalis l ) essential oil',
#  u'and beer',
#  u'melon',
#  u'gum benzoin',
#  u'tobacco)',
#  u'lime)',
#  u'brown',
#  u'smaller galanga (alpinium officinarum hance)',
#  u'ceylon cardamom essential oil',
#  u'fried garlic',
#  u'chicken (cooked)',
#  u'artemisia frigida',
#  u'occurring as the d-',
#  u'cocoa bean',
#  u'tangerine juice',
#  u'lamb liver',
#  u'orange oil from leaves',
#  u'monarda punctata',
#  u'mat\xe9 (green',
#  u'honduras balsams',
#  u'loganberry',
#  u'because of the yellow color developed',
#  u'smaller amounts of eugenol are',
#  u'pork',
#  u'the oxidative decomposition of heated lard',
#  u'enokidake',
#  u'black currant grapes',
#  u'tubers of aconitum napellus',
#  u'mastic gum oil',
#  u'as a flavor component',
#  u'currant',
#  u'dried',
#  u'frankfurter',
#  u'the juice of citrus fruits',
#  u'black currants',
#  u'port',
#  u'butter as a glyceride',
#  u'anise seeds',
#  u'cinnamon root',
#  u'and buckwheat',
#  u'other citrus species (flowers',
#  u'sour-sop',
#  u'sassafras officinale',
#  u'camphor wood oil',
#  u'of spirea ulmaria',
#  u'the d-form occurs',
#  u'ground',
#  u'r\xe9union geranium',
#  u'benzoic acid occurs naturally',
#  u'corymbosus',
#  u'mussels',
#  u'tabasco pepper',
#  u'french',
#  u'pubescens)',
#  u'french lavender',
#  u'peanut oil',
#  u'california lemon',
#  u'green bell pepper',
#  u'but very seldom',
#  u'vitis vinifera l',
#  u'celery root',
#  u'various callitris species (c',
#  u'rose oil',
#  u'other varieties of mushrooms',
#  u'salicifolia maxim',
#  u'(raw)',
#  u'wine',
#  u'cinnamon',
#  u'peel oils',
#  u'cognac oil',
#  u'levisticum officinale (lovage)',
#  u'cinnamon bark oil (cinnamomum zeylanicum blume)',
#  u'mushroom (shiitake',
#  u'a major constituent of collagen',
#  u'fried chicken',
#  u'soybeans',
#  u'radish',
#  u'mixed with the l-form it is found',
#  u'bacon fat',
#  u'corn oil',
#  u'rose apple',
#  u'sunflower oil (cis-',
#  u'pepino fruit (solanum muricatum)',
#  u'raspberry',
#  u'juniper berry (alcoholic extract)',
#  u'piper longum',
#  u'sake',
#  u'fruit (carica pentagona heilborn)',
#  u'orange essence',
#  u'wood',
#  u'peru',
#  u'strawberry fruit',
#  u'fresh coffee',
#  u'apple juice',
#  u'it is contained',
#  u'quantitatively assessed',
#  u'feyoa fruit',
#  u'chocolate',
#  u'over 120 natural food products',
#  u'olive',
#  u'malt whiskey',
#  u'spearmint',
#  u'straw-berry',
#  u'myrtus communis',
#  u'prumus persica',
#  u'ginger grass',
#  u'sour',
#  u'commonly found among the degradation products of proteins',
#  u'potato chip',
#  u'pumpkin',
#  u'some sea algae',
#  u'the \u03b2-isomer is the most frequently encoun-',
#  u'isomer',
#  u'eucalyptus oil',
#  u'larger amounts in',
#  u'fish oil',
#  u'champaca concrete at 0 01%',
#  u'(0 10%)',
#  u'fairly siz-able amounts',
#  u'anise brandy',
#  u'jasmine absolute china (0 05%)',
#  u'nature including acacia',
#  u'bourbon (vanilla plantifolia andrews)',
#  u'other vitis species',
#  u'fruit oil',
#  u'japanese ho leaf oil',
#  u'hop oil beer',
#  u'tomato aroma',
#  u'absolute',
#  u'civet (cis-form)',
#  u'been identified',
#  u'typhia',
#  u'cooked apple',
#  u'ylang ylang oil ii',
#  u'gelatin',
#  u'cooked blackberry',
#  u'peanuts (raw)',
#  u'the l-form has been',
#  u'goat cheese',
#  u'coconut (1 ppm)',
#  u'reported to be found',
#  u'fagus species',
#  u'bachang (mangifera foetida l )',
#  u'natural',
#  u'prob-ably',
#  u'from violet flowers (21%)',
#  u'rupescens',
#  u'mango',
#  u'reported as a constituent in',
#  u'roots of alliaria officinalis',
#  u'jerusalem artichoke (helianthus tuberosus)',
#  u'japanese horseradish',
#  u'rye breads',
#  u'reported found as a component in',
#  u'grape musts',
#  u'palm nut oils',
#  u'the ripe fruit of capsicum annuum l',
#  u'most plant',
#  u'grapefruit peel',
#  u'it has been reported',
#  u'lavage leaf',
#  u'salvia',
#  u'the cultures of certa',
#  u'forms',
#  u'labdanum leaf oil (0 50%)',
#  u'hydrolysis from aloe wood (aquilaria algallocha roxb )',
#  u'reportedly identified',
#  u'of eucalyptus polibrac tea has been reported to conta',
#  u'heated pork fat',
#  u'cheeses (parmesan',
#  u'ex poljak oil',
#  u'hop',
#  u'wild marjoram',
#  u'fibrous prote',
#  u'lovage corn oil',
#  u'shredded wheat',
#  u'distilled from the wood of myrocarpus fastigiatus',
#  u'prunes',
#  u'cistus labdaniferus',
#  u'laurel leaf oil turkey (0 10%)',
#  u'more than 150 derivatives from leaves',
#  u'peel (feijoa sellowiana)',
#  u'raw radish',
#  u'sorbitol is one of the most widely found sugar alcohols',
#  u'thymus',
#  u'goat',
#  u'bulgarian peppermint',
#  u'two optically inactive isomers',
#  u'heracleum',
#  u'french peppermint',
#  u'parmesan cheese',
#  u'vitis labrusca l',
#  u'artemisia camphorata',
#  u'the stereochemistry of santalols has been discussed by brieger (burdock',
#  u'roasted virginia tobacco',
#  u'of heracelum villosum fisch',
#  u'oil grosso (0 05%)',
#  u'cumin',
#  u'shoyu (fermented soy hydrolysate)',
#  u'artemisia hausiliensis',
#  u'oat groats (toasted)',
#  u'mindanaese cinnamomum oil',
#  u'reported found european cranberry',
#  u'fried or grilled beef',
#  u'(heated)',
#  u'myrtle',
#  u'hydrolyzed vegetable protein',
#  u'cocoa (2 1 ppm)',
#  u'constituent of allium sativum essential oil',
#  u'sumatra benzoin',
#  u'(rosaceae',
#  u'black cur-rants',
#  u'kiwi fruit',
#  u'fermented tea',
#  u'peanut (arachis hypogaea)',
#  u'anise (pimpinella anisum l )',
#  u'of pinus jeffreyi murr',
#  u'contained',
#  u'matricaria parthenium',
#  u'pantothenic acid',
#  u'myrtle leaf',
#  u'beef tallow',
#  u'cloves',
#  u'coconut oil',
#  u'durian (durio zibethinus)',
#  u'romano',
#  u'roasted shellfish',
#  u'elderberries',
#  u'sweet marjoram',
#  u'stored hops',
#  u'passionfruit',
#  u'orris derivatives',
#  u'cooked potatoes',
#  u'which only traces of cysteine are present',
#  u'natural resources',
#  u'wheat bran',
#  u'caucas',
#  u'melissa oil (9 99%)',
#  u'essential oils as an ester',
#  u'heracleum giganteum l',
#  u'comte',
#  u'other fats as a product of oxidative rancidity',
#  u'cheese',
#  u'whiskies',
#  u'eucalyptus goniocalyx',
#  u'the aroma of roasted coffee',
#  u'celery stalk',
#  u'orientalis',
#  u'spanish',
#  u'of litsea odorifera',
#  u'lamb\u2019s let-tuce',
#  u'cassava',
#  u'sheep',
#  u'clary sage',
#  u'santalols are found among the',
#  u'geranium rose-scented oil (pelargonium spp ) cuba (14 70%)',
#  u'coriander leaf',
#  u'grapefruit blossoms',
#  u'shrimp (cooked)',
#  u'white',
#  u'over 170 natural products including apricot',
#  u'of cinnamomum cassia',
#  u'l-bornyl isovalerate has been reported',
#  u'cheeses (blue',
#  u'assorted types of lima',
#  u'citronella',
#  u'gin',
#  u'flowers',
#  u'onion oil',
#  u'canned beef stew',
#  u'roman chamomile oil',
#  u'oats',
#  u'and zucc',
#  u'achasma walang val',
#  u'geranium stem oil',
#  u'essential oils',
#  u'apples',
#  u'fruits',
#  u'as a volatile component in',
#  u'black chokeberry (aronia',
#  u'coconut',
#  u'pine-apple',
#  u'cape gooseberry',
#  u'balsam',
#  u'the most abundant',
#  u'1-methylnaphthalene at concentrations ranging from 2 8 to 49 2 ppb',
#  u'cajenne linalool',
#  u'coriaria',
#  u'roasted hazelnut',
#  u'beef extract',
#  u'red sage',
#  u'peel oils of orange',
#  u'boiled crab',
#  u'rue (ruta graveolens l )',
#  u'pseudohirtum',
#  u'sometimes esterified',
#  u'mixture with the l-form',
#  u'jack fruit',
#  u'vanilla fragrans',
#  u'types of grape brandy',
#  u'santolinaefolia)',
#  u'ericaceae',
#  u'reported found as a constituent of coffee',
#  u'barbaco fruit (carica pentagona heilbron)',
#  u'honeydew',
#  u'over 100 foods',
#  u'enzymes with a molar ratio of 3 5% compared to the other amino acids',
#  u'from roots of cochlearia armoracia',
#  u'arctic bramble',
#  u'foeniculum vulgare piperitum oil (14 1%)',
#  u'scaberrima',
#  u'ambergris oil',
#  u'normally occurring',
#  u'passion fruit juice',
#  u'cistus ladaniferus l',
#  ...]

# %%
recipe_comb

# %%
compute_all_weights(recipe_comb, comp_ing_dict, edge_list)

# %%
# def match_ingredients(recipe, comp_ing_dict):
#     sanitzed_comp_ing = {k.decode('utf-8'): v for k, v in comp_ing_dict.iteritems()}
#     matches = []
#     for ing in recipe:
#         match_list = process.extractBests(ing, sanitzed_comp_ing.keys(), scorer=fuzz.token_set_ratio, score_cutoff=85)
#         matches+= [match[0] for match in match_list]
#     return None

# %%
from itertools import permutations

# %%
with open('./backbone_edges_dict.pkl') as f:
    edge_dict = pickle.load(f)

# %%
# recipe_comb

# %%
rt = ['coffee', 'milk']

# %%
compute_single_avg_weight(rt, comp_ing_dict, edge_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-6c63a9e5894f> in <module>()
# ----> 1 compute_single_avg_weight(rt, comp_ing_dict, edge_dict)
#
# TypeError: compute_single_avg_weight() takes exactly 4 arguments (3 given)

# %%
35*2/()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-96ae150719a2> in <module>()
# ----> 1 35*2/()
#
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'

# %%
rt = recipe_comb['Spiced Cocoa Recipe']
print len(list(permutations(rt,2)))
# Out:
# 30

# %%
edge_ids = []
for ing_pair in list(permutations(match_ingredients(rt, comp_ing_dict), 2)):
    edge_ids.append(ing_pair[0] +', ' + ing_pair[1])
#     edge_ids.append(ing_pair[1] +', ' + ing_pair[0])
edge_ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4264dfe45095> in <module>()
#       1 edge_ids = []
# ----> 2 for ing_pair in list(permutations(match_ingredients(rt, comp_ing_dict), 2)):
#       3     edge_ids.append(ing_pair[0] +', ' + ing_pair[1])
#       4 #     edge_ids.append(ing_pair[1] +', ' + ing_pair[0])
#       5 edge_ids
#
# NameError: name 'permutations' is not defined

# %%
for edge in edge_ids:
    if edge_dict[edge] != 0:
        print edge, edge_dict[edge]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d48a390341c5> in <module>()
# ----> 1 for edge in edge_ids:
#       2     if edge_dict[edge] != 0:
#       3         print edge, edge_dict[edge]
#
# NameError: name 'edge_ids' is not defined

# %%
match_ingredients(rt, comp_ing_dict)
# Out:
# [u'maple syrup',
#  u'lemon',
#  u'juice',
#  u'corn mint',
#  u'pepper-mint oil',
#  u'corn mint oil',
#  u'juice (lemon',
#  u'lemon juice',
#  u'mint',
#  u'corn mint oil (mentha arvensis l']

# %%
# asc_comp_ing.keys()

# %%
def get_range(dictionary, begin, end):
  return dict(itertools.islice(dictionary.iteritems(), begin, end+1))

# %%
recipe_sub = get_range(recipe_comb,0,10)
# %prun recipe_weights = compute_all_weights(recipe_sub, comp_ing_dict, edge_dict)

# %%
recipe_weights
# Out:
# defaultdict(float,
#             {u'Corpse Reviver No. 1': 6.333333333333333,
#              u'Dark and Stormy ': 38.0,
#              u'Grapefruit Negroni': 0.2,
#              u'Harvest Highball': 4.666666666666666,
#              u'John the Baptist Recipe': 1.0,
#              u'Perfect Ten Martini': 0.0,
#              u'Samba Breeze': 2.333333333333333,
#              u'Smokin\u2019 Mary': 0.4,
#              u'Sunset Gold': 0.0,
#              u'The Joy Division': 0.0,
#              u'The Translucent Cocktail': 0.0})

# %%
with open('./avg_recipe_weights.pkl', 'r') as f:
    avg_w = pickle.load(f)

# %%
avg_w
# Out:
# defaultdict(float,
#             {u'Grapefruit Negroni': 0.2,
#              u'Greenpoint': 0.6,
#              u'Harvest Highball': 4.666666666666666,
#              u'Perfect Ten Martini': 0.0,
#              u'Piha Spritz Recipe': 1.857142857142857,
#              u'Pumpkin &amp; Spice': 2.75,
#              u'Rob Roy': 1.6666666666666665,
#              u'Samba Breeze': 2.333333333333333,
#              u'Sunset Gold': 0.0,
#              u'The Joy Division': 0.0,
#              u'The Translucent Cocktail': 0.0})

# %%
with open('./new_avg_random_weights.pkl', 'r') as f:
    avg_random = pickle.load(f)
